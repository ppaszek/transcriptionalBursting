# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn import linear_model
from statsmodels.formula.api import ols

induced_data = pd.read_csv('induced_genes_outliers_removed_all_zero_removed.csv')
induced_data = induced_data.iloc[:,1:]

#grp1 = ['IFITM3','SRGN','IL1RN','IFI27L2A','TNF','IFI205','TARM1','TNFSF9','IRG1','GLIPR2','INHBA','BTG1','PSME2','CLEC4E','2310016C08RIK','SQSTM1','NFKBIA','USP18','EBI3','CD86','MS4A6D','NT5C3','FPR2','H3F3B','SERPINA3G','CAV1','FAS','MS4A6C','LGALS9','GM4902','CD200','IFI204','CISH','PROCR','SLAMF7','AI607873','SGK1','IL15','ACPP','CXCL16','SLFN2','H2-Q7','MT2','H2-T23','THBS1','UBE2L6','AY096003','H1F0','ATF3','TANK','TNFSF15','HSPA5','IL15RA','IRF1','MED21','IRGM1','CCRL2','ZBP1','CASP1','RAB32','SP100','IRF8','BLNK','PSMB9','PCGF5','KTELC1','RILPL2','TMEM39A','TRIM30A','TNIP3','RBM7','SLC2A6','GBP3','BIRC3','TLR2','GTF2B','CFB','SBDS','CAR13','ARF4','SEPW1','BST2','NMI','DUSP1','PYHIN1','CD47','ZFP36','CD274','SAMHD1','SWAP70','IL7R','RELA','AK042010','A130040M12RIK','D14ERTD668E','NFKBIZ','ADAP2','XAF1','PNP','ZUFSP','IFI35','ACSL1','ANXA7','SLC7A2','HERC6','TAPBP','SLFN5','SLFN8','IFIH1','FGL2','LCP2','STAT1','GBP5','TRIM30D','LAP3','STAT5A','GBP6','DDX58','CLIC4','DHX58','STAT2','TNFAIP3','TAP1','ELL2','PIK3R5','PARP9','KPNA3','HIF1A','AFTPH','DTX3L']
#grp2 = ['SDC4','CXCL1','IL1A','CXCL3','IL1B','CCL3','AW112010','CCL17','PRDX1','CCL4','H2-M2']
#with open("global_regressions/summary.csv","w") as logfile:
#    logfile.write("gene,scoreAll\n")


#glist=['CCL5','CCL17','AK217941','AK138792','PRDX1','CXCL10','APOL7C','AW112010','IL1B','CXCL1','CCL3','SDC4','H2-M2','LY6C2','CLU','IL1A','ZDHHC21','CXCL3','CCR7','CD14','CD69','BCL2A1B','IFI27L2A','SLPI','SERPINB9','IFITM3','AA467197','GLIPR2','MX1','TNF','TARM1','BCL2A1D','CLEC4D','IRG1','CD40','BCL2A1A','USP18','SAMSN1','CLEC4E','CAR4','1810029B16RIK','CD86','SQSTM1','SERPINB6B','RNASET2B','MS4A6D','NUPR1','P2RY14','2310016C08RIK','H2-Q7','FOS','GBP2','CDKN1A','NFKBIA','FPR1','EBI3','FPR2','SAMHD1','UBE2L6','IFIT2','MS4A6C','ARF4','STXBP3A','AY096003','EPSTI1','TNIP3','AI607873','SLAMF7','CD200','RAB8B','MT2','SLFN2','HSPA5','BIRC3','IRGM1','MARCKSL1','TMEM39A','ETV3','TREX1','PROCR','BLNK','RELA','RTP4','CCRL2','TRIM30A','BHLHE40','PLAUR','KYNU','TLR2','BST2','SWAP70','ZBP1','SP100','GBP3','PCGF5','KTELC1','IRF8','IGTP','SOD2','CISH','TNFSF15','MNDAL','CFB','PLEK','PNP','ZFP36','NMI','SLC2A6','H1F0','SBDS','XAF1','NFKBIZ','TRAF1','PYHIN1','MTPN','SLC7A2','APOBEC3','CD274','TAPBP','LGALS3BP','KTN1','PPP1CB','ZUFSP','PTTG1','IFIH1','GM4951','BATF','ADAP2','IFI203','IFI35','GADD45B','PELI1','STAT1','LCP2','STAT2','GBP6','KPNA3','SLFN5','GBP5','PFKP','TAP1','TOR3A','INSIG1','DAB2','AFTPH','TXNRD1']

regression_data=pd.read_csv('summary_mean_var_all_cond.csv')
glist=regression_data.iloc[:,0].tolist();

# %%
x
# Out:
# array([  3.04802783e+01,   4.54950095e+02,   8.38031117e+02,
#          7.10301238e+02,   9.72864922e+02,   1.41244583e+02,
#          1.08086040e+03,   8.14579840e+02,   2.01483062e+02,
#          3.21550343e+02,   1.18444405e+01,   4.50396451e+01,
#          1.57874524e+03,   2.02917395e+02,   1.01740475e+02,
#          1.59641919e+03,   2.87951322e-01,   2.90803889e+03,
#          3.32398058e+02,   1.08762771e+03,   4.85120121e+01,
#          1.74788576e+03,   2.64619210e+03,   1.52172552e+03,
#          8.73531625e+00,   4.56399480e+02])

# %%
#print(induced_data.head)

#genelist = induced_data.iloc[:,0].reset_index(drop=True).drop_duplicates().tolist()
#genelist += [genelist.pop(24)] #manually moving index 24 TNF to end so visible on plots

i=0

plt.subplots(1,1,figsize=(5,4.5))
axes = plt.gca()
axes.set_xlim([0,4])
axes.set_ylim([0,10000000])

with open("my_summary_freq_var_all_conds_robust_2702.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % ('gene','N','intercept','slope','min x','max x','R2'))



for test_gene in glist:
    i+=1
    print(i)
    summary_stats = induced_data[induced_data["Gene"]==test_gene]
    #print(summary_stats)
    if (len(summary_stats.loc[summary_stats['Mean'] == 0,['Mean']])>0) :
        print("Missing data for %s" % test_gene)
        with open("errorlog.csv","a") as logfile:
            logfile.write("%s\n" % test_gene)
        continue
    
    print("Working on %s mean/freq regression..." % test_gene)
    

    x=np.ravel(summary_stats['Frequency'].values.reshape(-1, 1))
    #print(x)
    y=np.ravel(summary_stats['Var'].values.reshape(-1, 1))
    x=x.reshape(-1, 1)
    y=y.reshape(-1, 1)
    
    lm = linear_model.LinearRegression()
    model = lm.fit(x,y)
    
    Fy=lm.predict(x)
    Residuals=y-Fy;   
    I = abs( Residuals) < 1.5 * np.std(Residuals);
    x1=x[I==True]
    y1=y[I==True]
    x1=x1.reshape(-1, 1)
    y1=y1.reshape(-1, 1)
    
    model = lm.fit(x1,y1)
    print("Intercept:\t",lm.intercept_)
    print("Coefficients:\t",lm.coef_)
    scoreAll = lm.score(x1,y1)
    print("R^2 score:\t",scoreAll)

    linecol = 'gray'

    """
    if(test_gene == 'TNF') :
        linecol = 'red'
    elif(test_gene == 'IL1A'):
        linecol = 'blue'
    elif(test_gene == 'IL1B'):
        linecol = 'green'
    elif(test_gene == 'CCL4'):
        linecol = 'orange'
    elif(test_gene == 'CCL17'):
        linecol = 'purple'
    """
    
    #if test_gene in glist:
        
    plt.plot(x1, lm.predict(x1), color=linecol, linewidth=1)

    with open("my_summary_freq_var_all_conds_robust_2702.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % (test_gene,len(x1),float(lm.intercept_),float(lm.coef_),float(min(x1)), float(max(x1)), scoreAll))
        print("%s,%s\n" % (test_gene,scoreAll))

plt.ylabel("Var")
plt.xlabel("Freq")
#plt.savefig("global_regressions/mean_var_composite.png")
plt.savefig("my_freq_var_allconds_robust.png")
plt.close()
# Out:
# 1
# Working on CXCL1 mean/freq regression...
# Intercept:	 [-885357.11924436]
# Coefficients:	 [[ 22700382.8939885]]
# R^2 score:	 0.913253087269
# CXCL1,0.913253087269
#
# 2
# Working on RSAD2 mean/freq regression...
# Intercept:	 [-201494.89215769]
# Coefficients:	 [[ 2000196.81069357]]
# R^2 score:	 0.931325814766
# RSAD2,0.931325814766
#
# 3
# Working on OASL1 mean/freq regression...
# Intercept:	 [-21998.81041718]
# Coefficients:	 [[ 389407.78927243]]
# R^2 score:	 0.961882171222
# OASL1,0.961882171222
#
# 4
# Working on NT5C3 mean/freq regression...
# Intercept:	 [-32844.60156794]
# Coefficients:	 [[ 419240.73878072]]
# R^2 score:	 0.916126966314
# NT5C3,0.916126966314
#
# 5
# Working on CCL4 mean/freq regression...
# Intercept:	 [-12299533.30986355]
# Coefficients:	 [[  1.82661193e+08]]
# R^2 score:	 0.926163083136
# CCL4,0.926163083136
#
# 6
# Working on EBI3 mean/freq regression...
# Intercept:	 [-67303.8507555]
# Coefficients:	 [[ 666930.88087833]]
# R^2 score:	 0.725928976911
# EBI3,0.725928976911
#
# 7
# Working on IRGM1 mean/freq regression...
# Intercept:	 [-11209.25550836]
# Coefficients:	 [[ 176775.95276144]]
# R^2 score:	 0.802425004162
# IRGM1,0.802425004162
#
# 8
# Working on IFIT2 mean/freq regression...
# Intercept:	 [-15963.89448716]
# Coefficients:	 [[ 287873.52216942]]
# R^2 score:	 0.960688006395
# IFIT2,0.960688006395
#
# 9
# Working on PYHIN1 mean/freq regression...
# Intercept:	 [-6054.51437153]
# Coefficients:	 [[ 95165.19246288]]
# R^2 score:	 0.967059184299
# PYHIN1,0.967059184299
#
# 10
# Working on CAR4 mean/freq regression...
# Intercept:	 [-15625.18672115]
# Coefficients:	 [[ 847534.43701147]]
# R^2 score:	 0.937736698148
# CAR4,0.937736698148
#
# 11
# Working on SLFN8 mean/freq regression...
# Intercept:	 [-1325.43988163]
# Coefficients:	 [[ 41045.30229152]]
# R^2 score:	 0.803904303125
# SLFN8,0.803904303125
#
# 12
# Working on AW112010 mean/freq regression...
# Intercept:	 [-3330584.50638699]
# Coefficients:	 [[ 20275815.63735066]]
# R^2 score:	 0.872085806298
# AW112010,0.872085806298
#
# 13
# Working on U90926 mean/freq regression...
# Intercept:	 [-53981.37279878]
# Coefficients:	 [[ 4873050.58103412]]
# R^2 score:	 0.169339285737
# U90926,0.169339285737
#
# 14
# Working on IL15 mean/freq regression...
# Intercept:	 [-13649.3769916]
# Coefficients:	 [[ 276455.92633741]]
# R^2 score:	 0.883964627289
# IL15,0.883964627289
#
# 15
# Working on GM4902 mean/freq regression...
# Intercept:	 [-18833.71587631]
# Coefficients:	 [[ 307456.1524145]]
# R^2 score:	 0.832530306718
# GM4902,0.832530306718
#
# 16
# Working on GM14446 mean/freq regression...
# Intercept:	 [-54294.60404217]
# Coefficients:	 [[ 2437182.62152447]]
# R^2 score:	 0.909358263928
# GM14446,0.909358263928
#
# 17
# Working on FAM26F mean/freq regression...
# Intercept:	 [-160.71619766]
# Coefficients:	 [[ 107455.53703714]]
# R^2 score:	 0.708175409236
# FAM26F,0.708175409236
#
# 18
# Working on D14ERTD668E mean/freq regression...
# Intercept:	 [-2039.83669516]
# Coefficients:	 [[ 65913.77328196]]
# R^2 score:	 0.914533310157
# D14ERTD668E,0.914533310157
#
# 19
# Working on GM4951 mean/freq regression...
# Intercept:	 [-3123.49028592]
# Coefficients:	 [[ 109593.86987306]]
# R^2 score:	 0.924265703955
# GM4951,0.924265703955
#
# 20
# Working on FGL2 mean/freq regression...
# Intercept:	 [-2461.60466641]
# Coefficients:	 [[ 39137.44675989]]
# R^2 score:	 0.519984083456
# FGL2,0.519984083456
#
# 21
# Working on APOL7C mean/freq regression...
# Intercept:	 [-119644.26609806]
# Coefficients:	 [[ 6174553.59924255]]
# R^2 score:	 0.590171758837
# APOL7C,0.590171758837
#
# 22
# Working on TRIM30A mean/freq regression...
# Intercept:	 [-9419.12428049]
# Coefficients:	 [[ 166567.48454758]]
# R^2 score:	 0.926671911612
# TRIM30A,0.926671911612
#
# 23
# Working on CCL3 mean/freq regression...
# Intercept:	 [-728750.22718638]
# Coefficients:	 [[ 19749029.52718284]]
# R^2 score:	 0.422589143736
# CCL3,0.422589143736
#
# 24
# Working on CXCL3 mean/freq regression...
# Intercept:	 [-1025845.2190933]
# Coefficients:	 [[ 14243704.47342089]]
# R^2 score:	 0.64677564925
# CXCL3,0.64677564925
#
# 25
# Working on CFB mean/freq regression...
# Intercept:	 [-2790.35763622]
# Coefficients:	 [[ 129066.67349659]]
# R^2 score:	 0.817857697244
# CFB,0.817857697244
#
# 26
# Working on TMEM39A mean/freq regression...
# Intercept:	 [-9004.33802506]
# Coefficients:	 [[ 167635.3490682]]
# R^2 score:	 0.775383832377
# TMEM39A,0.775383832377
#
# 27
# Working on CCND2 mean/freq regression...
# Intercept:	 [-17667.56716193]
# Coefficients:	 [[ 193778.67876572]]
# R^2 score:	 0.769240993598
# CCND2,0.769240993598
#
# 28
# Working on MS4A6C mean/freq regression...
# Intercept:	 [-13682.62398058]
# Coefficients:	 [[ 359478.35525943]]
# R^2 score:	 0.747180574187
# MS4A6C,0.747180574187
#
# 29
# Working on IRG1 mean/freq regression...
# Intercept:	 [-28366.16681555]
# Coefficients:	 [[ 1148940.27728561]]
# R^2 score:	 0.812111217165
# IRG1,0.812111217165
#
# 30
# Working on CCR7 mean/freq regression...
# Intercept:	 [-10574.02275831]
# Coefficients:	 [[ 4145028.72455025]]
# R^2 score:	 0.780858930318
# CCR7,0.780858930318
#
# 31
# Working on USP18 mean/freq regression...
# Intercept:	 [-46135.14135621]
# Coefficients:	 [[ 594810.09380982]]
# R^2 score:	 0.835173404665
# USP18,0.835173404665
#
# 32
# Working on IFIT3 mean/freq regression...
# Intercept:	 [-26346.10930915]
# Coefficients:	 [[ 1151001.49115131]]
# R^2 score:	 0.972165593507
# IFIT3,0.972165593507
#
# 33
# Working on ACPP mean/freq regression...
# Intercept:	 [-22332.25774771]
# Coefficients:	 [[ 256331.51804568]]
# R^2 score:	 0.728017486737
# ACPP,0.728017486737
#
# 34
# Working on ACSL1 mean/freq regression...
# Intercept:	 [-6866.56634799]
# Coefficients:	 [[ 65500.45841277]]
# R^2 score:	 0.587330330264
# ACSL1,0.587330330264
#
# 35
# Working on STAT5A mean/freq regression...
# Intercept:	 [-4665.4242692]
# Coefficients:	 [[ 41435.53516215]]
# R^2 score:	 0.721544412597
# STAT5A,0.721544412597
#
# 36
# Working on TNFSF9 mean/freq regression...
# Intercept:	 [-20715.6036588]
# Coefficients:	 [[ 677587.86956986]]
# R^2 score:	 0.581425632687
# TNFSF9,0.581425632687
#
# 37
# Working on CD40 mean/freq regression...
# Intercept:	 [-89214.14334413]
# Coefficients:	 [[ 1292803.13345132]]
# R^2 score:	 0.841275197548
# CD40,0.841275197548
#
# 38
# Working on IFI205 mean/freq regression...
# Intercept:	 [-91341.96233798]
# Coefficients:	 [[ 1092791.97548182]]
# R^2 score:	 0.856446216394
# IFI205,0.856446216394
#
# 39
# Working on MS4A4C mean/freq regression...
# Intercept:	 [-8943.34793186]
# Coefficients:	 [[ 333878.71135855]]
# R^2 score:	 0.851532173246
# MS4A4C,0.851532173246
#
# 40
# Working on TARM1 mean/freq regression...
# Intercept:	 [-111145.70970177]
# Coefficients:	 [[ 1388382.29770968]]
# R^2 score:	 0.738524530982
# TARM1,0.738524530982
#
# 41
# Working on NUDT17 mean/freq regression...
# Intercept:	 [-12178.09653974]
# Coefficients:	 [[ 406193.94425795]]
# R^2 score:	 0.839741572084
# NUDT17,0.839741572084
#
# 42
# Working on AFTPH mean/freq regression...
# Intercept:	 [-1378.34203527]
# Coefficients:	 [[ 18598.90785344]]
# R^2 score:	 0.77081532196
# AFTPH,0.77081532196
#
# 43
# Working on IRF7 mean/freq regression...
# Intercept:	 [-3731.67717775]
# Coefficients:	 [[ 107043.97195523]]
# R^2 score:	 0.868389430844
# IRF7,0.868389430844
#
# 44
# Working on TLR2 mean/freq regression...
# Intercept:	 [-3224.79170512]
# Coefficients:	 [[ 124052.15279235]]
# R^2 score:	 0.681126595259
# TLR2,0.681126595259
#
# 45
# Working on IL15RA mean/freq regression...
# Intercept:	 [-6286.83432691]
# Coefficients:	 [[ 177194.63371219]]
# R^2 score:	 0.759826578787
# IL15RA,0.759826578787
#
# 46
# Working on INHBA mean/freq regression...
# Intercept:	 [-10806.04478992]
# Coefficients:	 [[ 560774.69672142]]
# R^2 score:	 0.701282523523
# INHBA,0.701282523523
#
# 47
# Working on IIGP1 mean/freq regression...
# Intercept:	 [-3217.68700166]
# Coefficients:	 [[ 95527.02033241]]
# R^2 score:	 0.619086859059
# IIGP1,0.619086859059
#
# 48
# Working on TRIM30D mean/freq regression...
# Intercept:	 [-1553.52456216]
# Coefficients:	 [[ 39112.40190068]]
# R^2 score:	 0.861031935132
# TRIM30D,0.861031935132
#
# 49
# Working on TIMP1 mean/freq regression...
# Intercept:	 [-20857.67557924]
# Coefficients:	 [[ 867980.64815686]]
# R^2 score:	 0.770265098434
# TIMP1,0.770265098434
#
# 50
# Working on CCL7 mean/freq regression...
# Intercept:	 [-40561.92869717]
# Coefficients:	 [[ 8690817.33505044]]
# R^2 score:	 0.219958680027
# CCL7,0.219958680027
#
# 51
# Working on SRGN mean/freq regression...
# Intercept:	 [ 168911.50876802]
# Coefficients:	 [[ 1395398.48366375]]
# R^2 score:	 0.749823938741
# SRGN,0.749823938741
#
# 52
# Working on IL1A mean/freq regression...
# Intercept:	 [ 274143.37026429]
# Coefficients:	 [[ 5085170.35004315]]
# R^2 score:	 0.500113076476
# IL1A,0.500113076476
#
# 53
# Working on SERPINA3G mean/freq regression...
# Intercept:	 [-5869.97924372]
# Coefficients:	 [[ 354921.56762911]]
# R^2 score:	 0.555723771198
# SERPINA3G,0.555723771198
#
# 54
# Working on TAP1 mean/freq regression...
# Intercept:	 [-983.53498706]
# Coefficients:	 [[ 29244.50890706]]
# R^2 score:	 0.765791557033
# TAP1,0.765791557033
#
# 55
# Working on SLAMF7 mean/freq regression...
# Intercept:	 [ 6403.3083285]
# Coefficients:	 [[ 264524.72701838]]
# R^2 score:	 0.700949686281
# SLAMF7,0.700949686281
#
# 56
# Working on IFIT1 mean/freq regression...
# Intercept:	 [ 39462.00422126]
# Coefficients:	 [[ 476558.69216953]]
# R^2 score:	 0.721892073973
# IFIT1,0.721892073973
#
# 57
# Working on CISH mean/freq regression...
# Intercept:	 [-6652.74802143]
# Coefficients:	 [[ 232358.03248116]]
# R^2 score:	 0.722009199318
# CISH,0.722009199318
#
# 58
# Working on FAS mean/freq regression...
# Intercept:	 [-8593.25933067]
# Coefficients:	 [[ 267712.40368347]]
# R^2 score:	 0.518874504691
# FAS,0.518874504691
#
# 59
# Working on CXCL10 mean/freq regression...
# Intercept:	 [-1960796.59462251]
# Coefficients:	 [[ 24726462.87447429]]
# R^2 score:	 0.83299730983
# CXCL10,0.83299730983
#
# 60
# Working on SLFN5 mean/freq regression...
# Intercept:	 [-5482.68609441]
# Coefficients:	 [[ 50069.30977904]]
# R^2 score:	 0.873698836474
# SLFN5,0.873698836474
#
# 61
# Working on SLC2A6 mean/freq regression...
# Intercept:	 [-6227.75538076]
# Coefficients:	 [[ 112556.9291791]]
# R^2 score:	 0.475972820267
# SLC2A6,0.475972820267
#
# 62
# Working on CMPK2 mean/freq regression...
# Intercept:	 [-15138.40552283]
# Coefficients:	 [[ 264216.7130918]]
# R^2 score:	 0.778294052687
# CMPK2,0.778294052687
#
# 63
# Working on PCGF5 mean/freq regression...
# Intercept:	 [ 2320.43131046]
# Coefficients:	 [[ 55161.75455519]]
# R^2 score:	 0.154699951891
# PCGF5,0.154699951891
#
# 64
# Working on CAR13 mean/freq regression...
# Intercept:	 [-2031.8471297]
# Coefficients:	 [[ 71531.60888998]]
# R^2 score:	 0.487329014918
# CAR13,0.487329014918
#
# 65
# Working on GBP3 mean/freq regression...
# Intercept:	 [-5362.22289601]
# Coefficients:	 [[ 117481.64555758]]
# R^2 score:	 0.745143949618
# GBP3,0.745143949618
#
# 66
# Working on UBE2L6 mean/freq regression...
# Intercept:	 [-920.75356199]
# Coefficients:	 [[ 210842.03890927]]
# R^2 score:	 0.67268299471
# UBE2L6,0.67268299471
#
# 67
# Working on MX2 mean/freq regression...
# Intercept:	 [ 33.57400614]
# Coefficients:	 [[ 74696.85264366]]
# R^2 score:	 0.720982586566
# MX2,0.720982586566
#
# 68
# Working on ZDHHC21 mean/freq regression...
# Intercept:	 [ 51935.09002546]
# Coefficients:	 [[-70839.98422729]]
# R^2 score:	 0.249025792701
# ZDHHC21,0.249025792701
#
# 69
# Working on AK138792 mean/freq regression...
# Intercept:	 [ 802097.80463901]
# Coefficients:	 [[-898285.52469611]]
# R^2 score:	 0.217775184848
# AK138792,0.217775184848
#
# 70
# Working on CH25H mean/freq regression...
# Intercept:	 [-6232.19449345]
# Coefficients:	 [[ 418063.41054068]]
# R^2 score:	 0.536886880051
# CH25H,0.536886880051
#
# 71
# Working on PTGS2 mean/freq regression...
# Intercept:	 [-2420.37527695]
# Coefficients:	 [[ 114576.51846943]]
# R^2 score:	 0.820570535738
# PTGS2,0.820570535738
#
# 72
# Working on SAMHD1 mean/freq regression...
# Intercept:	 [-12730.86920742]
# Coefficients:	 [[ 75582.08437476]]
# R^2 score:	 0.548407393877
# SAMHD1,0.548407393877
#
# 73
# Working on SDC4 mean/freq regression...
# Intercept:	 [ 10647.98607669]
# Coefficients:	 [[ 4675537.96980196]]
# R^2 score:	 0.189477683992
# SDC4,0.189477683992
#
# 74
# Working on ADAP2 mean/freq regression...
# Intercept:	 [ 489.90758886]
# Coefficients:	 [[ 40691.40427128]]
# R^2 score:	 0.431670614629
# ADAP2,0.431670614629
#
# 75
# Working on MS4A6D mean/freq regression...
# Intercept:	 [-29481.77299691]
# Coefficients:	 [[ 487764.9407181]]
# R^2 score:	 0.709197822765
# MS4A6D,0.709197822765
#
# 76
# Working on ATF3 mean/freq regression...
# Intercept:	 [-810.81950886]
# Coefficients:	 [[ 158441.07871477]]
# R^2 score:	 0.387334741669
# ATF3,0.387334741669
#
# 77
# Working on TNFSF15 mean/freq regression...
# Intercept:	 [-9019.97421209]
# Coefficients:	 [[ 182304.85401087]]
# R^2 score:	 0.83832385273
# TNFSF15,0.83832385273
#
# 78
# Working on RELA mean/freq regression...
# Intercept:	 [ 8102.63824044]
# Coefficients:	 [[ 22111.13753772]]
# R^2 score:	 0.0479893205203
# RELA,0.0479893205203
#
# 79
# Working on ZFP36 mean/freq regression...
# Intercept:	 [-5836.68915262]
# Coefficients:	 [[ 85624.02345371]]
# R^2 score:	 0.481793556277
# ZFP36,0.481793556277
#
# 80
# Working on SLFN2 mean/freq regression...
# Intercept:	 [ 77324.65682895]
# Coefficients:	 [[ 163578.47579895]]
# R^2 score:	 0.369268910881
# SLFN2,0.369268910881
#
# 81
# Working on GM12250 mean/freq regression...
# Intercept:	 [-539.04600562]
# Coefficients:	 [[ 33984.74919879]]
# R^2 score:	 0.919309118891
# GM12250,0.919309118891
#
# 82
# Working on STAT1 mean/freq regression...
# Intercept:	 [ 1792.69674777]
# Coefficients:	 [[ 34667.88675135]]
# R^2 score:	 0.73079460654
# STAT1,0.73079460654
#
# 83
# Working on BIRC3 mean/freq regression...
# Intercept:	 [ 6728.17177594]
# Coefficients:	 [[ 54451.03723672]]
# R^2 score:	 0.12600330336
# BIRC3,0.12600330336
#
# 84
# Working on 1190002H23RIK mean/freq regression...
# Intercept:	 [ 6433.82562932]
# Coefficients:	 [[ 129818.98993254]]
# R^2 score:	 0.148887081084
# 1190002H23RIK,0.148887081084
#
# 85
# Working on ALDH1A2 mean/freq regression...
# Intercept:	 [ 6016.38451126]
# Coefficients:	 [[ 189476.38236486]]
# R^2 score:	 0.119505428638
# ALDH1A2,0.119505428638
#
# 86
# Working on OASL2 mean/freq regression...
# Intercept:	 [-1625.76927]
# Coefficients:	 [[ 83287.07306163]]
# R^2 score:	 0.734479278862
# OASL2,0.734479278862
#
# 87
# Working on IL27 mean/freq regression...
# Intercept:	 [-2041.08593079]
# Coefficients:	 [[ 166221.68925936]]
# R^2 score:	 0.400567298735
# IL27,0.400567298735
#
# 88
# Working on H1F0 mean/freq regression...
# Intercept:	 [ 3930.02367567]
# Coefficients:	 [[ 154197.66559239]]
# R^2 score:	 0.422189086177
# H1F0,0.422189086177
#
# 89
# Working on CCL2 mean/freq regression...
# Intercept:	 [ 156763.82208902]
# Coefficients:	 [[ 5163279.760056]]
# R^2 score:	 0.15469826984
# CCL2,0.15469826984
#
# 90
# Working on DDX58 mean/freq regression...
# Intercept:	 [-1155.3542925]
# Coefficients:	 [[ 34753.3999531]]
# R^2 score:	 0.774913972719
# DDX58,0.774913972719
#
# 91
# Working on GBP5 mean/freq regression...
# Intercept:	 [-284.90176102]
# Coefficients:	 [[ 35367.17357313]]
# R^2 score:	 0.760455535151
# GBP5,0.760455535151
#
# 92
# Working on CAV1 mean/freq regression...
# Intercept:	 [ 11042.41388105]
# Coefficients:	 [[ 235129.61174207]]
# R^2 score:	 0.589205610142
# CAV1,0.589205610142
#
# 93
# Working on NMI mean/freq regression...
# Intercept:	 [-705.25179885]
# Coefficients:	 [[ 86536.95067914]]
# R^2 score:	 0.577052047018
# NMI,0.577052047018
#
# 94
# Working on CCL17 mean/freq regression...
# Intercept:	 [ 101473.6306629]
# Coefficients:	 [[  1.35065742e+08]]
# R^2 score:	 0.513974337039
# CCL17,0.513974337039
#
# 95
# Working on SLPI mean/freq regression...
# Intercept:	 [ 185710.35322868]
# Coefficients:	 [[-452294.29859675]]
# R^2 score:	 0.016346417623
# SLPI,0.016346417623
#
# 96
# Working on H2-T23 mean/freq regression...
# Intercept:	 [ 57716.1146715]
# Coefficients:	 [[ 134040.2138226]]
# R^2 score:	 0.378898298518
# H2-T23,0.378898298518
#
# 97
# Working on NFKBIZ mean/freq regression...
# Intercept:	 [ 3308.8694452]
# Coefficients:	 [[ 46137.39278159]]
# R^2 score:	 0.318995203188
# NFKBIZ,0.318995203188
#
# 98
# Working on DHX58 mean/freq regression...
# Intercept:	 [ 20.47415099]
# Coefficients:	 [[ 20788.73627777]]
# R^2 score:	 0.627285726268
# DHX58,0.627285726268
#
# 99
# Working on THBS1 mean/freq regression...
# Intercept:	 [ 6008.52723137]
# Coefficients:	 [[ 166151.01362583]]
# R^2 score:	 0.46496900379
# THBS1,0.46496900379
#
# 100
# Working on HERC6 mean/freq regression...
# Intercept:	 [ 1895.48263552]
# Coefficients:	 [[ 29033.2003783]]
# R^2 score:	 0.743933885624
# HERC6,0.743933885624
#
# 101
# Working on CD86 mean/freq regression...
# Intercept:	 [ 8702.2038975]
# Coefficients:	 [[ 349023.12177013]]
# R^2 score:	 0.440699728092
# CD86,0.440699728092
#
# 102
# Working on IGTP mean/freq regression...
# Intercept:	 [ 1049.20765109]
# Coefficients:	 [[ 61270.09461436]]
# R^2 score:	 0.713701497581
# IGTP,0.713701497581
#
# 103
# Working on FABP3 mean/freq regression...
# Intercept:	 [-15347.98704015]
# Coefficients:	 [[ 554749.3840081]]
# R^2 score:	 0.703813884381
# FABP3,0.703813884381
#
# 104
# Working on AK042010 mean/freq regression...
# Intercept:	 [ 3812.63528942]
# Coefficients:	 [[ 41157.08506747]]
# R^2 score:	 0.451023140747
# AK042010,0.451023140747
#
# 105
# Working on GBP6 mean/freq regression...
# Intercept:	 [ 452.36796821]
# Coefficients:	 [[ 30452.34207523]]
# R^2 score:	 0.65833138625
# GBP6,0.65833138625
#
# 106
# Working on IL1RN mean/freq regression...
# Intercept:	 [ 51340.90520783]
# Coefficients:	 [[ 1141534.82974945]]
# R^2 score:	 0.736219086588
# IL1RN,0.736219086588
#
# 107
# Working on SERPINB9B mean/freq regression...
# Intercept:	 [-5912.59741378]
# Coefficients:	 [[ 1138476.65940959]]
# R^2 score:	 0.106984045997
# SERPINB9B,0.106984045997
#
# 108
# Working on INSIG1 mean/freq regression...
# Intercept:	 [ 8659.06672479]
# Coefficients:	 [[-2485.10396382]]
# R^2 score:	 0.0176209122175
# INSIG1,0.0176209122175
#
# 109
# Working on RTP4 mean/freq regression...
# Intercept:	 [ 4675.12447916]
# Coefficients:	 [[ 142228.30749009]]
# R^2 score:	 0.86456282082
# RTP4,0.86456282082
#
# 110
# Working on IL1B mean/freq regression...
# Intercept:	 [ 928907.08104604]
# Coefficients:	 [[ 8541341.79569487]]
# R^2 score:	 0.510309030197
# IL1B,0.510309030197
#
# 111
# Working on IFI204 mean/freq regression...
# Intercept:	 [ 21912.12384047]
# Coefficients:	 [[ 212421.65128293]]
# R^2 score:	 0.702669951214
# IFI204,0.702669951214
#
# 112
# Working on CD69 mean/freq regression...
# Intercept:	 [-34622.00482329]
# Coefficients:	 [[ 1171358.85188197]]
# R^2 score:	 0.319954534648
# CD69,0.319954534648
#
# 113
# Working on LGALS9 mean/freq regression...
# Intercept:	 [ 18976.35360684]
# Coefficients:	 [[ 216048.75138896]]
# R^2 score:	 0.363146168423
# LGALS9,0.363146168423
#
# 114
# Working on IFI27L2A mean/freq regression...
# Intercept:	 [ 125934.67982896]
# Coefficients:	 [[ 715162.78568976]]
# R^2 score:	 0.294169595634
# IFI27L2A,0.294169595634
#
# 115
# Working on IFI47 mean/freq regression...
# Intercept:	 [-8479.16648054]
# Coefficients:	 [[ 335349.81870771]]
# R^2 score:	 0.8589125678
# IFI47,0.8589125678
#
# 116
# Working on CLU mean/freq regression...
# Intercept:	 [-208439.02907262]
# Coefficients:	 [[ 14494832.68102053]]
# R^2 score:	 0.599221315075
# CLU,0.599221315075
#
# 117
# Working on 2310016C08RIK mean/freq regression...
# Intercept:	 [ 35828.25287554]
# Coefficients:	 [[ 442313.31312427]]
# R^2 score:	 0.613826840535
# 2310016C08RIK,0.613826840535
#
# 118
# Working on KPNA3 mean/freq regression...
# Intercept:	 [ 1295.25622855]
# Coefficients:	 [[ 17232.7394845]]
# R^2 score:	 0.478080377786
# KPNA3,0.478080377786
#
# 119
# Working on GLIPR2 mean/freq regression...
# Intercept:	 [ 55581.66715111]
# Coefficients:	 [[ 392665.5034932]]
# R^2 score:	 0.114815869296
# GLIPR2,0.114815869296
#
# 120
# Working on XAF1 mean/freq regression...
# Intercept:	 [ 427.73200949]
# Coefficients:	 [[ 50887.50646769]]
# R^2 score:	 0.655902724667
# XAF1,0.655902724667
#
# 121
# Working on SLC7A2 mean/freq regression...
# Intercept:	 [ 224.63965265]
# Coefficients:	 [[ 32691.22234473]]
# R^2 score:	 0.428406262324
# SLC7A2,0.428406262324
#
# 122
# Working on PROCR mean/freq regression...
# Intercept:	 [-2.28526943]
# Coefficients:	 [[ 208823.49476397]]
# R^2 score:	 0.673694626686
# PROCR,0.673694626686
#
# 123
# Working on PRPF38A mean/freq regression...
# Intercept:	 [ 15096.77722645]
# Coefficients:	 [[-17274.43331245]]
# R^2 score:	 0.0255015214687
# PRPF38A,0.0255015214687
#
# 124
# Working on 1810029B16RIK mean/freq regression...
# Intercept:	 [ 84828.95104339]
# Coefficients:	 [[-28589.5270521]]
# R^2 score:	 0.00904415772236
# 1810029B16RIK,0.00904415772236
#
# 125
# Working on CCRL2 mean/freq regression...
# Intercept:	 [ 25185.62962487]
# Coefficients:	 [[ 60816.03433496]]
# R^2 score:	 0.242194752444
# CCRL2,0.242194752444
#
# 126
# Working on GBP2 mean/freq regression...
# Intercept:	 [ 4204.50811144]
# Coefficients:	 [[ 182324.54462345]]
# R^2 score:	 0.438330548652
# GBP2,0.438330548652
#
# 127
# Working on DUSP1 mean/freq regression...
# Intercept:	 [ 9498.69010599]
# Coefficients:	 [[ 25485.09938893]]
# R^2 score:	 0.170894531497
# DUSP1,0.170894531497
#
# 128
# Working on PTX3 mean/freq regression...
# Intercept:	 [ 1641.10174507]
# Coefficients:	 [[ 417025.88574524]]
# R^2 score:	 0.399894959793
# PTX3,0.399894959793
#
# 129
# Working on BST2 mean/freq regression...
# Intercept:	 [ 4386.93341221]
# Coefficients:	 [[ 43177.78856506]]
# R^2 score:	 0.279724889635
# BST2,0.279724889635
#
# 130
# Working on RAB32 mean/freq regression...
# Intercept:	 [ 16082.8706166]
# Coefficients:	 [[ 91426.80538959]]
# R^2 score:	 0.30987571773
# RAB32,0.30987571773
#
# 131
# Working on CLEC4E mean/freq regression...
# Intercept:	 [ 25761.11946437]
# Coefficients:	 [[ 580473.31530977]]
# R^2 score:	 0.567295330821
# CLEC4E,0.567295330821
#
# 132
# Working on BLNK mean/freq regression...
# Intercept:	 [ 4971.69854204]
# Coefficients:	 [[ 104420.26137147]]
# R^2 score:	 0.4040919177
# BLNK,0.4040919177
#
# 133
# Working on SP100 mean/freq regression...
# Intercept:	 [-602.56054841]
# Coefficients:	 [[ 129474.83465339]]
# R^2 score:	 0.462398073535
# SP100,0.462398073535
#
# 134
# Working on STAT2 mean/freq regression...
# Intercept:	 [ 1435.30858112]
# Coefficients:	 [[ 22719.1547841]]
# R^2 score:	 0.589631624763
# STAT2,0.589631624763
#
# 135
# Working on CD200 mean/freq regression...
# Intercept:	 [ 488.84290525]
# Coefficients:	 [[ 203394.18378994]]
# R^2 score:	 0.437200730664
# CD200,0.437200730664
#
# 136
# Working on PARP9 mean/freq regression...
# Intercept:	 [ 1012.15844516]
# Coefficients:	 [[ 18985.07141462]]
# R^2 score:	 0.637236600415
# PARP9,0.637236600415
#
# 137
# Working on PRDX1 mean/freq regression...
# Intercept:	 [ 26393589.3756962]
# Coefficients:	 [[ 5666371.20519783]]
# R^2 score:	 0.0221248289156
# PRDX1,0.0221248289156
#
# 138
# Working on MMP13 mean/freq regression...
# Intercept:	 [ 8888.95688527]
# Coefficients:	 [[ 187433.61728937]]
# R^2 score:	 0.114984011281
# MMP13,0.114984011281
#
# 139
# Working on CD274 mean/freq regression...
# Intercept:	 [-478.862884]
# Coefficients:	 [[ 75381.99061222]]
# R^2 score:	 0.625190666569
# CD274,0.625190666569
#
# 140
# Working on AI607873 mean/freq regression...
# Intercept:	 [ 12290.67750724]
# Coefficients:	 [[ 149167.55959904]]
# R^2 score:	 0.337601501792
# AI607873,0.337601501792
#
# 141
# Working on PMP22 mean/freq regression...
# Intercept:	 [ 23071.75721875]
# Coefficients:	 [[ 135133.15002391]]
# R^2 score:	 0.216000753261
# PMP22,0.216000753261
#
# 142
# Working on CD47 mean/freq regression...
# Intercept:	 [ 66600.02706388]
# Coefficients:	 [[-14637.55142845]]
# R^2 score:	 0.0220260279936
# CD47,0.0220260279936
#
# 143
# Working on ZBP1 mean/freq regression...
# Intercept:	 [ 4823.39510743]
# Coefficients:	 [[ 118303.86946601]]
# R^2 score:	 0.545290069071
# ZBP1,0.545290069071
#
# 144
# Working on PHF11 mean/freq regression...
# Intercept:	 [-5297.99463743]
# Coefficients:	 [[ 129651.61058608]]
# R^2 score:	 0.882692473688
# PHF11,0.882692473688
#
# 145
# Working on TOR3A mean/freq regression...
# Intercept:	 [-283.98778961]
# Coefficients:	 [[ 26234.97036302]]
# R^2 score:	 0.688696933848
# TOR3A,0.688696933848
#
# 146
# Working on IFI35 mean/freq regression...
# Intercept:	 [ 2996.02338975]
# Coefficients:	 [[ 49750.77173051]]
# R^2 score:	 0.66724263998
# IFI35,0.66724263998
#
# 147
# Working on LCP2 mean/freq regression...
# Intercept:	 [ 6721.38414611]
# Coefficients:	 [[ 6067.56365693]]
# R^2 score:	 0.0474609722134
# LCP2,0.0474609722134
#
# 148
# Working on SBDS mean/freq regression...
# Intercept:	 [ 3930.84676748]
# Coefficients:	 [[ 96874.7411798]]
# R^2 score:	 0.562973251198
# SBDS,0.562973251198
#
# 149
# Working on IFITM3 mean/freq regression...
# Intercept:	 [ 181511.23691216]
# Coefficients:	 [[ 1123695.25390012]]
# R^2 score:	 0.618340819997
# IFITM3,0.618340819997
#
# 150
# Working on DTX3L mean/freq regression...
# Intercept:	 [ 1867.38535355]
# Coefficients:	 [[ 2525.87076232]]
# R^2 score:	 0.194126208297
# DTX3L,0.194126208297
#
# 151
# Working on IL6 mean/freq regression...
# Intercept:	 [ 71840.01391894]
# Coefficients:	 [[ 2268152.39478689]]
# R^2 score:	 0.758557769574
# IL6,0.758557769574
#
# 152
# Working on FPR1 mean/freq regression...
# Intercept:	 [ 1029.21851137]
# Coefficients:	 [[ 414474.66340512]]
# R^2 score:	 0.765121433535
# FPR1,0.765121433535
#
# 153
# Working on AY096003 mean/freq regression...
# Intercept:	 [ 6347.68818416]
# Coefficients:	 [[ 123231.36154311]]
# R^2 score:	 0.426245104794
# AY096003,0.426245104794
#
# 154
# Working on SAA3 mean/freq regression...
# Intercept:	 [-86736.68865819]
# Coefficients:	 [[ 5386141.80776558]]
# R^2 score:	 0.20766337614
# SAA3,0.20766337614
#
# 155
# Working on FOS mean/freq regression...
# Intercept:	 [ 7259.43959051]
# Coefficients:	 [[ 36561.18031549]]
# R^2 score:	 0.0216849456307
# FOS,0.0216849456307
#
# 156
# Working on ZUFSP mean/freq regression...
# Intercept:	 [ 1010.51922988]
# Coefficients:	 [[ 46479.20709228]]
# R^2 score:	 0.464579028459
# ZUFSP,0.464579028459
#
# 157
# Working on EPSTI1 mean/freq regression...
# Intercept:	 [ 14835.72327906]
# Coefficients:	 [[-14911.12633121]]
# R^2 score:	 0.024466394198
# EPSTI1,0.024466394198
#
# 158
# Working on PDZK1IP1 mean/freq regression...
# Intercept:	 [ 9513.11367424]
# Coefficients:	 [[ 90513.8552035]]
# R^2 score:	 0.149017904755
# PDZK1IP1,0.149017904755
#
# 159
# Working on MCA32 mean/freq regression...
# Intercept:	 [ 26685.35175755]
# Coefficients:	 [[ 101612.15966299]]
# R^2 score:	 0.0755314076142
# MCA32,0.0755314076142
#
# 160
# Working on NFKBIA mean/freq regression...
# Intercept:	 [-13560.70072523]
# Coefficients:	 [[ 461143.05555995]]
# R^2 score:	 0.618927763909
# NFKBIA,0.618927763909
#
# 161
# Working on H2-T10 mean/freq regression...
# Intercept:	 [ 6719.6327314]
# Coefficients:	 [[ 123046.21050658]]
# R^2 score:	 0.433775626501
# H2-T10,0.433775626501
#
# 162
# Working on IFNB1 mean/freq regression...
# Intercept:	 [ 9841.67370133]
# Coefficients:	 [[ 167592.73926572]]
# R^2 score:	 0.0659373997733
# IFNB1,0.0659373997733
#
# 163
# Working on IFIH1 mean/freq regression...
# Intercept:	 [ 8311.74029826]
# Coefficients:	 [[ 31143.53222111]]
# R^2 score:	 0.712348989705
# IFIH1,0.712348989705
#
# 164
# Working on AK052414 mean/freq regression...
# Intercept:	 [ 4314.34693002]
# Coefficients:	 [[ 50797.56364216]]
# R^2 score:	 0.230581445883
# AK052414,0.230581445883
#
# 165
# Working on MT2 mean/freq regression...
# Intercept:	 [ 6177.85801292]
# Coefficients:	 [[ 187866.42442329]]
# R^2 score:	 0.530284187721
# MT2,0.530284187721
#
# 166
# Working on CLIC4 mean/freq regression...
# Intercept:	 [ 13436.76929967]
# Coefficients:	 [[ 20637.02574321]]
# R^2 score:	 0.299871111485
# CLIC4,0.299871111485
#
# 167
# Working on ARF4 mean/freq regression...
# Intercept:	 [ 64690.42778904]
# Coefficients:	 [[-4484.95681488]]
# R^2 score:	 0.0017238338265
# ARF4,0.0017238338265
#
# 168
# Working on ETV3 mean/freq regression...
# Intercept:	 [ 19802.10515751]
# Coefficients:	 [[ 1664.09327245]]
# R^2 score:	 0.000208774137152
# ETV3,0.000208774137152
#
# 169
# Working on SERPINB6B mean/freq regression...
# Intercept:	 [ 9712.32103459]
# Coefficients:	 [[ 495900.22939665]]
# R^2 score:	 0.393206584666
# SERPINB6B,0.393206584666
#
# 170
# Working on RNASET2B mean/freq regression...
# Intercept:	 [ 156209.38657423]
# Coefficients:	 [[-186140.61222598]]
# R^2 score:	 0.256232716989
# RNASET2B,0.256232716989
#
# 171
# Working on KTELC1 mean/freq regression...
# Intercept:	 [ 4774.8550518]
# Coefficients:	 [[ 81872.49566206]]
# R^2 score:	 0.38467417128
# KTELC1,0.38467417128
#
# 172
# Working on IL7R mean/freq regression...
# Intercept:	 [ 16697.38165741]
# Coefficients:	 [[ 11875.52996073]]
# R^2 score:	 0.0297987489421
# IL7R,0.0297987489421
#
# 173
# Working on LAP3 mean/freq regression...
# Intercept:	 [ 1975.00442098]
# Coefficients:	 [[ 15800.74512443]]
# R^2 score:	 0.223305289647
# LAP3,0.223305289647
#
# 174
# Working on FPR2 mean/freq regression...
# Intercept:	 [ 16039.07607754]
# Coefficients:	 [[ 219566.05695215]]
# R^2 score:	 0.571507248869
# FPR2,0.571507248869
#
# 175
# Working on TNIP3 mean/freq regression...
# Intercept:	 [ 19605.4537239]
# Coefficients:	 [[ 54296.43354375]]
# R^2 score:	 0.153066609109
# TNIP3,0.153066609109
# 176
# Working on NCOA7 mean/freq regression...
# Intercept:	 [ 16199.43700957]
# Coefficients:	 [[-9499.95946084]]
# R^2 score:	 0.00485632483774
# NCOA7,0.00485632483774
#
# 177
# Working on TNFAIP3 mean/freq regression...
# Intercept:	 [ 6563.99153325]
# Coefficients:	 [[ 14062.29571421]]
# R^2 score:	 0.301631253618
# TNFAIP3,0.301631253618
#
# 178
# Working on ELL2 mean/freq regression...
# Intercept:	 [ 4032.21800757]
# Coefficients:	 [[ 7429.64422948]]
# R^2 score:	 0.0576617047758
# ELL2,0.0576617047758
#
# 179
# Working on PTTG1 mean/freq regression...
# Intercept:	 [-3592.83771355]
# Coefficients:	 [[ 78740.08748452]]
# R^2 score:	 0.737777229626
# PTTG1,0.737777229626
#
# 180
# Working on MX1 mean/freq regression...
# Intercept:	 [ 12652.0241511]
# Coefficients:	 [[ 709352.1829531]]
# R^2 score:	 0.69287467836
# MX1,0.69287467836
#
# 181
# Working on RILPL2 mean/freq regression...
# Intercept:	 [ 15656.54000536]
# Coefficients:	 [[ 68406.58967429]]
# R^2 score:	 0.251479188403
# RILPL2,0.251479188403
#
# 182
# Working on CCL5 mean/freq regression...
# Intercept:	 [ 36927833.51990296]
# Coefficients:	 [[ 87543112.05881518]]
# R^2 score:	 0.690213769171
# CCL5,0.690213769171
#
# 183
# Working on CAR2 mean/freq regression...
# Intercept:	 [ 2767.92747886]
# Coefficients:	 [[ 327656.25173551]]
# R^2 score:	 0.22031501775
# CAR2,0.22031501775
#
# 184
# Working on TNF mean/freq regression...
# Intercept:	 [ 72746.16754499]
# Coefficients:	 [[ 977558.25887731]]
# R^2 score:	 0.649508260899
# TNF,0.649508260899
#
# 185
# Working on SWAP70 mean/freq regression...
# Intercept:	 [ 5068.76227478]
# Coefficients:	 [[ 26767.76029807]]
# R^2 score:	 0.1671745222
# SWAP70,0.1671745222
#
# 186
# Working on IRF8 mean/freq regression...
# Intercept:	 [ 7164.63781011]
# Coefficients:	 [[ 84443.32493421]]
# R^2 score:	 0.282974164342
# IRF8,0.282974164342
#
# 187
# Working on TRAF1 mean/freq regression...
# Intercept:	 [ 17820.931722]
# Coefficients:	 [[ 40822.144805]]
# R^2 score:	 0.0835320851163
# TRAF1,0.0835320851163
#
# 188
# Working on PPP1CB mean/freq regression...
# Intercept:	 [ 12882.6415485]
# Coefficients:	 [[-9095.24048378]]
# R^2 score:	 0.0477330099047
# PPP1CB,0.0477330099047
#
# 189
# Working on SERPINB9 mean/freq regression...
# Intercept:	 [ 17763.19790021]
# Coefficients:	 [[ 360277.07794329]]
# R^2 score:	 0.200026195248
# SERPINB9,0.200026195248
#
# 190
# Working on RBM7 mean/freq regression...
# Intercept:	 [ 32985.51905204]
# Coefficients:	 [[ 554.4837319]]
# R^2 score:	 1.76149889827e-05
# RBM7,1.76149889827e-05
#
# 191
# Working on 9430076C15RIK mean/freq regression...
# Intercept:	 [ 3772.0896318]
# Coefficients:	 [[ 28493.98350693]]
# R^2 score:	 0.260809316716
# 9430076C15RIK,0.260809316716
#
# 192
# Working on H2-Q7 mean/freq regression...
# Intercept:	 [ 16767.48147661]
# Coefficients:	 [[ 118971.63248611]]
# R^2 score:	 0.276024112682
# H2-Q7,0.276024112682
#
# 193
# Working on MALT1 mean/freq regression...
# Intercept:	 [ 19323.6634157]
# Coefficients:	 [[ 19969.44149366]]
# R^2 score:	 0.098842309578
# MALT1,0.098842309578
#
# 194
# Working on AK217941 mean/freq regression...
# Intercept:	 [ 59589.08788664]
# Coefficients:	 [[ 67413.78499694]]
# R^2 score:	 0.0133866865312
# AK217941,0.0133866865312
#
# 195
# Working on KTN1 mean/freq regression...
# Intercept:	 [ 3548.76788231]
# Coefficients:	 [[ 16978.42146319]]
# R^2 score:	 0.14328190229
# KTN1,0.14328190229
#
# 196
# Working on HSPA5 mean/freq regression...
# Intercept:	 [ 89634.37467614]
# Coefficients:	 [[ 35231.18541534]]
# R^2 score:	 0.0433177781765
# HSPA5,0.0433177781765
#
# 197
# Working on MYD88 mean/freq regression...
# Intercept:	 [ 9705.24995]
# Coefficients:	 [[ 27204.76767558]]
# R^2 score:	 0.0861463351947
# MYD88,0.0861463351947
#
# 198
# Working on TAPBP mean/freq regression...
# Intercept:	 [ 22606.85791293]
# Coefficients:	 [[ 14126.24988478]]
# R^2 score:	 0.105000204043
# TAPBP,0.105000204043
#
# 199
# Working on MKIAA1673 mean/freq regression...
# Intercept:	 [ 2242.12399551]
# Coefficients:	 [[ 15341.80810045]]
# R^2 score:	 0.314526948347
# MKIAA1673,0.314526948347
#
# 200
# Working on IFRD1 mean/freq regression...
# Intercept:	 [ 16533.74473707]
# Coefficients:	 [[ 28222.3648713]]
# R^2 score:	 0.0660786879226
# IFRD1,0.0660786879226
#
# 201
# Working on CASP1 mean/freq regression...
# Intercept:	 [ 19666.5468678]
# Coefficients:	 [[ 53158.37394815]]
# R^2 score:	 0.0756922477281
# CASP1,0.0756922477281
#
# 202
# Working on IFI203 mean/freq regression...
# Intercept:	 [ 5201.60140022]
# Coefficients:	 [[ 33251.21946122]]
# R^2 score:	 0.500836970996
# IFI203,0.500836970996
#
# 203
# Working on IRF1 mean/freq regression...
# Intercept:	 [ 13212.37411945]
# Coefficients:	 [[ 104847.76409454]]
# R^2 score:	 0.378890915219
# IRF1,0.378890915219
#
# 204
# Working on TNFRSF1B mean/freq regression...
# Intercept:	 [ 10510.26256175]
# Coefficients:	 [[ 29682.62366987]]
# R^2 score:	 0.251364162405
# TNFRSF1B,0.251364162405
#
# 205
# Working on A130040M12RIK mean/freq regression...
# Intercept:	 [ 14985.33718407]
# Coefficients:	 [[ 37605.77011669]]
# R^2 score:	 0.302243742732
# A130040M12RIK,0.302243742732
#
# 206
# Working on PNP mean/freq regression...
# Intercept:	 [ 10557.01874955]
# Coefficients:	 [[ 55726.84737272]]
# R^2 score:	 0.425384277206
# PNP,0.425384277206
#
# 207
# Working on SP140 mean/freq regression...
# Intercept:	 [ 3230.92990001]
# Coefficients:	 [[ 61483.75921237]]
# R^2 score:	 0.497276225144
# SP140,0.497276225144
#
# 208
# Working on BHLHE40 mean/freq regression...
# Intercept:	 [ 38470.19402564]
# Coefficients:	 [[ 3326.42858717]]
# R^2 score:	 0.00172640180022
# BHLHE40,0.00172640180022
#
# 209
# Working on CXCL16 mean/freq regression...
# Intercept:	 [ 124254.77518344]
# Coefficients:	 [[ 70643.59027013]]
# R^2 score:	 0.0616379449383
# CXCL16,0.0616379449383
#
# 210
# Working on MAP2K1 mean/freq regression...
# Intercept:	 [ 6520.51111363]
# Coefficients:	 [[ 7275.404562]]
# R^2 score:	 0.045057507551
# MAP2K1,0.045057507551
#
# 211
# Working on RASGEF1B mean/freq regression...
# Intercept:	 [ 5951.06613024]
# Coefficients:	 [[ 33491.64583519]]
# R^2 score:	 0.178245116373
# RASGEF1B,0.178245116373
#
# 212
# Working on CDKN1A mean/freq regression...
# Intercept:	 [ 87150.37750488]
# Coefficients:	 [[ 70692.06308679]]
# R^2 score:	 0.0923713868325
# CDKN1A,0.0923713868325
#
# 213
# Working on SGK1 mean/freq regression...
# Intercept:	 [ 46009.53209942]
# Coefficients:	 [[ 171602.2967972]]
# R^2 score:	 0.488823525273
# SGK1,0.488823525273
#
# 214
# Working on OAS1A mean/freq regression...
# Intercept:	 [ 11992.62563701]
# Coefficients:	 [[ 37502.90144976]]
# R^2 score:	 0.278173046416
# OAS1A,0.278173046416
#
# 215
# Working on SQSTM1 mean/freq regression...
# Intercept:	 [ 264290.87484403]
# Coefficients:	 [[ 230648.86662036]]
# R^2 score:	 0.167659875162
# SQSTM1,0.167659875162
#
# 216
# Working on RNF19B mean/freq regression...
# Intercept:	 [ 6148.56800721]
# Coefficients:	 [[ 17628.43928637]]
# R^2 score:	 0.104101165285
# RNF19B,0.104101165285
#
# 217
# Working on SLC7A11 mean/freq regression...
# Intercept:	 [ 55088.08145519]
# Coefficients:	 [[-7987.5826903]]
# R^2 score:	 0.0347185054563
# SLC7A11,0.0347185054563
#
# 218
# Working on CD83 mean/freq regression...
# Intercept:	 [ 32501.03666678]
# Coefficients:	 [[ 356155.66891987]]
# R^2 score:	 0.236746759072
# CD83,0.236746759072
#
# 219
# Working on SAMSN1 mean/freq regression...
# Intercept:	 [ 36278.19923605]
# Coefficients:	 [[ 311451.50355151]]
# R^2 score:	 0.30798688425
# SAMSN1,0.30798688425
#
# 220
# Working on MED21 mean/freq regression...
# Intercept:	 [ 21886.3198999]
# Coefficients:	 [[ 2793.54585053]]
# R^2 score:	 0.000133850603205
# MED21,0.000133850603205
#
# 221
# Working on HK2 mean/freq regression...
# Intercept:	 [ 15823.46252617]
# Coefficients:	 [[-522.71054106]]
# R^2 score:	 0.000119561080499
# HK2,0.000119561080499
#
# 222
# Working on PARP14 mean/freq regression...
# Intercept:	 [ 5538.55025977]
# Coefficients:	 [[ 27064.27318165]]
# R^2 score:	 0.564241141148
# PARP14,0.564241141148
#
# 223
# Working on GM6377 mean/freq regression...
# Intercept:	 [ 2008.93245442]
# Coefficients:	 [[ 13129.3700571]]
# R^2 score:	 0.166404542448
# GM6377,0.166404542448
#
# 224
# Working on CCL22 mean/freq regression...
# Intercept:	 [ 7127243.73872014]
# Coefficients:	 [[ 27739159.82621416]]
# R^2 score:	 0.255394001004
# CCL22,0.255394001004
#
# 225
# Working on BTG1 mean/freq regression...
# Intercept:	 [ 1601542.217397]
# Coefficients:	 [[-67192.04774593]]
# R^2 score:	 0.0268725934065
# BTG1,0.0268725934065
#
# 226
# Working on PDPN mean/freq regression...
# Intercept:	 [ 47855.28272521]
# Coefficients:	 [[ 68840.2122335]]
# R^2 score:	 0.0794926207876
# PDPN,0.0794926207876
#
# 227
# Working on SOD2 mean/freq regression...
# Intercept:	 [ 18869.73918086]
# Coefficients:	 [[ 15559.69960512]]
# R^2 score:	 0.202840631162
# SOD2,0.202840631162
#
# 228
# Working on MNDAL mean/freq regression...
# Intercept:	 [ 28928.64246432]
# Coefficients:	 [[ 90843.78276492]]
# R^2 score:	 0.417581303025
# MNDAL,0.417581303025
#
# 229
# Working on CXCL2 mean/freq regression...
# Intercept:	 [ 524885.14922913]
# Coefficients:	 [[ 832745.87618015]]
# R^2 score:	 0.217584334359
# CXCL2,0.217584334359
#
# 230
# Working on PELI1 mean/freq regression...
# Intercept:	 [ 2247.61556659]
# Coefficients:	 [[ 10349.98492087]]
# R^2 score:	 0.372350647461
# PELI1,0.372350647461
#
# 231
# Working on NCK1 mean/freq regression...
# Intercept:	 [ 14634.46369515]
# Coefficients:	 [[ 24103.29009301]]
# R^2 score:	 0.0452012392711
# NCK1,0.0452012392711
#
# 232
# Working on GADD45B mean/freq regression...
# Intercept:	 [ 6325.04287241]
# Coefficients:	 [[ 35070.38001676]]
# R^2 score:	 0.49800894159
# GADD45B,0.49800894159
#
# 233
# Working on PSME2 mean/freq regression...
# Intercept:	 [ 646825.21095125]
# Coefficients:	 [[ 77600.85387664]]
# R^2 score:	 0.0126765793232
# PSME2,0.0126765793232
#
# 234
# Working on CD14 mean/freq regression...
# Intercept:	 [ 225976.55154934]
# Coefficients:	 [[ 773172.18766176]]
# R^2 score:	 0.13270920219
# CD14,0.13270920219
#
# 235
# Working on LGALS3BP mean/freq regression...
# Intercept:	 [ 12089.07310211]
# Coefficients:	 [[ 63120.35117496]]
# R^2 score:	 0.323456267916
# LGALS3BP,0.323456267916
#
# 236
# Working on CLEC4D mean/freq regression...
# Intercept:	 [ 135083.89534719]
# Coefficients:	 [[-22092.51351566]]
# R^2 score:	 0.00249413683154
# CLEC4D,0.00249413683154
#
# 237
# Working on SNX10 mean/freq regression...
# Intercept:	 [ 51453.32456336]
# Coefficients:	 [[-15923.94053812]]
# R^2 score:	 0.0460624768918
# SNX10,0.0460624768918
#
# 238
# Working on BTG2 mean/freq regression...
# Intercept:	 [ 11351.8422234]
# Coefficients:	 [[ 8815.45038205]]
# R^2 score:	 0.018769405764
# BTG2,0.018769405764
#
# 239
# Working on NFKB1 mean/freq regression...
# Intercept:	 [ 22280.90074278]
# Coefficients:	 [[ 24459.60790747]]
# R^2 score:	 0.122177034873
# NFKB1,0.122177034873
#
# 240
# Working on PSMB9 mean/freq regression...
# Intercept:	 [ 33640.9897822]
# Coefficients:	 [[ 33112.90338063]]
# R^2 score:	 0.0588164593639
# PSMB9,0.0588164593639
#
# 241
# Working on RNASET2A mean/freq regression...
# Intercept:	 [ 22974.41534732]
# Coefficients:	 [[ 69358.75856839]]
# R^2 score:	 0.215078797112
# RNASET2A,0.215078797112
#
# 242
# Working on P2RY14 mean/freq regression...
# Intercept:	 [ 41156.67737657]
# Coefficients:	 [[ 17026.90716177]]
# R^2 score:	 0.00810548093056
# P2RY14,0.00810548093056
#
# 243
# Working on RNF114 mean/freq regression...
# Intercept:	 [ 15884.89241128]
# Coefficients:	 [[ 86429.33539637]]
# R^2 score:	 0.302758004871
# RNF114,0.302758004871
#
# 244
# Working on TMEM219 mean/freq regression...
# Intercept:	 [ 46037.70180585]
# Coefficients:	 [[-29593.62353231]]
# R^2 score:	 0.0450740495052
# TMEM219,0.0450740495052
#
# 245
# Working on LY6C2 mean/freq regression...
# Intercept:	 [-3819.8891047]
# Coefficients:	 [[ 620397.92458465]]
# R^2 score:	 0.284540393043
# LY6C2,0.284540393043
#
# 246
# Working on IL12B mean/freq regression...
# Intercept:	 [-238261.97997872]
# Coefficients:	 [[ 11175100.84115813]]
# R^2 score:	 0.767746002789
# IL12B,0.767746002789
#
# 247
# Working on F10 mean/freq regression...
# Intercept:	 [ 67482.74488572]
# Coefficients:	 [[ 26293.79698137]]
# R^2 score:	 0.00665572649941
# F10,0.00665572649941
#
# 248
# Working on CASP7 mean/freq regression...
# Intercept:	 [ 33376.92842838]
# Coefficients:	 [[-77728.48071752]]
# R^2 score:	 0.191094118954
# CASP7,0.191094118954
#
# 249
# Working on MDM2 mean/freq regression...
# Intercept:	 [ 23742.02864102]
# Coefficients:	 [[ 29854.65186132]]
# R^2 score:	 0.0452814900688
# MDM2,0.0452814900688
#
# 250
# Working on KLF6 mean/freq regression...
# Intercept:	 [ 43688.31338992]
# Coefficients:	 [[-7001.0873994]]
# R^2 score:	 0.0157641562388
# KLF6,0.0157641562388
#
# 251
# Working on NUPR1 mean/freq regression...
# Intercept:	 [ 64145.61890718]
# Coefficients:	 [[ 614602.8730439]]
# R^2 score:	 0.217758386979
# NUPR1,0.217758386979
#
# 252
# Working on CASP11 mean/freq regression...
# Intercept:	 [ 11803.51083034]
# Coefficients:	 [[ 119039.32190139]]
# R^2 score:	 0.394202420816
# CASP11,0.394202420816
#
# 253
# Working on 2810474O19RIK mean/freq regression...
# Intercept:	 [ 7218.7497913]
# Coefficients:	 [[ 8037.04626025]]
# R^2 score:	 0.11351092078
# 2810474O19RIK,0.11351092078
#
# 254
# Working on HCK mean/freq regression...
# Intercept:	 [ 6296.63945242]
# Coefficients:	 [[ 19338.61339231]]
# R^2 score:	 0.14352361987
# HCK,0.14352361987
#
# 255
# Working on RAB8B mean/freq regression...
# Intercept:	 [ 56832.49240641]
# Coefficients:	 [[ 903.21266284]]
# R^2 score:	 0.000195957040126
# RAB8B,0.000195957040126
#
# 256
# Working on BCL2A1D mean/freq regression...
# Intercept:	 [ 1062520.65758878]
# Coefficients:	 [[-2865.09632396]]
# R^2 score:	 3.58402556724e-05
# BCL2A1D,3.58402556724e-05
#
# 257
# Working on STXBP3A mean/freq regression...
# Intercept:	 [ 15834.37361369]
# Coefficients:	 [[ 13987.30459803]]
# R^2 score:	 0.0407275200551
# STXBP3A,0.0407275200551
#
# 258
# Working on PFKP mean/freq regression...
# Intercept:	 [ 9468.47784447]
# Coefficients:	 [[ 15131.41155571]]
# R^2 score:	 0.173614618645
# PFKP,0.173614618645
#
# 259
# Working on TANK mean/freq regression...
# Intercept:	 [ 70978.27504228]
# Coefficients:	 [[ 38935.42483906]]
# R^2 score:	 0.0413808440714
# TANK,0.0413808440714
#
# 260
# Working on TGIF1 mean/freq regression...
# Intercept:	 [ 30087.9573808]
# Coefficients:	 [[ 11178.54780785]]
# R^2 score:	 0.00777155321812
# TGIF1,0.00777155321812
#
# 261
# Working on PPP1R15A mean/freq regression...
# Intercept:	 [ 17936.2372325]
# Coefficients:	 [[ 22902.12502994]]
# R^2 score:	 0.0356531013421
# PPP1R15A,0.0356531013421
#
# 262
# Working on SEPW1 mean/freq regression...
# Intercept:	 [ 95535.67408109]
# Coefficients:	 [[-31983.41506989]]
# R^2 score:	 0.122805577227
# SEPW1,0.122805577227
#
# 263
# Working on PLAUR mean/freq regression...
# Intercept:	 [ 109561.91066159]
# Coefficients:	 [[ 81752.8313402]]
# R^2 score:	 0.0605398744363
# PLAUR,0.0605398744363
#
# 264
# Working on H2-M2 mean/freq regression...
# Intercept:	 [ 1230171.14654423]
# Coefficients:	 [[ 1526695.18121032]]
# R^2 score:	 0.150860425327
# H2-M2,0.150860425327
#
# 265
# Working on BATF mean/freq regression...
# Intercept:	 [ 2337.99604517]
# Coefficients:	 [[ 105047.73836356]]
# R^2 score:	 0.435282399183
# BATF,0.435282399183
#
# 266
# Working on NUP62-IL4I1 mean/freq regression...
# Intercept:	 [ 28506.5175604]
# Coefficients:	 [[ 202945.17910617]]
# R^2 score:	 0.407279282533
# NUP62-IL4I1,0.407279282533
#
# 267
# Working on TNFAIP2 mean/freq regression...
# Intercept:	 [ 94332.99518259]
# Coefficients:	 [[ 30697.55181208]]
# R^2 score:	 0.033307922475
# TNFAIP2,0.033307922475
#
# 268
# Working on FNDC3A mean/freq regression...
# Intercept:	 [ 12512.49611541]
# Coefficients:	 [[-2997.01835062]]
# R^2 score:	 0.00498406511331
# FNDC3A,0.00498406511331
#
# 269
# Working on TREX1 mean/freq regression...
# Intercept:	 [ 49028.60969902]
# Coefficients:	 [[ 171238.21898045]]
# R^2 score:	 0.608697017846
# TREX1,0.608697017846
#
# 270
# Working on RAB9 mean/freq regression...
# Intercept:	 [ 21733.85268001]
# Coefficients:	 [[-6501.59720017]]
# R^2 score:	 0.0053693262789
# RAB9,0.0053693262789
#
# 271
# Working on BCL2A1A mean/freq regression...
# Intercept:	 [ 525949.33062631]
# Coefficients:	 [[ 55350.99120594]]
# R^2 score:	 0.0219279892077
# BCL2A1A,0.0219279892077
#
# 272
# Working on PDE4B mean/freq regression...
# Intercept:	 [ 9710.13102846]
# Coefficients:	 [[ 796.44216811]]
# R^2 score:	 0.000561754760612
# PDE4B,0.000561754760612
#
# 273
# Working on PIK3R5 mean/freq regression...
# Intercept:	 [ 16731.86622014]
# Coefficients:	 [[-8888.87266832]]
# R^2 score:	 0.0946732522324
# PIK3R5,0.0946732522324
#
# 274
# Working on RND3 mean/freq regression...
# Intercept:	 [ 3233.39835024]
# Coefficients:	 [[ 8438.78111966]]
# R^2 score:	 0.09550121364
# RND3,0.09550121364
#
# 275
# Working on CD44 mean/freq regression...
# Intercept:	 [ 55844.99394943]
# Coefficients:	 [[ 4902.77357819]]
# R^2 score:	 0.00638638216165
# CD44,0.00638638216165
#
# 276
# Working on AK172683 mean/freq regression...
# Intercept:	 [ 1258.18005621]
# Coefficients:	 [[ 7390.76727645]]
# R^2 score:	 0.396899202123
# AK172683,0.396899202123
#
# 277
# Working on ARL5C mean/freq regression...
# Intercept:	 [ 21983.48089467]
# Coefficients:	 [[-4661.83387821]]
# R^2 score:	 0.00296980901753
# ARL5C,0.00296980901753
#
# 278
# Working on IER3 mean/freq regression...
# Intercept:	 [ 12989.80396856]
# Coefficients:	 [[ 35671.66042154]]
# R^2 score:	 0.0929024188036
# IER3,0.0929024188036
#
# 279
# Working on GTF2B mean/freq regression...
# Intercept:	 [ 33307.51053772]
# Coefficients:	 [[ 18741.17398336]]
# R^2 score:	 0.0371799317861
# GTF2B,0.0371799317861
#
# 280
# Working on ANXA7 mean/freq regression...
# Intercept:	 [ 21894.91802384]
# Coefficients:	 [[-9165.51245408]]
# R^2 score:	 0.0401420453319
# ANXA7,0.0401420453319
#
# 281
# Working on TXNRD1 mean/freq regression...
# Intercept:	 [ 12932.30329989]
# Coefficients:	 [[ 3155.34892342]]
# R^2 score:	 0.0412530789927
# TXNRD1,0.0412530789927
#
# 282
# Working on HIF1A mean/freq regression...
# Intercept:	 [ 9437.70178032]
# Coefficients:	 [[-2610.87435567]]
# R^2 score:	 0.0510267949686
# HIF1A,0.0510267949686
#
# 283
# Working on MARCKSL1 mean/freq regression...
# Intercept:	 [ 23428.5647113]
# Coefficients:	 [[ 76951.46872679]]
# R^2 score:	 0.241852000877
# MARCKSL1,0.241852000877
#
# 284
# Working on PLK2 mean/freq regression...
# Intercept:	 [ 20907.98311256]
# Coefficients:	 [[ 28248.19367058]]
# R^2 score:	 0.252859405955
# PLK2,0.252859405955
#
# 285
# Working on CFLAR mean/freq regression...
# Intercept:	 [ 18386.49669073]
# Coefficients:	 [[ 14755.53820322]]
# R^2 score:	 0.215455494921
# CFLAR,0.215455494921
#
# 286
# Working on G530011O06RIK mean/freq regression...
# Intercept:	 [ 9024.89890474]
# Coefficients:	 [[ 53655.68789661]]
# R^2 score:	 0.134797757519
# G530011O06RIK,0.134797757519
#
# 287
# Working on B3GNT2 mean/freq regression...
# Intercept:	 [ 15339.55332531]
# Coefficients:	 [[-10550.49922264]]
# R^2 score:	 0.039013671085
# B3GNT2,0.039013671085
#
# 288
# Working on MTPN mean/freq regression...
# Intercept:	 [ 34050.86844246]
# Coefficients:	 [[ 10294.52610966]]
# R^2 score:	 0.0277909504171
# MTPN,0.0277909504171
#
# 289
# Working on PSMB10 mean/freq regression...
# Intercept:	 [ 42071.5893587]
# Coefficients:	 [[-15402.52843347]]
# R^2 score:	 0.0349664322996
# PSMB10,0.0349664322996
#
# 290
# Working on PTPRE mean/freq regression...
# Intercept:	 [ 12799.88495839]
# Coefficients:	 [[-9861.36868588]]
# R^2 score:	 0.114983203174
# PTPRE,0.114983203174
#
# 291
# Working on MKIAA0694 mean/freq regression...
# Intercept:	 [ 17799.65766923]
# Coefficients:	 [[-2358.75705734]]
# R^2 score:	 0.00183122238143
# MKIAA0694,0.00183122238143
#
# 292
# Working on OLR1 mean/freq regression...
# Intercept:	 [ 1513.35382324]
# Coefficients:	 [[ 44302.15999695]]
# R^2 score:	 0.359165904963
# OLR1,0.359165904963
#
# 293
# Working on CCNL1 mean/freq regression...
# Intercept:	 [ 22814.09553498]
# Coefficients:	 [[-4394.83318409]]
# R^2 score:	 0.00620883906373
# CCNL1,0.00620883906373
#
# 294
# Working on AA467197 mean/freq regression...
# Intercept:	 [ 876738.86194256]
# Coefficients:	 [[ 650177.19063615]]
# R^2 score:	 0.0842176693749
# AA467197,0.0842176693749
#
# 295
# Working on DNAJB6 mean/freq regression...
# Intercept:	 [ 55552.69198766]
# Coefficients:	 [[-34727.37929181]]
# R^2 score:	 0.228207253316
# DNAJB6,0.228207253316
#
# 296
# Working on EHD1 mean/freq regression...
# Intercept:	 [ 9769.37734788]
# Coefficients:	 [[ 2402.55157575]]
# R^2 score:	 0.0183140341745
# EHD1,0.0183140341745
#
# 297
# Working on H3F3B mean/freq regression...
# Intercept:	 [ 742481.17665541]
# Coefficients:	 [[-115509.62696154]]
# R^2 score:	 0.136154434882
# H3F3B,0.136154434882
#
# 298
# Working on SLC15A3 mean/freq regression...
# Intercept:	 [ 74311.43751428]
# Coefficients:	 [[-29572.42870912]]
# R^2 score:	 0.228762807539
# SLC15A3,0.228762807539
#
# 299
# Working on NFKBIB mean/freq regression...
# Intercept:	 [ 10552.15122558]
# Coefficients:	 [[ 25060.44168459]]
# R^2 score:	 0.116152487008
# NFKBIB,0.116152487008
#
# 300
# Working on JAK2 mean/freq regression...
# Intercept:	 [ 24506.9083893]
# Coefficients:	 [[-11536.19825418]]
# R^2 score:	 0.086912015572
# JAK2,0.086912015572
#
# 301
# Working on PLEK mean/freq regression...
# Intercept:	 [ 132561.83039807]
# Coefficients:	 [[ 41874.59283496]]
# R^2 score:	 0.127584813358
# PLEK,0.127584813358
#
# 302
# Working on RAP1B mean/freq regression...
# Intercept:	 [ 76960.71981371]
# Coefficients:	 [[ 2856.33288387]]
# R^2 score:	 0.00099570596692
# RAP1B,0.00099570596692
#
# 303
# Working on SLC3A2 mean/freq regression...
# Intercept:	 [ 60438.74040559]
# Coefficients:	 [[-16434.31038906]]
# R^2 score:	 0.0632617387615
# SLC3A2,0.0632617387615
#
# 304
# Working on PGAP2 mean/freq regression...
# Intercept:	 [ 34537.05284981]
# Coefficients:	 [[ 7929.92152321]]
# R^2 score:	 0.00239501341736
# PGAP2,0.00239501341736
#
# 305
# Working on ALCAM mean/freq regression...
# Intercept:	 [ 6085.58209545]
# Coefficients:	 [[ 101.95485467]]
# R^2 score:	 8.57440759002e-05
# ALCAM,8.57440759002e-05
#
# 306
# Working on UBC mean/freq regression...
# Intercept:	 [ 5499800.97365527]
# Coefficients:	 [[-484204.16262432]]
# R^2 score:	 0.00998784435814
# UBC,0.00998784435814
#
# 307
# Working on TFG mean/freq regression...
# Intercept:	 [ 19181.85223681]
# Coefficients:	 [[-6735.51703394]]
# R^2 score:	 0.0109505025427
# TFG,0.0109505025427
#
# 308
# Working on PILRA mean/freq regression...
# Intercept:	 [ 19242.99114589]
# Coefficients:	 [[ 3185.48354887]]
# R^2 score:	 0.00581283766249
# PILRA,0.00581283766249
#
# 309
# Working on PSME1 mean/freq regression...
# Intercept:	 [ 191885.95115811]
# Coefficients:	 [[-6119.313065]]
# R^2 score:	 0.00023641454823
# PSME1,0.00023641454823
#
# 310
# Working on DAB2 mean/freq regression...
# Intercept:	 [ 4951.75660135]
# Coefficients:	 [[ 15417.54170769]]
# R^2 score:	 0.365566450951
# DAB2,0.365566450951
#
# 311
# Working on AK142678 mean/freq regression...
# Intercept:	 [ 35832.4666466]
# Coefficients:	 [[-58295.27835042]]
# R^2 score:	 0.0536319973378
# AK142678,0.0536319973378
#
# 312
# Working on PNRC1 mean/freq regression...
# Intercept:	 [ 17259.92253791]
# Coefficients:	 [[-8558.30299826]]
# R^2 score:	 0.0522518164633
# PNRC1,0.0522518164633
#
# 313
# Working on SKIL mean/freq regression...
# Intercept:	 [ 8075.2296955]
# Coefficients:	 [[ 1990.65583276]]
# R^2 score:	 0.0477084097948
# SKIL,0.0477084097948
#
# 314
# Working on SAT1 mean/freq regression...
# Intercept:	 [ 1927157.80929476]
# Coefficients:	 [[-679351.81427075]]
# R^2 score:	 0.384591795427
# SAT1,0.384591795427
#
# 315
# Working on BCL2A1B mean/freq regression...
# Intercept:	 [ 2228817.88254139]
# Coefficients:	 [[-92028.34866487]]
# R^2 score:	 0.0386188935802
# BCL2A1B,0.0386188935802
#
# 316
# Working on GNA13 mean/freq regression...
# Intercept:	 [ 17439.58860956]
# Coefficients:	 [[-3890.33897263]]
# R^2 score:	 0.0290516207882
# GNA13,0.0290516207882
#
# 317
# Working on NRP2 mean/freq regression...
# Intercept:	 [ 11301.06225907]
# Coefficients:	 [[-1918.00477992]]
# R^2 score:	 0.00801443732128
# NRP2,0.00801443732128
#
# 318
# Working on NAMPT mean/freq regression...
# Intercept:	 [ 129062.31627961]
# Coefficients:	 [[-35988.75975581]]
# R^2 score:	 0.0509064595496
# NAMPT,0.0509064595496
#
# 319
# Working on ISG15 mean/freq regression...
# Intercept:	 [ 14566.27288781]
# Coefficients:	 [[ 17789.72996906]]
# R^2 score:	 0.118586835359
# ISG15,0.118586835359
#
# 320
# Working on FAM102B mean/freq regression...
# Intercept:	 [ 2986.93523251]
# Coefficients:	 [[ 11194.07132504]]
# R^2 score:	 0.250789770462
# FAM102B,0.250789770462
#
# 321
# Working on BCL2A1C mean/freq regression...
# Intercept:	 [ 9819.87863759]
# Coefficients:	 [[ 8587.08397104]]
# R^2 score:	 0.171889146103
# BCL2A1C,0.171889146103
#
# 322
# Working on BIRC6 mean/freq regression...
# Intercept:	 [ 46210.09172013]
# Coefficients:	 [[-35150.9635353]]
# R^2 score:	 0.1009950107
# BIRC6,0.1009950107
#
# 323
# Working on RGS1 mean/freq regression...
# Intercept:	 [ 651995.07162198]
# Coefficients:	 [[ 93100.69388041]]
# R^2 score:	 0.0160017668404
# RGS1,0.0160017668404
