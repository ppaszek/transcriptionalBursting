# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn import linear_model
from statsmodels.formula.api import ols

induced_data = pd.read_csv('induced_genes_outliers_removed_all_zero_removed.csv')
induced_data = induced_data.iloc[:,1:]

#grp1 = ['IFITM3','SRGN','IL1RN','IFI27L2A','TNF','IFI205','TARM1','TNFSF9','IRG1','GLIPR2','INHBA','BTG1','PSME2','CLEC4E','2310016C08RIK','SQSTM1','NFKBIA','USP18','EBI3','CD86','MS4A6D','NT5C3','FPR2','H3F3B','SERPINA3G','CAV1','FAS','MS4A6C','LGALS9','GM4902','CD200','IFI204','CISH','PROCR','SLAMF7','AI607873','SGK1','IL15','ACPP','CXCL16','SLFN2','H2-Q7','MT2','H2-T23','THBS1','UBE2L6','AY096003','H1F0','ATF3','TANK','TNFSF15','HSPA5','IL15RA','IRF1','MED21','IRGM1','CCRL2','ZBP1','CASP1','RAB32','SP100','IRF8','BLNK','PSMB9','PCGF5','KTELC1','RILPL2','TMEM39A','TRIM30A','TNIP3','RBM7','SLC2A6','GBP3','BIRC3','TLR2','GTF2B','CFB','SBDS','CAR13','ARF4','SEPW1','BST2','NMI','DUSP1','PYHIN1','CD47','ZFP36','CD274','SAMHD1','SWAP70','IL7R','RELA','AK042010','A130040M12RIK','D14ERTD668E','NFKBIZ','ADAP2','XAF1','PNP','ZUFSP','IFI35','ACSL1','ANXA7','SLC7A2','HERC6','TAPBP','SLFN5','SLFN8','IFIH1','FGL2','LCP2','STAT1','GBP5','TRIM30D','LAP3','STAT5A','GBP6','DDX58','CLIC4','DHX58','STAT2','TNFAIP3','TAP1','ELL2','PIK3R5','PARP9','KPNA3','HIF1A','AFTPH','DTX3L']
#grp2 = ['SDC4','CXCL1','IL1A','CXCL3','IL1B','CCL3','AW112010','CCL17','PRDX1','CCL4','H2-M2']
#with open("global_regressions/summary.csv","w") as logfile:
#    logfile.write("gene,scoreAll\n")


#glist=['CCL5','CCL17','AK217941','AK138792','PRDX1','CXCL10','APOL7C','AW112010','IL1B','CXCL1','CCL3','SDC4','H2-M2','LY6C2','CLU','IL1A','ZDHHC21','CXCL3','CCR7','CD14','CD69','BCL2A1B','IFI27L2A','SLPI','SERPINB9','IFITM3','AA467197','GLIPR2','MX1','TNF','TARM1','BCL2A1D','CLEC4D','IRG1','CD40','BCL2A1A','USP18','SAMSN1','CLEC4E','CAR4','1810029B16RIK','CD86','SQSTM1','SERPINB6B','RNASET2B','MS4A6D','NUPR1','P2RY14','2310016C08RIK','H2-Q7','FOS','GBP2','CDKN1A','NFKBIA','FPR1','EBI3','FPR2','SAMHD1','UBE2L6','IFIT2','MS4A6C','ARF4','STXBP3A','AY096003','EPSTI1','TNIP3','AI607873','SLAMF7','CD200','RAB8B','MT2','SLFN2','HSPA5','BIRC3','IRGM1','MARCKSL1','TMEM39A','ETV3','TREX1','PROCR','BLNK','RELA','RTP4','CCRL2','TRIM30A','BHLHE40','PLAUR','KYNU','TLR2','BST2','SWAP70','ZBP1','SP100','GBP3','PCGF5','KTELC1','IRF8','IGTP','SOD2','CISH','TNFSF15','MNDAL','CFB','PLEK','PNP','ZFP36','NMI','SLC2A6','H1F0','SBDS','XAF1','NFKBIZ','TRAF1','PYHIN1','MTPN','SLC7A2','APOBEC3','CD274','TAPBP','LGALS3BP','KTN1','PPP1CB','ZUFSP','PTTG1','IFIH1','GM4951','BATF','ADAP2','IFI203','IFI35','GADD45B','PELI1','STAT1','LCP2','STAT2','GBP6','KPNA3','SLFN5','GBP5','PFKP','TAP1','TOR3A','INSIG1','DAB2','AFTPH','TXNRD1']

regression_data=pd.read_csv('summary_mean_var_all_cond.csv')
glist=regression_data.iloc[:,0].tolist();

# %%
glist
# Out:
# ['CXCL1',
#  'RSAD2',
#  'OASL1',
#  'NT5C3',
#  'CCL4',
#  'EBI3',
#  'IRGM1',
#  'IFIT2',
#  'PYHIN1',
#  'CAR4',
#  'SLFN8',
#  'AW112010',
#  'U90926',
#  'IL15',
#  'GM4902',
#  'GM14446',
#  'FAM26F',
#  'D14ERTD668E',
#  'GM4951',
#  'FGL2',
#  'APOL7C',
#  'TRIM30A',
#  'CCL3',
#  'CXCL3',
#  'CFB',
#  'TMEM39A',
#  'CCND2',
#  'MS4A6C',
#  'IRG1',
#  'CCR7',
#  'USP18',
#  'IFIT3',
#  'ACPP',
#  'ACSL1',
#  'STAT5A',
#  'TNFSF9',
#  'CD40',
#  'IFI205',
#  'MS4A4C',
#  'TARM1',
#  'NUDT17',
#  'AFTPH',
#  'IRF7',
#  'TLR2',
#  'IL15RA',
#  'INHBA',
#  'IIGP1',
#  'TRIM30D',
#  'TIMP1',
#  'CCL7',
#  'SRGN',
#  'IL1A',
#  'SERPINA3G',
#  'TAP1',
#  'SLAMF7',
#  'IFIT1',
#  'CISH',
#  'FAS',
#  'CXCL10',
#  'SLFN5',
#  'SLC2A6',
#  'CMPK2',
#  'PCGF5',
#  'CAR13',
#  'GBP3',
#  'UBE2L6',
#  'MX2',
#  'ZDHHC21',
#  'AK138792',
#  'CH25H',
#  'PTGS2',
#  'SAMHD1',
#  'SDC4',
#  'ADAP2',
#  'MS4A6D',
#  'ATF3',
#  'TNFSF15',
#  'RELA',
#  'ZFP36',
#  'SLFN2',
#  'GM12250',
#  'STAT1',
#  'BIRC3',
#  '1190002H23RIK',
#  'ALDH1A2',
#  'OASL2',
#  'IL27',
#  'H1F0',
#  'CCL2',
#  'DDX58',
#  'GBP5',
#  'CAV1',
#  'NMI',
#  'CCL17',
#  'SLPI',
#  'H2-T23',
#  'NFKBIZ',
#  'DHX58',
#  'THBS1',
#  'HERC6',
#  'CD86',
#  'IGTP',
#  'FABP3',
#  'AK042010',
#  'GBP6',
#  'IL1RN',
#  'SERPINB9B',
#  'INSIG1',
#  'RTP4',
#  'IL1B',
#  'IFI204',
#  'CD69',
#  'LGALS9',
#  'IFI27L2A',
#  'IFI47',
#  'CLU',
#  '2310016C08RIK',
#  'KPNA3',
#  'GLIPR2',
#  'XAF1',
#  'SLC7A2',
#  'PROCR',
#  'PRPF38A',
#  '1810029B16RIK',
#  'CCRL2',
#  'GBP2',
#  'DUSP1',
#  'PTX3',
#  'BST2',
#  'RAB32',
#  'CLEC4E',
#  'BLNK',
#  'SP100',
#  'STAT2',
#  'CD200',
#  'PARP9',
#  'PRDX1',
#  'MMP13',
#  'CD274',
#  'AI607873',
#  'PMP22',
#  'CD47',
#  'ZBP1',
#  'PHF11',
#  'TOR3A',
#  'IFI35',
#  'LCP2',
#  'SBDS',
#  'IFITM3',
#  'DTX3L',
#  'IL6',
#  'FPR1',
#  'AY096003',
#  'SAA3',
#  'FOS',
#  'ZUFSP',
#  'EPSTI1',
#  'PDZK1IP1',
#  'MCA32',
#  'NFKBIA',
#  'H2-T10',
#  'IFNB1',
#  'IFIH1',
#  'AK052414',
#  'MT2',
#  'CLIC4',
#  'ARF4',
#  'ETV3',
#  'SERPINB6B',
#  'RNASET2B',
#  'KTELC1',
#  'IL7R',
#  'LAP3',
#  'FPR2',
#  'TNIP3',
#  'NCOA7',
#  'TNFAIP3',
#  'ELL2',
#  'PTTG1',
#  'MX1',
#  'RILPL2',
#  'CCL5',
#  'CAR2',
#  'TNF',
#  'SWAP70',
#  'IRF8',
#  'TRAF1',
#  'PPP1CB',
#  'SERPINB9',
#  'RBM7',
#  '9430076C15RIK',
#  'H2-Q7',
#  'MALT1',
#  'AK217941',
#  'KTN1',
#  'HSPA5',
#  'MYD88',
#  'TAPBP',
#  'MKIAA1673',
#  'IFRD1',
#  'CASP1',
#  'IFI203',
#  'IRF1',
#  'TNFRSF1B',
#  'A130040M12RIK',
#  'PNP',
#  'SP140',
#  'BHLHE40',
#  'CXCL16',
#  'MAP2K1',
#  'RASGEF1B',
#  'CDKN1A',
#  'SGK1',
#  'OAS1A',
#  'SQSTM1',
#  'RNF19B',
#  'SLC7A11',
#  'CD83',
#  'SAMSN1',
#  'MED21',
#  'HK2',
#  'PARP14',
#  'GM6377',
#  'CCL22',
#  'BTG1',
#  'PDPN',
#  'SOD2',
#  'MNDAL',
#  'CXCL2',
#  'PELI1',
#  'NCK1',
#  'GADD45B',
#  'PSME2',
#  'CD14',
#  'LGALS3BP',
#  'CLEC4D',
#  'SNX10',
#  'BTG2',
#  'NFKB1',
#  'PSMB9',
#  'RNASET2A',
#  'P2RY14',
#  'RNF114',
#  'TMEM219',
#  'LY6C2',
#  'IL12B',
#  'F10',
#  'CASP7',
#  'MDM2',
#  'KLF6',
#  'NUPR1',
#  'CASP11',
#  '2810474O19RIK',
#  'HCK',
#  'RAB8B',
#  'BCL2A1D',
#  'STXBP3A',
#  'PFKP',
#  'TANK',
#  'TGIF1',
#  'PPP1R15A',
#  'SEPW1',
#  'PLAUR',
#  'H2-M2',
#  'BATF',
#  'NUP62-IL4I1',
#  'TNFAIP2',
#  'FNDC3A',
#  'TREX1',
#  'RAB9',
#  'BCL2A1A',
#  'PDE4B',
#  'PIK3R5',
#  'RND3',
#  'CD44',
#  'AK172683',
#  'ARL5C',
#  'IER3',
#  'GTF2B',
#  'ANXA7',
#  'TXNRD1',
#  'HIF1A',
#  'MARCKSL1',
#  'PLK2',
#  'CFLAR',
#  'G530011O06RIK',
#  'B3GNT2',
#  'MTPN',
#  'PSMB10',
#  'PTPRE',
#  'MKIAA0694',
#  'OLR1',
#  'CCNL1',
#  'AA467197',
#  'DNAJB6',
#  'EHD1',
#  'H3F3B',
#  'SLC15A3',
#  'NFKBIB',
#  'JAK2',
#  'PLEK',
#  'RAP1B',
#  'SLC3A2',
#  'PGAP2',
#  'ALCAM',
#  'UBC',
#  'TFG',
#  'PILRA',
#  'PSME1',
#  'DAB2',
#  'AK142678',
#  'PNRC1',
#  'SKIL',
#  'SAT1',
#  'BCL2A1B',
#  'GNA13',
#  'NRP2',
#  'NAMPT',
#  'ISG15',
#  'FAM102B',
#  'BCL2A1C',
#  'BIRC6',
#  'RGS1']

# %%
#print(induced_data.head)

#genelist = induced_data.iloc[:,0].reset_index(drop=True).drop_duplicates().tolist()
#genelist += [genelist.pop(24)] #manually moving index 24 TNF to end so visible on plots

i=0

plt.subplots(1,1,figsize=(5,4.5))
axes = plt.gca()
axes.set_xlim([0,3000])
axes.set_ylim([0,4])

with open("my_summary_mean_freq_all_conds.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % ('gene','N','intercept','slope','min x','max x','R2'))



for test_gene in glist:
    i+=1
    print(i)
    summary_stats = induced_data[induced_data["Gene"]==test_gene]
    #print(summary_stats)
    if (len(summary_stats.loc[summary_stats['Mean'] == 0,['Mean']])>0) :
        print("Missing data for %s" % test_gene)
        with open("errorlog.csv","a") as logfile:
            logfile.write("%s\n" % test_gene)
        continue
    
    print("Working on %s mean/freq regression..." % test_gene)
    lm = linear_model.LinearRegression()
    model = lm.fit(summary_stats['Mean'].values.reshape(-1, 1),summary_stats['Frequency'])
    print("Intercept:\t",lm.intercept_)
    print("Coefficients:\t",lm.coef_)
    scoreAll = lm.score(summary_stats['Mean'].values.reshape(-1, 1),summary_stats['Frequency'])
    print("R^2 score:\t",scoreAll)

    linecol = 'gray'

    """
    if(test_gene == 'TNF') :
        linecol = 'red'
    elif(test_gene == 'IL1A'):
        linecol = 'blue'
    elif(test_gene == 'IL1B'):
        linecol = 'green'
    elif(test_gene == 'CCL4'):
        linecol = 'orange'
    elif(test_gene == 'CCL17'):
        linecol = 'purple'
    """
    
    #if test_gene in glist:
        
    plt.plot(summary_stats['Mean'], lm.predict(summary_stats['Mean'].values.reshape(-1,1)), color=linecol, linewidth=1)

    with open("my_summary_mean_freq_all_conds.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % (test_gene,len(summary_stats['Mean']),lm.intercept_,float(lm.coef_),min(summary_stats['Mean']), max(summary_stats['Mean']), scoreAll))
        print("%s,%s\n" % (test_gene,scoreAll))

plt.ylabel("Freq")
plt.xlabel("Mean")
#plt.savefig("global_regressions/mean_var_composite.png")
plt.savefig("my_mean_freq_allconds.png")
plt.close()
# Out:
# 1
# Working on CXCL1 mean/freq regression...
# Intercept:	 0.0554951427671
# Coefficients:	 [ 0.00018496]
# R^2 score:	 0.919393740004
# CXCL1,0.919393740004
#
# 2
# Working on RSAD2 mean/freq regression...
# Intercept:	 0.125755921955
# Coefficients:	 [ 0.00066769]
# R^2 score:	 0.914880182169
# RSAD2,0.914880182169
#
# 3
# Working on OASL1 mean/freq regression...
# Intercept:	 0.0589734582767
# Coefficients:	 [ 0.00152855]
# R^2 score:	 0.947868522131
# OASL1,0.947868522131
#
# 4
# Working on NT5C3 mean/freq regression...
# Intercept:	 0.0741034232369
# Coefficients:	 [ 0.0014309]
# R^2 score:	 0.948211079325
# NT5C3,0.948211079325
#
# 5
# Working on CCL4 mean/freq regression...
# Intercept:	 0.100647826151
# Coefficients:	 [  6.90858463e-05]
# R^2 score:	 0.936355178827
# CCL4,0.936355178827
#
# 6
# Working on EBI3 mean/freq regression...
# Intercept:	 0.105793625808
# Coefficients:	 [ 0.00088391]
# R^2 score:	 0.737736015474
# EBI3,0.737736015474
#
# 7
# Working on IRGM1 mean/freq regression...
# Intercept:	 0.0691175384503
# Coefficients:	 [ 0.00214404]
# R^2 score:	 0.944528072496
# IRGM1,0.944528072496
#
# 8
# Working on IFIT2 mean/freq regression...
# Intercept:	 0.0522805164661
# Coefficients:	 [ 0.00171337]
# R^2 score:	 0.958063817584
# IFIT2,0.958063817584
#
# 9
# Working on PYHIN1 mean/freq regression...
# Intercept:	 0.0507469972959
# Coefficients:	 [ 0.00305718]
# R^2 score:	 0.968350489912
# PYHIN1,0.968350489912
#
# 10
# Working on CAR4 mean/freq regression...
# Intercept:	 0.0190298733957
# Coefficients:	 [ 0.00100169]
# R^2 score:	 0.899173082626
# CAR4,0.899173082626
#
# 11
# Working on SLFN8 mean/freq regression...
# Intercept:	 0.0512746350561
# Coefficients:	 [ 0.00389894]
# R^2 score:	 0.910106067358
# SLFN8,0.910106067358
#
# 12
# Working on AW112010 mean/freq regression...
# Intercept:	 0.176193642707
# Coefficients:	 [ 0.00018698]
# R^2 score:	 0.909394258024
# AW112010,0.909394258024
#
# 13
# Working on U90926 mean/freq regression...
# Intercept:	 0.0196549249051
# Coefficients:	 [ 0.00014419]
# R^2 score:	 0.456228563772
# U90926,0.456228563772
#
# 14
# Working on IL15 mean/freq regression...
# Intercept:	 0.0539309036176
# Coefficients:	 [ 0.00167693]
# R^2 score:	 0.905963166682
# IL15,0.905963166682
#
# 15
# Working on GM4902 mean/freq regression...
# Intercept:	 0.0691522778002
# Coefficients:	 [ 0.00156811]
# R^2 score:	 0.887267502849
# GM4902,0.887267502849
#
# 16
# Working on GM14446 mean/freq regression...
# Intercept:	 0.0265883960276
# Coefficients:	 [ 0.00056787]
# R^2 score:	 0.86651742464
# GM14446,0.86651742464
#
# 17
# Working on FAM26F mean/freq regression...
# Intercept:	 0.023955653891
# Coefficients:	 [ 0.00248248]
# R^2 score:	 0.828259695706
# FAM26F,0.828259695706
#
# 18
# Working on D14ERTD668E mean/freq regression...
# Intercept:	 0.0386346572793
# Coefficients:	 [ 0.0033835]
# R^2 score:	 0.940773309571
# D14ERTD668E,0.940773309571
#
# 19
# Working on GM4951 mean/freq regression...
# Intercept:	 0.0244352922615
# Coefficients:	 [ 0.00271191]
# R^2 score:	 0.932795671251
# GM4951,0.932795671251
#
# 20
# Working on FGL2 mean/freq regression...
# Intercept:	 0.084713377638
# Coefficients:	 [ 0.00368825]
# R^2 score:	 0.709776295838
# FGL2,0.709776295838
#
# 21
# Working on APOL7C mean/freq regression...
# Intercept:	 0.0406929117172
# Coefficients:	 [ 0.00020782]
# R^2 score:	 0.70203464608
# APOL7C,0.70203464608
#
# 22
# Working on TRIM30A mean/freq regression...
# Intercept:	 0.0512317986447
# Coefficients:	 [ 0.00248783]
# R^2 score:	 0.925836041494
# TRIM30A,0.925836041494
#
# 23
# Working on CCL3 mean/freq regression...
# Intercept:	 0.210521168916
# Coefficients:	 [ 0.00013206]
# R^2 score:	 0.544581405717
# CCL3,0.544581405717
#
# 24
# Working on CXCL3 mean/freq regression...
# Intercept:	 0.106729547054
# Coefficients:	 [ 0.00019581]
# R^2 score:	 0.801993167123
# CXCL3,0.801993167123
#
# 25
# Working on CFB mean/freq regression...
# Intercept:	 0.0500046259127
# Coefficients:	 [ 0.00206965]
# R^2 score:	 0.625658150036
# CFB,0.625658150036
#
# 26
# Working on TMEM39A mean/freq regression...
# Intercept:	 0.0831791187483
# Coefficients:	 [ 0.0017463]
# R^2 score:	 0.692931269831
# TMEM39A,0.692931269831
#
# 27
# Working on CCND2 mean/freq regression...
# Intercept:	 0.0999360567831
# Coefficients:	 [ 0.00185113]
# R^2 score:	 0.817667187559
# CCND2,0.817667187559
#
# 28
# Working on MS4A6C mean/freq regression...
# Intercept:	 0.0497169892092
# Coefficients:	 [ 0.00138189]
# R^2 score:	 0.839724941612
# MS4A6C,0.839724941612
#
# 29
# Working on IRG1 mean/freq regression...
# Intercept:	 0.0894996062057
# Coefficients:	 [ 0.00084732]
# R^2 score:	 0.878186020588
# IRG1,0.878186020588
#
# 30
# Working on CCR7 mean/freq regression...
# Intercept:	 0.01899849753
# Coefficients:	 [ 0.00045686]
# R^2 score:	 0.925293278874
# CCR7,0.925293278874
#
# 31
# Working on USP18 mean/freq regression...
# Intercept:	 0.0867891493347
# Coefficients:	 [ 0.00118797]
# R^2 score:	 0.784168487524
# USP18,0.784168487524
#
# 32
# Working on IFIT3 mean/freq regression...
# Intercept:	 0.0228544660693
# Coefficients:	 [ 0.00081557]
# R^2 score:	 0.93571822161
# IFIT3,0.93571822161
#
# 33
# Working on ACPP mean/freq regression...
# Intercept:	 0.10381040683
# Coefficients:	 [ 0.00146416]
# R^2 score:	 0.739695183219
# ACPP,0.739695183219
#
# 34
# Working on ACSL1 mean/freq regression...
# Intercept:	 0.143895980866
# Coefficients:	 [ 0.00230495]
# R^2 score:	 0.49667932943
# ACSL1,0.49667932943
#
# 35
# Working on STAT5A mean/freq regression...
# Intercept:	 0.147565520786
# Coefficients:	 [ 0.00388858]
# R^2 score:	 0.732750429992
# STAT5A,0.732750429992
#
# 36
# Working on TNFSF9 mean/freq regression...
# Intercept:	 0.0592061132637
# Coefficients:	 [ 0.00077586]
# R^2 score:	 0.68757277549
# TNFSF9,0.68757277549
#
# 37
# Working on CD40 mean/freq regression...
# Intercept:	 0.0901013669957
# Coefficients:	 [ 0.00071638]
# R^2 score:	 0.88679667898
# CD40,0.88679667898
#
# 38
# Working on IFI205 mean/freq regression...
# Intercept:	 0.100869193931
# Coefficients:	 [ 0.00079814]
# R^2 score:	 0.818768761603
# IFI205,0.818768761603
#
# 39
# Working on MS4A4C mean/freq regression...
# Intercept:	 0.0299790257448
# Coefficients:	 [ 0.00120819]
# R^2 score:	 0.692742321412
# MS4A4C,0.692742321412
#
# 40
# Working on TARM1 mean/freq regression...
# Intercept:	 0.090149874343
# Coefficients:	 [ 0.00061331]
# R^2 score:	 0.60342834343
# TARM1,0.60342834343
#
# 41
# Working on NUDT17 mean/freq regression...
# Intercept:	 0.0376268051684
# Coefficients:	 [ 0.00125911]
# R^2 score:	 0.800617505656
# NUDT17,0.800617505656
#
# 42
# Working on AFTPH mean/freq regression...
# Intercept:	 0.0721226921582
# Coefficients:	 [ 0.00645268]
# R^2 score:	 0.892446569577
# AFTPH,0.892446569577
#
# 43
# Working on IRF7 mean/freq regression...
# Intercept:	 0.0475866654552
# Coefficients:	 [ 0.00253257]
# R^2 score:	 0.814275603453
# IRF7,0.814275603453
#
# 44
# Working on TLR2 mean/freq regression...
# Intercept:	 0.0997985878787
# Coefficients:	 [ 0.00230967]
# R^2 score:	 0.678012471164
# TLR2,0.678012471164
#
# 45
# Working on IL15RA mean/freq regression...
# Intercept:	 0.0550767404884
# Coefficients:	 [ 0.00197319]
# R^2 score:	 0.83202869251
# IL15RA,0.83202869251
#
# 46
# Working on INHBA mean/freq regression...
# Intercept:	 0.0644069650434
# Coefficients:	 [ 0.00087593]
# R^2 score:	 0.784640647614
# INHBA,0.784640647614
#
# 47
# Working on IIGP1 mean/freq regression...
# Intercept:	 0.0526632826394
# Coefficients:	 [ 0.00195414]
# R^2 score:	 0.68731221103
# IIGP1,0.68731221103
#
# 48
# Working on TRIM30D mean/freq regression...
# Intercept:	 0.0730199706684
# Coefficients:	 [ 0.00474586]
# R^2 score:	 0.837474741084
# TRIM30D,0.837474741084
#
# 49
# Working on TIMP1 mean/freq regression...
# Intercept:	 0.0240150823638
# Coefficients:	 [ 0.00092952]
# R^2 score:	 0.661863151876
# TIMP1,0.661863151876
#
# 50
# Working on CCL7 mean/freq regression...
# Intercept:	 0.0168252706885
# Coefficients:	 [ 0.0001307]
# R^2 score:	 0.254691329721
# CCL7,0.254691329721
#
# 51
# Working on SRGN mean/freq regression...
# Intercept:	 0.228731780715
# Coefficients:	 [ 0.00070127]
# R^2 score:	 0.853574222863
# SRGN,0.853574222863
#
# 52
# Working on IL1A mean/freq regression...
# Intercept:	 0.123437511306
# Coefficients:	 [ 0.00031924]
# R^2 score:	 0.685650604836
# IL1A,0.685650604836
#
# 53
# Working on SERPINA3G mean/freq regression...
# Intercept:	 0.0212129221348
# Coefficients:	 [ 0.00152454]
# R^2 score:	 0.806837249734
# SERPINA3G,0.806837249734
#
# 54
# Working on TAP1 mean/freq regression...
# Intercept:	 0.0736304069097
# Coefficients:	 [ 0.00472365]
# R^2 score:	 0.806659912693
# TAP1,0.806659912693
#
# 55
# Working on SLAMF7 mean/freq regression...
# Intercept:	 0.0966638195724
# Coefficients:	 [ 0.00168488]
# R^2 score:	 0.865070685077
# SLAMF7,0.865070685077
#
# 56
# Working on IFIT1 mean/freq regression...
# Intercept:	 0.0359429982199
# Coefficients:	 [ 0.00121041]
# R^2 score:	 0.884414553513
# IFIT1,0.884414553513
#
# 57
# Working on CISH mean/freq regression...
# Intercept:	 0.0844703249702
# Coefficients:	 [ 0.00166485]
# R^2 score:	 0.770938761748
# CISH,0.770938761748
#
# 58
# Working on FAS mean/freq regression...
# Intercept:	 0.0855183469773
# Coefficients:	 [ 0.00117876]
# R^2 score:	 0.722604381992
# FAS,0.722604381992
#
# 59
# Working on CXCL10 mean/freq regression...
# Intercept:	 0.102793301043
# Coefficients:	 [ 0.00017075]
# R^2 score:	 0.826897079642
# CXCL10,0.826897079642
#
# 60
# Working on SLFN5 mean/freq regression...
# Intercept:	 0.102366412326
# Coefficients:	 [ 0.00404919]
# R^2 score:	 0.863098215624
# SLFN5,0.863098215624
#
# 61
# Working on SLC2A6 mean/freq regression...
# Intercept:	 0.177767180679
# Coefficients:	 [ 0.00190249]
# R^2 score:	 0.649152369709
# SLC2A6,0.649152369709
#
# 62
# Working on CMPK2 mean/freq regression...
# Intercept:	 0.0584023927538
# Coefficients:	 [ 0.00171409]
# R^2 score:	 0.863396927117
# CMPK2,0.863396927117
#
# 63
# Working on PCGF5 mean/freq regression...
# Intercept:	 0.0859148840224
# Coefficients:	 [ 0.00172598]
# R^2 score:	 0.551683971474
# PCGF5,0.551683971474
#
# 64
# Working on CAR13 mean/freq regression...
# Intercept:	 0.0875297001853
# Coefficients:	 [ 0.00211564]
# R^2 score:	 0.57478679789
# CAR13,0.57478679789
#
# 65
# Working on GBP3 mean/freq regression...
# Intercept:	 0.0597741060498
# Coefficients:	 [ 0.00243419]
# R^2 score:	 0.835761588143
# GBP3,0.835761588143
#
# 66
# Working on UBE2L6 mean/freq regression...
# Intercept:	 0.0821688235678
# Coefficients:	 [ 0.00171532]
# R^2 score:	 0.82357640287
# UBE2L6,0.82357640287
#
# 67
# Working on MX2 mean/freq regression...
# Intercept:	 0.0313011403058
# Coefficients:	 [ 0.00306243]
# R^2 score:	 0.660762708934
# MX2,0.660762708934
#
# 68
# Working on ZDHHC21 mean/freq regression...
# Intercept:	 0.623461871827
# Coefficients:	 [-0.00579285]
# R^2 score:	 0.286402337684
# ZDHHC21,0.286402337684
#
# 69
# Working on AK138792 mean/freq regression...
# Intercept:	 0.621382366206
# Coefficients:	 [-0.00173801]
# R^2 score:	 0.305451431914
# AK138792,0.305451431914
#
# 70
# Working on CH25H mean/freq regression...
# Intercept:	 0.0289551346273
# Coefficients:	 [ 0.00089641]
# R^2 score:	 0.663838120371
# CH25H,0.663838120371
#
# 71
# Working on PTGS2 mean/freq regression...
# Intercept:	 0.0412242707128
# Coefficients:	 [ 0.00246426]
# R^2 score:	 0.76572873561
# PTGS2,0.76572873561
#
# 72
# Working on SAMHD1 mean/freq regression...
# Intercept:	 0.345149960308
# Coefficients:	 [ 0.00243074]
# R^2 score:	 0.605370412193
# SAMHD1,0.605370412193
#
# 73
# Working on SDC4 mean/freq regression...
# Intercept:	 0.252082302285
# Coefficients:	 [ 0.00018942]
# R^2 score:	 0.206319037609
# SDC4,0.206319037609
#
# 74
# Working on ADAP2 mean/freq regression...
# Intercept:	 0.0754190459133
# Coefficients:	 [ 0.00284425]
# R^2 score:	 0.616480274629
# ADAP2,0.616480274629
#
# 75
# Working on MS4A6D mean/freq regression...
# Intercept:	 0.121026896935
# Coefficients:	 [ 0.00116329]
# R^2 score:	 0.683446617461
# MS4A6D,0.683446617461
#
# 76
# Working on ATF3 mean/freq regression...
# Intercept:	 0.193009714839
# Coefficients:	 [ 0.00148405]
# R^2 score:	 0.479126086257
# ATF3,0.479126086257
#
# 77
# Working on TNFSF15 mean/freq regression...
# Intercept:	 0.0627941964001
# Coefficients:	 [ 0.00209273]
# R^2 score:	 0.827947958648
# TNFSF15,0.827947958648
#
# 78
# Working on RELA mean/freq regression...
# Intercept:	 0.149137705955
# Coefficients:	 [ 0.00178746]
# R^2 score:	 0.326943336551
# RELA,0.326943336551
#
# 79
# Working on ZFP36 mean/freq regression...
# Intercept:	 0.193555661337
# Coefficients:	 [ 0.00225732]
# R^2 score:	 0.566780093872
# ZFP36,0.566780093872
#
# 80
# Working on SLFN2 mean/freq regression...
# Intercept:	 0.376161982187
# Coefficients:	 [ 0.00148654]
# R^2 score:	 0.623986618952
# SLFN2,0.623986618952
#
# 81
# Working on GM12250 mean/freq regression...
# Intercept:	 0.0377994878572
# Coefficients:	 [ 0.0044979]
# R^2 score:	 0.895195387593
# GM12250,0.895195387593
#
# 82
# Working on STAT1 mean/freq regression...
# Intercept:	 0.0419328369397
# Coefficients:	 [ 0.00471683]
# R^2 score:	 0.863808020953
# STAT1,0.863808020953
#
# 83
# Working on BIRC3 mean/freq regression...
# Intercept:	 0.139343588526
# Coefficients:	 [ 0.00151349]
# R^2 score:	 0.439801607445
# BIRC3,0.439801607445
#
# 84
# Working on 1190002H23RIK mean/freq regression...
# Intercept:	 0.0510287676079
# Coefficients:	 [ 0.00096553]
# R^2 score:	 0.378662188682
# 1190002H23RIK,0.378662188682
#
# 85
# Working on ALDH1A2 mean/freq regression...
# Intercept:	 0.042279379339
# Coefficients:	 [ 0.00079752]
# R^2 score:	 0.48662879298
# ALDH1A2,0.48662879298
#
# 86
# Working on OASL2 mean/freq regression...
# Intercept:	 0.0475285057753
# Coefficients:	 [ 0.00341726]
# R^2 score:	 0.83065074854
# OASL2,0.83065074854
#
# 87
# Working on IL27 mean/freq regression...
# Intercept:	 0.0361359495329
# Coefficients:	 [ 0.00152491]
# R^2 score:	 0.710616876225
# IL27,0.710616876225
#
# 88
# Working on H1F0 mean/freq regression...
# Intercept:	 0.152895564584
# Coefficients:	 [ 0.00154682]
# R^2 score:	 0.712070795535
# H1F0,0.712070795535
#
# 89
# Working on CCL2 mean/freq regression...
# Intercept:	 0.0662637107475
# Coefficients:	 [ 0.00014015]
# R^2 score:	 0.343376996389
# CCL2,0.343376996389
#
# 90
# Working on DDX58 mean/freq regression...
# Intercept:	 0.0576050362873
# Coefficients:	 [ 0.00478668]
# R^2 score:	 0.781372666378
# DDX58,0.781372666378
#
# 91
# Working on GBP5 mean/freq regression...
# Intercept:	 0.0474944596332
# Coefficients:	 [ 0.00473734]
# R^2 score:	 0.829940494301
# GBP5,0.829940494301
#
# 92
# Working on CAV1 mean/freq regression...
# Intercept:	 0.0628068264224
# Coefficients:	 [ 0.00151637]
# R^2 score:	 0.730285895936
# CAV1,0.730285895936
#
# 93
# Working on NMI mean/freq regression...
# Intercept:	 0.0544646774726
# Coefficients:	 [ 0.00272844]
# R^2 score:	 0.630344088386
# NMI,0.630344088386
#
# 94
# Working on CCL17 mean/freq regression...
# Intercept:	 0.108687969874
# Coefficients:	 [  6.56029090e-05]
# R^2 score:	 0.746338288997
# CCL17,0.746338288997
#
# 95
# Working on SLPI mean/freq regression...
# Intercept:	 0.110994665443
# Coefficients:	 [  6.01374094e-05]
# R^2 score:	 0.021039338119
# SLPI,0.021039338119
#
# 96
# Working on H2-T23 mean/freq regression...
# Intercept:	 0.278870906604
# Coefficients:	 [ 0.00136483]
# R^2 score:	 0.541697127215
# H2-T23,0.541697127215
#
# 97
# Working on NFKBIZ mean/freq regression...
# Intercept:	 0.0990170128934
# Coefficients:	 [ 0.00329311]
# R^2 score:	 0.681939253549
# NFKBIZ,0.681939253549
#
# 98
# Working on DHX58 mean/freq regression...
# Intercept:	 0.0457946645848
# Coefficients:	 [ 0.00481632]
# R^2 score:	 0.765201860889
# DHX58,0.765201860889
#
# 99
# Working on THBS1 mean/freq regression...
# Intercept:	 0.0618198642575
# Coefficients:	 [ 0.00178713]
# R^2 score:	 0.5789114033
# THBS1,0.5789114033
#
# 100
# Working on HERC6 mean/freq regression...
# Intercept:	 0.0178752359047
# Coefficients:	 [ 0.00448722]
# R^2 score:	 0.862761677129
# HERC6,0.862761677129
#
# 101
# Working on CD86 mean/freq regression...
# Intercept:	 0.106381276769
# Coefficients:	 [ 0.00109913]
# R^2 score:	 0.599195199853
# CD86,0.599195199853
#
# 102
# Working on IGTP mean/freq regression...
# Intercept:	 0.0173759464461
# Coefficients:	 [ 0.00305135]
# R^2 score:	 0.867421983014
# IGTP,0.867421983014
#
# 103
# Working on FABP3 mean/freq regression...
# Intercept:	 0.0307677861568
# Coefficients:	 [ 0.00096657]
# R^2 score:	 0.693440208474
# FABP3,0.693440208474
#
# 104
# Working on AK042010 mean/freq regression...
# Intercept:	 0.036181283947
# Coefficients:	 [ 0.00323634]
# R^2 score:	 0.731516314371
# AK042010,0.731516314371
#
# 105
# Working on GBP6 mean/freq regression...
# Intercept:	 0.0701156555062
# Coefficients:	 [ 0.00459795]
# R^2 score:	 0.780390812052
# GBP6,0.780390812052
#
# 106
# Working on IL1RN mean/freq regression...
# Intercept:	 0.0908252922852
# Coefficients:	 [ 0.00079922]
# R^2 score:	 0.839171947387
# IL1RN,0.839171947387
#
# 107
# Working on SERPINB9B mean/freq regression...
# Intercept:	 0.0263095848409
# Coefficients:	 [ 0.00020363]
# R^2 score:	 0.296778072053
# SERPINB9B,0.296778072053
#
# 108
# Working on INSIG1 mean/freq regression...
# Intercept:	 0.406932045817
# Coefficients:	 [ 0.0030742]
# R^2 score:	 0.127973206022
# INSIG1,0.127973206022
#
# 109
# Working on RTP4 mean/freq regression...
# Intercept:	 0.00579931534202
# Coefficients:	 [ 0.00245334]
# R^2 score:	 0.886297118185
# RTP4,0.886297118185
#
# 110
# Working on IL1B mean/freq regression...
# Intercept:	 0.154088840185
# Coefficients:	 [ 0.00022714]
# R^2 score:	 0.639812484507
# IL1B,0.639812484507
#
# 111
# Working on IFI204 mean/freq regression...
# Intercept:	 0.0949457328265
# Coefficients:	 [ 0.00177529]
# R^2 score:	 0.809237941533
# IFI204,0.809237941533
#
# 112
# Working on CD69 mean/freq regression...
# Intercept:	 0.110261748852
# Coefficients:	 [ 0.00045959]
# R^2 score:	 0.519278824612
# CD69,0.519278824612
#
# 113
# Working on LGALS9 mean/freq regression...
# Intercept:	 0.111524497082
# Coefficients:	 [ 0.00135654]
# R^2 score:	 0.706189173269
# LGALS9,0.706189173269
#
# 114
# Working on IFI27L2A mean/freq regression...
# Intercept:	 0.151902715303
# Coefficients:	 [ 0.00068397]
# R^2 score:	 0.538335167203
# IFI27L2A,0.538335167203
#
# 115
# Working on IFI47 mean/freq regression...
# Intercept:	 0.0425331003594
# Coefficients:	 [ 0.00170864]
# R^2 score:	 0.867295255123
# IFI47,0.867295255123
#
# 116
# Working on CLU mean/freq regression...
# Intercept:	 0.0210922845868
# Coefficients:	 [ 0.00017522]
# R^2 score:	 0.67028065864
# CLU,0.67028065864
#
# 117
# Working on 2310016C08RIK mean/freq regression...
# Intercept:	 0.0203829505113
# Coefficients:	 [ 0.00120694]
# R^2 score:	 0.798191067487
# 2310016C08RIK,0.798191067487
#
# 118
# Working on KPNA3 mean/freq regression...
# Intercept:	 0.107822419502
# Coefficients:	 [ 0.00539788]
# R^2 score:	 0.745832385633
# KPNA3,0.745832385633
#
# 119
# Working on GLIPR2 mean/freq regression...
# Intercept:	 0.0887721226605
# Coefficients:	 [ 0.000654]
# R^2 score:	 0.520620780523
# GLIPR2,0.520620780523
#
# 120
# Working on XAF1 mean/freq regression...
# Intercept:	 0.0592540101611
# Coefficients:	 [ 0.0036184]
# R^2 score:	 0.812238785101
# XAF1,0.812238785101
#
# 121
# Working on SLC7A2 mean/freq regression...
# Intercept:	 0.189790733442
# Coefficients:	 [ 0.0030178]
# R^2 score:	 0.602418515155
# SLC7A2,0.602418515155
#
# 122
# Working on PROCR mean/freq regression...
# Intercept:	 0.0558016051132
# Coefficients:	 [ 0.00160002]
# R^2 score:	 0.641010059847
# PROCR,0.641010059847
#
# 123
# Working on PRPF38A mean/freq regression...
# Intercept:	 0.136452865057
# Coefficients:	 [ 0.00069705]
# R^2 score:	 0.062878905203
# PRPF38A,0.062878905203
#
# 124
# Working on 1810029B16RIK mean/freq regression...
# Intercept:	 0.237131618443
# Coefficients:	 [ 0.00067851]
# R^2 score:	 0.0938188910707
# 1810029B16RIK,0.0938188910707
#
# 125
# Working on CCRL2 mean/freq regression...
# Intercept:	 0.0736148570941
# Coefficients:	 [ 0.00216682]
# R^2 score:	 0.733925066499
# CCRL2,0.733925066499
#
# 126
# Working on GBP2 mean/freq regression...
# Intercept:	 0.21030496713
# Coefficients:	 [ 0.00137347]
# R^2 score:	 0.587640272026
# GBP2,0.587640272026
#
# 127
# Working on DUSP1 mean/freq regression...
# Intercept:	 0.111014836763
# Coefficients:	 [ 0.00232788]
# R^2 score:	 0.530070819608
# DUSP1,0.530070819608
#
# 128
# Working on PTX3 mean/freq regression...
# Intercept:	 0.0356431833902
# Coefficients:	 [ 0.00087218]
# R^2 score:	 0.618148108815
# PTX3,0.618148108815
#
# 129
# Working on BST2 mean/freq regression...
# Intercept:	 0.081882500802
# Coefficients:	 [ 0.00252685]
# R^2 score:	 0.59710439047
# BST2,0.59710439047
#
# 130
# Working on RAB32 mean/freq regression...
# Intercept:	 0.110696378784
# Coefficients:	 [ 0.00198154]
# R^2 score:	 0.635643568516
# RAB32,0.635643568516
#
# 131
# Working on CLEC4E mean/freq regression...
# Intercept:	 0.0990458000989
# Coefficients:	 [ 0.00102996]
# R^2 score:	 0.7125891335
# CLEC4E,0.7125891335
#
# 132
# Working on BLNK mean/freq regression...
# Intercept:	 0.0886041333101
# Coefficients:	 [ 0.00203584]
# R^2 score:	 0.733061781609
# BLNK,0.733061781609
#
# 133
# Working on SP100 mean/freq regression...
# Intercept:	 0.103605926638
# Coefficients:	 [ 0.00201867]
# R^2 score:	 0.607285933592
# SP100,0.607285933592
#
# 134
# Working on STAT2 mean/freq regression...
# Intercept:	 0.0421676263739
# Coefficients:	 [ 0.00515169]
# R^2 score:	 0.786768986812
# STAT2,0.786768986812
#
# 135
# Working on CD200 mean/freq regression...
# Intercept:	 0.0807622488519
# Coefficients:	 [ 0.00139665]
# R^2 score:	 0.649385626319
# CD200,0.649385626319
#
# 136
# Working on PARP9 mean/freq regression...
# Intercept:	 0.0208941501805
# Coefficients:	 [ 0.00635591]
# R^2 score:	 0.744349695362
# PARP9,0.744349695362
#
# 137
# Working on PRDX1 mean/freq regression...
# Intercept:	 0.772953089286
# Coefficients:	 [ 0.00010108]
# R^2 score:	 0.314960752722
# PRDX1,0.314960752722
#
# 138
# Working on MMP13 mean/freq regression...
# Intercept:	 0.0353103421295
# Coefficients:	 [ 0.00072469]
# R^2 score:	 0.416965344316
# MMP13,0.416965344316
#
# 139
# Working on CD274 mean/freq regression...
# Intercept:	 0.114677925965
# Coefficients:	 [ 0.0031456]
# R^2 score:	 0.726730529641
# CD274,0.726730529641
#
# 140
# Working on AI607873 mean/freq regression...
# Intercept:	 0.0634177809938
# Coefficients:	 [ 0.00164007]
# R^2 score:	 0.674402426163
# AI607873,0.674402426163
#
# 141
# Working on PMP22 mean/freq regression...
# Intercept:	 0.0956583195435
# Coefficients:	 [ 0.00112969]
# R^2 score:	 0.573332197213
# PMP22,0.573332197213
#
# 142
# Working on CD47 mean/freq regression...
# Intercept:	 0.518195105012
# Coefficients:	 [ 0.00140258]
# R^2 score:	 0.146786702823
# CD47,0.146786702823
#
# 143
# Working on ZBP1 mean/freq regression...
# Intercept:	 0.0297819143082
# Coefficients:	 [ 0.00228728]
# R^2 score:	 0.812240304675
# ZBP1,0.812240304675
#
# 144
# Working on PHF11 mean/freq regression...
# Intercept:	 0.0367250838082
# Coefficients:	 [ 0.00219755]
# R^2 score:	 0.809690569135
# PHF11,0.809690569135
#
# 145
# Working on TOR3A mean/freq regression...
# Intercept:	 0.0536120121234
# Coefficients:	 [ 0.00524747]
# R^2 score:	 0.844971144806
# TOR3A,0.844971144806
#
# 146
# Working on IFI35 mean/freq regression...
# Intercept:	 0.001258209204
# Coefficients:	 [ 0.00398096]
# R^2 score:	 0.872986530778
# IFI35,0.872986530778
#
# 147
# Working on LCP2 mean/freq regression...
# Intercept:	 0.105663355106
# Coefficients:	 [ 0.00401812]
# R^2 score:	 0.500690936829
# LCP2,0.500690936829
#
# 148
# Working on SBDS mean/freq regression...
# Intercept:	 0.18577072434
# Coefficients:	 [ 0.00232882]
# R^2 score:	 0.61883438439
# SBDS,0.61883438439
#
# 149
# Working on IFITM3 mean/freq regression...
# Intercept:	 0.0436105339959
# Coefficients:	 [ 0.000687]
# R^2 score:	 0.815602630078
# IFITM3,0.815602630078
#
# 150
# Working on DTX3L mean/freq regression...
# Intercept:	 0.0627253118397
# Coefficients:	 [ 0.00972253]
# R^2 score:	 0.686593462376
# DTX3L,0.686593462376
#
# 151
# Working on IL6 mean/freq regression...
# Intercept:	 0.0483639252942
# Coefficients:	 [ 0.0005434]
# R^2 score:	 0.827637484265
# IL6,0.827637484265
#
# 152
# Working on FPR1 mean/freq regression...
# Intercept:	 0.0147065814683
# Coefficients:	 [ 0.00123723]
# R^2 score:	 0.783909324748
# FPR1,0.783909324748
#
# 153
# Working on AY096003 mean/freq regression...
# Intercept:	 0.0895618069356
# Coefficients:	 [ 0.00177966]
# R^2 score:	 0.656374770579
# AY096003,0.656374770579
#
# 154
# Working on SAA3 mean/freq regression...
# Intercept:	 0.0492515982706
# Coefficients:	 [ 0.00013478]
# R^2 score:	 0.26610778295
# SAA3,0.26610778295
#
# 155
# Working on FOS mean/freq regression...
# Intercept:	 0.0598709438304
# Coefficients:	 [ 0.00103356]
# R^2 score:	 0.341290391769
# FOS,0.341290391769
#
# 156
# Working on ZUFSP mean/freq regression...
# Intercept:	 0.0397570432397
# Coefficients:	 [ 0.0037123]
# R^2 score:	 0.729322940464
# ZUFSP,0.729322940464
#
# 157
# Working on EPSTI1 mean/freq regression...
# Intercept:	 0.11913354464
# Coefficients:	 [ 0.00095771]
# R^2 score:	 0.0823042656501
# EPSTI1,0.0823042656501
#
# 158
# Working on PDZK1IP1 mean/freq regression...
# Intercept:	 0.0606094737718
# Coefficients:	 [ 0.00152498]
# R^2 score:	 0.459229640896
# PDZK1IP1,0.459229640896
#
# 159
# Working on MCA32 mean/freq regression...
# Intercept:	 0.0943480040809
# Coefficients:	 [ 0.0009745]
# R^2 score:	 0.409589729391
# MCA32,0.409589729391
#
# 160
# Working on NFKBIA mean/freq regression...
# Intercept:	 0.338956817651
# Coefficients:	 [ 0.00106955]
# R^2 score:	 0.689996410016
# NFKBIA,0.689996410016
#
# 161
# Working on H2-T10 mean/freq regression...
# Intercept:	 0.0770913280752
# Coefficients:	 [ 0.00185191]
# R^2 score:	 0.586951977696
# H2-T10,0.586951977696
#
# 162
# Working on IFNB1 mean/freq regression...
# Intercept:	 0.0213615916805
# Coefficients:	 [ 0.00056196]
# R^2 score:	 0.282055674863
# IFNB1,0.282055674863
#
# 163
# Working on IFIH1 mean/freq regression...
# Intercept:	 -0.0481858924321
# Coefficients:	 [ 0.00505218]
# R^2 score:	 0.906148334735
# IFIH1,0.906148334735
#
# 164
# Working on AK052414 mean/freq regression...
# Intercept:	 0.0597018626655
# Coefficients:	 [ 0.0018549]
# R^2 score:	 0.481781060314
# AK052414,0.481781060314
#
# 165
# Working on MT2 mean/freq regression...
# Intercept:	 0.0691025205925
# Coefficients:	 [ 0.00174746]
# R^2 score:	 0.805814253214
# MT2,0.805814253214
#
# 166
# Working on CLIC4 mean/freq regression...
# Intercept:	 0.265236794725
# Coefficients:	 [ 0.00405065]
# R^2 score:	 0.568978633333
# CLIC4,0.568978633333
#
# 167
# Working on ARF4 mean/freq regression...
# Intercept:	 0.398155441568
# Coefficients:	 [ 0.00162289]
# R^2 score:	 0.205012819109
# ARF4,0.205012819109
#
# 168
# Working on ETV3 mean/freq regression...
# Intercept:	 0.259562016165
# Coefficients:	 [ 0.00095236]
# R^2 score:	 0.0975543552337
# ETV3,0.0975543552337
#
# 169
# Working on SERPINB6B mean/freq regression...
# Intercept:	 0.027886247553
# Coefficients:	 [ 0.00072]
# R^2 score:	 0.573543767784
# SERPINB6B,0.573543767784
#
# 170
# Working on RNASET2B mean/freq regression...
# Intercept:	 0.351764324336
# Coefficients:	 [ 0.0003165]
# R^2 score:	 0.0297927484612
# RNASET2B,0.0297927484612
#
# 171
# Working on KTELC1 mean/freq regression...
# Intercept:	 0.0438018163767
# Coefficients:	 [ 0.00217692]
# R^2 score:	 0.699260166862
# KTELC1,0.699260166862
#
# 172
# Working on IL7R mean/freq regression...
# Intercept:	 0.134371819711
# Coefficients:	 [ 0.00256429]
# R^2 score:	 0.424787012643
# IL7R,0.424787012643
#
# 173
# Working on LAP3 mean/freq regression...
# Intercept:	 0.0801438262638
# Coefficients:	 [ 0.00415616]
# R^2 score:	 0.593809110795
# LAP3,0.593809110795
#
# 174
# Working on FPR2 mean/freq regression...
# Intercept:	 0.0245561713814
# Coefficients:	 [ 0.0016037]
# R^2 score:	 0.766120576621
# FPR2,0.766120576621
#
# 175
# Working on TNIP3 mean/freq regression...
# Intercept:	 0.190395840695
# Coefficients:	 [ 0.0018935]
# R^2 score:	 0.456741224748
# TNIP3,0.456741224748
#
# 176
# Working on NCOA7 mean/freq regression...
# Intercept:	 0.170335670013
# Coefficients:	 [ 0.00080939]
# R^2 score:	 0.0748709005918
# NCOA7,0.0748709005918
#
# 177
# Working on TNFAIP3 mean/freq regression...
# Intercept:	 0.0325461485137
# Coefficients:	 [ 0.00558659]
# R^2 score:	 0.737758226302
# TNFAIP3,0.737758226302
#
# 178
# Working on ELL2 mean/freq regression...
# Intercept:	 0.155246276258
# Coefficients:	 [ 0.00361765]
# R^2 score:	 0.328363616036
# ELL2,0.328363616036
#
# 179
# Working on PTTG1 mean/freq regression...
# Intercept:	 0.0913965487671
# Coefficients:	 [ 0.00229711]
# R^2 score:	 0.754322672958
# PTTG1,0.754322672958
#
# 180
# Working on MX1 mean/freq regression...
# Intercept:	 0.0611633176955
# Coefficients:	 [ 0.00098508]
# R^2 score:	 0.753882401686
# MX1,0.753882401686
#
# 181
# Working on RILPL2 mean/freq regression...
# Intercept:	 0.113830115027
# Coefficients:	 [ 0.00203064]
# R^2 score:	 0.5312848436
# RILPL2,0.5312848436
#
# 182
# Working on CCL5 mean/freq regression...
# Intercept:	 0.0299673471959
# Coefficients:	 [  8.33957416e-05]
# R^2 score:	 0.840364169881
# CCL5,0.840364169881
#
# 183
# Working on CAR2 mean/freq regression...
# Intercept:	 0.039217526192
# Coefficients:	 [ 0.00083728]
# R^2 score:	 0.505180896787
# CAR2,0.505180896787
#
# 184
# Working on TNF mean/freq regression...
# Intercept:	 0.0751274688493
# Coefficients:	 [ 0.00084519]
# R^2 score:	 0.54285293469
# TNF,0.54285293469
#
# 185
# Working on SWAP70 mean/freq regression...
# Intercept:	 0.0831754352537
# Coefficients:	 [ 0.00255636]
# R^2 score:	 0.408544129343
# SWAP70,0.408544129343
#
# 186
# Working on IRF8 mean/freq regression...
# Intercept:	 0.0720842030296
# Coefficients:	 [ 0.00200594]
# R^2 score:	 0.591072726259
# IRF8,0.591072726259
#
# 187
# Working on TRAF1 mean/freq regression...
# Intercept:	 0.10093420743
# Coefficients:	 [ 0.00181032]
# R^2 score:	 0.437452073076
# TRAF1,0.437452073076
#
# 188
# Working on PPP1CB mean/freq regression...
# Intercept:	 0.265206164765
# Coefficients:	 [ 0.001654]
# R^2 score:	 0.0902449362535
# PPP1CB,0.0902449362535
#
# 189
# Working on SERPINB9 mean/freq regression...
# Intercept:	 0.0508859826254
# Coefficients:	 [ 0.00081385]
# R^2 score:	 0.473117419328
# SERPINB9,0.473117419328
#
# 190
# Working on RBM7 mean/freq regression...
# Intercept:	 0.164077559492
# Coefficients:	 [ 0.00162373]
# R^2 score:	 0.250959503258
# RBM7,0.250959503258
#
# 191
# Working on 9430076C15RIK mean/freq regression...
# Intercept:	 0.14422917445
# Coefficients:	 [ 0.00247443]
# R^2 score:	 0.398575445735
# 9430076C15RIK,0.398575445735
#
# 192
# Working on H2-Q7 mean/freq regression...
# Intercept:	 0.0870677257824
# Coefficients:	 [ 0.00155043]
# R^2 score:	 0.615572865608
# H2-Q7,0.615572865608
#
# 193
# Working on MALT1 mean/freq regression...
# Intercept:	 0.186768588536
# Coefficients:	 [ 0.00284907]
# R^2 score:	 0.391307061766
# MALT1,0.391307061766
#
# 194
# Working on AK217941 mean/freq regression...
# Intercept:	 0.118437463115
# Coefficients:	 [ 0.00068892]
# R^2 score:	 0.158268152366
# AK217941,0.158268152366
#
# 195
# Working on KTN1 mean/freq regression...
# Intercept:	 0.0952274456127
# Coefficients:	 [ 0.00348832]
# R^2 score:	 0.509564199384
# KTN1,0.509564199384
#
# 196
# Working on HSPA5 mean/freq regression...
# Intercept:	 0.232389100281
# Coefficients:	 [ 0.00181536]
# R^2 score:	 0.453856130971
# HSPA5,0.453856130971
#
# 197
# Working on MYD88 mean/freq regression...
# Intercept:	 0.135136171962
# Coefficients:	 [ 0.00183078]
# R^2 score:	 0.323857912849
# MYD88,0.323857912849
#
# 198
# Working on TAPBP mean/freq regression...
# Intercept:	 0.474705483362
# Coefficients:	 [ 0.00232806]
# R^2 score:	 0.270680459646
# TAPBP,0.270680459646
#
# 199
# Working on MKIAA1673 mean/freq regression...
# Intercept:	 0.0749880026165
# Coefficients:	 [ 0.0046727]
# R^2 score:	 0.590710083802
# MKIAA1673,0.590710083802
#
# 200
# Working on IFRD1 mean/freq regression...
# Intercept:	 0.0855112147124
# Coefficients:	 [ 0.00206167]
# R^2 score:	 0.405228492755
# IFRD1,0.405228492755
#
# 201
# Working on CASP1 mean/freq regression...
# Intercept:	 0.120170975623
# Coefficients:	 [ 0.00153287]
# R^2 score:	 0.37258519708
# CASP1,0.37258519708
#
# 202
# Working on IFI203 mean/freq regression...
# Intercept:	 0.0617532848965
# Coefficients:	 [ 0.0040031]
# R^2 score:	 0.753907569675
# IFI203,0.753907569675
#
# 203
# Working on IRF1 mean/freq regression...
# Intercept:	 0.0861864702653
# Coefficients:	 [ 0.00201637]
# R^2 score:	 0.628971877
# IRF1,0.628971877
#
# 204
# Working on TNFRSF1B mean/freq regression...
# Intercept:	 0.22176578105
# Coefficients:	 [ 0.00277112]
# R^2 score:	 0.493406989133
# TNFRSF1B,0.493406989133
#
# 205
# Working on A130040M12RIK mean/freq regression...
# Intercept:	 0.11894051229
# Coefficients:	 [ 0.0032889]
# R^2 score:	 0.63536668976
# A130040M12RIK,0.63536668976
#
# 206
# Working on PNP mean/freq regression...
# Intercept:	 0.0521217314109
# Coefficients:	 [ 0.00388574]
# R^2 score:	 0.646775577366
# PNP,0.646775577366
#
# 207
# Working on SP140 mean/freq regression...
# Intercept:	 0.203122130604
# Coefficients:	 [ 0.00282865]
# R^2 score:	 0.590085838406
# SP140,0.590085838406
#
# 208
# Working on BHLHE40 mean/freq regression...
# Intercept:	 0.1827362244
# Coefficients:	 [ 0.00196498]
# R^2 score:	 0.244242009013
# BHLHE40,0.244242009013
#
# 209
# Working on CXCL16 mean/freq regression...
# Intercept:	 0.282695527099
# Coefficients:	 [ 0.00148097]
# R^2 score:	 0.431796963142
# CXCL16,0.431796963142
#
# 210
# Working on MAP2K1 mean/freq regression...
# Intercept:	 0.105757871819
# Coefficients:	 [ 0.00348311]
# R^2 score:	 0.388204907391
# MAP2K1,0.388204907391
#
# 211
# Working on RASGEF1B mean/freq regression...
# Intercept:	 0.0811350027307
# Coefficients:	 [ 0.002508]
# R^2 score:	 0.471070733432
# RASGEF1B,0.471070733432
#
# 212
# Working on CDKN1A mean/freq regression...
# Intercept:	 0.438063442235
# Coefficients:	 [ 0.00124632]
# R^2 score:	 0.328277953715
# CDKN1A,0.328277953715
#
# 213
# Working on SGK1 mean/freq regression...
# Intercept:	 0.0193670196485
# Coefficients:	 [ 0.00184473]
# R^2 score:	 0.76562192081
# SGK1,0.76562192081
#
# 214
# Working on OAS1A mean/freq regression...
# Intercept:	 0.078088539805
# Coefficients:	 [ 0.00260603]
# R^2 score:	 0.596448958819
# OAS1A,0.596448958819
#
# 215
# Working on SQSTM1 mean/freq regression...
# Intercept:	 0.236500925334
# Coefficients:	 [ 0.00106704]
# R^2 score:	 0.428575468653
# SQSTM1,0.428575468653
#
# 216
# Working on RNF19B mean/freq regression...
# Intercept:	 0.16886559049
# Coefficients:	 [ 0.00265178]
# R^2 score:	 0.35666796144
# RNF19B,0.35666796144
#
# 217
# Working on SLC7A11 mean/freq regression...
# Intercept:	 0.697348371387
# Coefficients:	 [ 0.00141901]
# R^2 score:	 0.0466960943701
# SLC7A11,0.0466960943701
#
# 218
# Working on CD83 mean/freq regression...
# Intercept:	 0.0518008476748
# Coefficients:	 [ 0.00093237]
# R^2 score:	 0.571046415663
# CD83,0.571046415663
#
# 219
# Working on SAMSN1 mean/freq regression...
# Intercept:	 0.167102080429
# Coefficients:	 [ 0.00094329]
# R^2 score:	 0.500019807693
# SAMSN1,0.500019807693
#
# 220
# Working on MED21 mean/freq regression...
# Intercept:	 0.120637567886
# Coefficients:	 [ 0.00064205]
# R^2 score:	 0.0668198300083
# MED21,0.0668198300083
#
# 221
# Working on HK2 mean/freq regression...
# Intercept:	 0.164819540823
# Coefficients:	 [ 0.00289052]
# R^2 score:	 0.318166883546
# HK2,0.318166883546
#
# 222
# Working on PARP14 mean/freq regression...
# Intercept:	 0.0401670299123
# Coefficients:	 [ 0.00443328]
# R^2 score:	 0.760252826506
# PARP14,0.760252826506
#
# 223
# Working on GM6377 mean/freq regression...
# Intercept:	 0.0815418317139
# Coefficients:	 [ 0.0028396]
# R^2 score:	 0.388032760957
# GM6377,0.388032760957
#
# 224
# Working on CCL22 mean/freq regression...
# Intercept:	 0.0486275552467
# Coefficients:	 [ 0.00011242]
# R^2 score:	 0.535716768096
# CCL22,0.535716768096
#
# 225
# Working on BTG1 mean/freq regression...
# Intercept:	 0.994260362155
# Coefficients:	 [ 0.0007321]
# R^2 score:	 0.151249256479
# BTG1,0.151249256479
#
# 226
# Working on PDPN mean/freq regression...
# Intercept:	 0.0915193477104
# Coefficients:	 [ 0.00109298]
# R^2 score:	 0.360341857867
# PDPN,0.360341857867
#
# 227
# Working on SOD2 mean/freq regression...
# Intercept:	 0.300956818911
# Coefficients:	 [ 0.00348694]
# R^2 score:	 0.439035625703
# SOD2,0.439035625703
#
# 228
# Working on MNDAL mean/freq regression...
# Intercept:	 0.053379778235
# Coefficients:	 [ 0.00234725]
# R^2 score:	 0.753080458202
# MNDAL,0.753080458202
#
# 229
# Working on CXCL2 mean/freq regression...
# Intercept:	 0.15190186272
# Coefficients:	 [ 0.00053851]
# R^2 score:	 0.503008831073
# CXCL2,0.503008831073
#
# 230
# Working on PELI1 mean/freq regression...
# Intercept:	 0.0773710538861
# Coefficients:	 [ 0.0065073]
# R^2 score:	 0.6842301012
# PELI1,0.6842301012
#
# 231
# Working on NCK1 mean/freq regression...
# Intercept:	 0.0771162171838
# Coefficients:	 [ 0.00239468]
# R^2 score:	 0.467616398494
# NCK1,0.467616398494
#
# 232
# Working on GADD45B mean/freq regression...
# Intercept:	 0.0757876406789
# Coefficients:	 [ 0.00404018]
# R^2 score:	 0.720079454008
# GADD45B,0.720079454008
#
# 233
# Working on PSME2 mean/freq regression...
# Intercept:	 0.423194404523
# Coefficients:	 [ 0.00078201]
# R^2 score:	 0.385644216356
# PSME2,0.385644216356
#
# 234
# Working on CD14 mean/freq regression...
# Intercept:	 0.416901805098
# Coefficients:	 [ 0.00034713]
# R^2 score:	 0.224301638703
# CD14,0.224301638703
#
# 235
# Working on LGALS3BP mean/freq regression...
# Intercept:	 0.107107529736
# Coefficients:	 [ 0.00256112]
# R^2 score:	 0.637328024737
# LGALS3BP,0.637328024737
#
# 236
# Working on CLEC4D mean/freq regression...
# Intercept:	 0.209925189138
# Coefficients:	 [ 0.00093013]
# R^2 score:	 0.275686178005
# CLEC4D,0.275686178005
#
# 237
# Working on SNX10 mean/freq regression...
# Intercept:	 0.346692033596
# Coefficients:	 [ 0.00190631]
# R^2 score:	 0.135613361549
# SNX10,0.135613361549
#
# 238
# Working on BTG2 mean/freq regression...
# Intercept:	 0.0871221224155
# Coefficients:	 [ 0.00208011]
# R^2 score:	 0.193003620726
# BTG2,0.193003620726
#
# 239
# Working on NFKB1 mean/freq regression...
# Intercept:	 0.130823701905
# Coefficients:	 [ 0.00295467]
# R^2 score:	 0.492293538319
# NFKB1,0.492293538319
#
# 240
# Working on PSMB9 mean/freq regression...
# Intercept:	 0.086612850053
# Coefficients:	 [ 0.00210525]
# R^2 score:	 0.535377958956
# PSMB9,0.535377958956
#
# 241
# Working on RNASET2A mean/freq regression...
# Intercept:	 0.0829673221166
# Coefficients:	 [ 0.00219196]
# R^2 score:	 0.627230221402
# RNASET2A,0.627230221402
#
# 242
# Working on P2RY14 mean/freq regression...
# Intercept:	 0.14233556567
# Coefficients:	 [ 0.00131901]
# R^2 score:	 0.224507955792
# P2RY14,0.224507955792
#
# 243
# Working on RNF114 mean/freq regression...
# Intercept:	 0.0753746243102
# Coefficients:	 [ 0.00183991]
# R^2 score:	 0.518130429087
# RNF114,0.518130429087
#
# 244
# Working on TMEM219 mean/freq regression...
# Intercept:	 0.131249061984
# Coefficients:	 [ 0.00171607]
# R^2 score:	 0.278429988467
# TMEM219,0.278429988467
#
# 245
# Working on LY6C2 mean/freq regression...
# Intercept:	 0.0316841168212
# Coefficients:	 [ 0.00052429]
# R^2 score:	 0.427307208771
# LY6C2,0.427307208771
#
# 246
# Working on IL12B mean/freq regression...
# Intercept:	 0.0268512100688
# Coefficients:	 [ 0.00024284]
# R^2 score:	 0.793481301543
# IL12B,0.793481301543
#
# 247
# Working on F10 mean/freq regression...
# Intercept:	 0.119589976262
# Coefficients:	 [ 0.00120089]
# R^2 score:	 0.327980345139
# F10,0.327980345139
#
# 248
# Working on CASP7 mean/freq regression...
# Intercept:	 0.133736813957
# Coefficients:	 [ 0.00066786]
# R^2 score:	 0.0324955694415
# CASP7,0.0324955694415
#
# 249
# Working on MDM2 mean/freq regression...
# Intercept:	 0.0924571780677
# Coefficients:	 [ 0.00200512]
# R^2 score:	 0.388553821738
# MDM2,0.388553821738
#
# 250
# Working on KLF6 mean/freq regression...
# Intercept:	 0.665535421621
# Coefficients:	 [ 0.00144359]
# R^2 score:	 0.0580346496279
# KLF6,0.0580346496279
#
# 251
# Working on NUPR1 mean/freq regression...
# Intercept:	 0.0843632791457
# Coefficients:	 [ 0.00060321]
# R^2 score:	 0.438333628692
# NUPR1,0.438333628692
#
# 252
# Working on CASP11 mean/freq regression...
# Intercept:	 0.0657963332341
# Coefficients:	 [ 0.00199139]
# R^2 score:	 0.710295888736
# CASP11,0.710295888736
#
# 253
# Working on 2810474O19RIK mean/freq regression...
# Intercept:	 0.263646369306
# Coefficients:	 [ 0.004195]
# R^2 score:	 0.368737983391
# 2810474O19RIK,0.368737983391
#
# 254
# Working on HCK mean/freq regression...
# Intercept:	 0.0580036478834
# Coefficients:	 [ 0.00364583]
# R^2 score:	 0.4986864537
# HCK,0.4986864537
#
# 255
# Working on RAB8B mean/freq regression...
# Intercept:	 0.652634050999
# Coefficients:	 [ 0.00154133]
# R^2 score:	 0.107660749696
# RAB8B,0.107660749696
#
# 256
# Working on BCL2A1D mean/freq regression...
# Intercept:	 0.608992263677
# Coefficients:	 [ 0.0009815]
# R^2 score:	 0.332452246394
# BCL2A1D,0.332452246394
#
# 257
# Working on STXBP3A mean/freq regression...
# Intercept:	 0.160072223408
# Coefficients:	 [ 0.00257058]
# R^2 score:	 0.339750751533
# STXBP3A,0.339750751533
#
# 258
# Working on PFKP mean/freq regression...
# Intercept:	 0.135903949257
# Coefficients:	 [ 0.00321403]
# R^2 score:	 0.464981766648
# PFKP,0.464981766648
#
# 259
# Working on TANK mean/freq regression...
# Intercept:	 0.20134939782
# Coefficients:	 [ 0.00156894]
# R^2 score:	 0.400872954182
# TANK,0.400872954182
#
# 260
# Working on TGIF1 mean/freq regression...
# Intercept:	 0.113006970267
# Coefficients:	 [ 0.00186548]
# R^2 score:	 0.32872810039
# TGIF1,0.32872810039
#
# 261
# Working on PPP1R15A mean/freq regression...
# Intercept:	 0.0929811006732
# Coefficients:	 [ 0.00177346]
# R^2 score:	 0.3550095477
# PPP1R15A,0.3550095477
#
# 262
# Working on SEPW1 mean/freq regression...
# Intercept:	 0.329470428358
# Coefficients:	 [ 0.0020017]
# R^2 score:	 0.259878998757
# SEPW1,0.259878998757
#
# 263
# Working on PLAUR mean/freq regression...
# Intercept:	 0.104275806041
# Coefficients:	 [ 0.00143061]
# R^2 score:	 0.546370984027
# PLAUR,0.546370984027
#
# 264
# Working on H2-M2 mean/freq regression...
# Intercept:	 -0.0324600444306
# Coefficients:	 [ 0.00050187]
# R^2 score:	 0.676866776497
# H2-M2,0.676866776497
#
# 265
# Working on BATF mean/freq regression...
# Intercept:	 0.0227063126788
# Coefficients:	 [ 0.00195982]
# R^2 score:	 0.637727922496
# BATF,0.637727922496
#
# 266
# Working on NUP62-IL4I1 mean/freq regression...
# Intercept:	 0.000211621547876
# Coefficients:	 [ 0.00156945]
# R^2 score:	 0.759598080597
# NUP62-IL4I1,0.759598080597
#
# 267
# Working on TNFAIP2 mean/freq regression...
# Intercept:	 0.421345754387
# Coefficients:	 [ 0.00188205]
# R^2 score:	 0.421917019733
# TNFAIP2,0.421917019733
#
# 268
# Working on FNDC3A mean/freq regression...
# Intercept:	 0.180914154143
# Coefficients:	 [ 0.00259639]
# R^2 score:	 0.151445669489
# FNDC3A,0.151445669489
#
# 269
# Working on TREX1 mean/freq regression...
# Intercept:	 -0.0125006212641
# Coefficients:	 [ 0.00193382]
# R^2 score:	 0.790353924045
# TREX1,0.790353924045
#
# 270
# Working on RAB9 mean/freq regression...
# Intercept:	 0.135285172611
# Coefficients:	 [ 0.00178281]
# R^2 score:	 0.164828529017
# RAB9,0.164828529017
#
# 271
# Working on BCL2A1A mean/freq regression...
# Intercept:	 0.519602916905
# Coefficients:	 [ 0.00121365]
# R^2 score:	 0.356192005748
# BCL2A1A,0.356192005748
#
# 272
# Working on PDE4B mean/freq regression...
# Intercept:	 0.151789887089
# Coefficients:	 [ 0.00356395]
# R^2 score:	 0.368769574306
# PDE4B,0.368769574306
#
# 273
# Working on PIK3R5 mean/freq regression...
# Intercept:	 0.249450821248
# Coefficients:	 [ 0.00319188]
# R^2 score:	 0.247486689921
# PIK3R5,0.247486689921
#
# 274
# Working on RND3 mean/freq regression...
# Intercept:	 0.0793947875132
# Coefficients:	 [ 0.00480548]
# R^2 score:	 0.533874128042
# RND3,0.533874128042
#
# 275
# Working on CD44 mean/freq regression...
# Intercept:	 0.397348614047
# Coefficients:	 [ 0.00235421]
# R^2 score:	 0.282675534339
# CD44,0.282675534339
#
# 276
# Working on AK172683 mean/freq regression...
# Intercept:	 0.0228629349404
# Coefficients:	 [ 0.00890473]
# R^2 score:	 0.733620717999
# AK172683,0.733620717999
#
# 277
# Working on ARL5C mean/freq regression...
# Intercept:	 0.234708784638
# Coefficients:	 [ 0.00134423]
# R^2 score:	 0.122665574938
# ARL5C,0.122665574938
#
# 278
# Working on IER3 mean/freq regression...
# Intercept:	 0.0474029599204
# Coefficients:	 [ 0.00209613]
# R^2 score:	 0.384924578196
# IER3,0.384924578196
#
# 279
# Working on GTF2B mean/freq regression...
# Intercept:	 0.00499083204375
# Coefficients:	 [ 0.00303975]
# R^2 score:	 0.506828922789
# GTF2B,0.506828922789
#
# 280
# Working on ANXA7 mean/freq regression...
# Intercept:	 0.11818734037
# Coefficients:	 [ 0.00329661]
# R^2 score:	 0.381298237625
# ANXA7,0.381298237625
#
# 281
# Working on TXNRD1 mean/freq regression...
# Intercept:	 0.115027595565
# Coefficients:	 [ 0.00635096]
# R^2 score:	 0.383866972693
# TXNRD1,0.383866972693
#
# 282
# Working on HIF1A mean/freq regression...
# Intercept:	 0.10167804812
# Coefficients:	 [ 0.00616491]
# R^2 score:	 0.283066997234
# HIF1A,0.283066997234
#
# 283
# Working on MARCKSL1 mean/freq regression...
# Intercept:	 0.0799684722833
# Coefficients:	 [ 0.00223295]
# R^2 score:	 0.551625439988
# MARCKSL1,0.551625439988
#
# 284
# Working on PLK2 mean/freq regression...
# Intercept:	 -0.0186731002771
# Coefficients:	 [ 0.00390716]
# R^2 score:	 0.774422833538
# PLK2,0.774422833538
#
# 285
# Working on CFLAR mean/freq regression...
# Intercept:	 0.0198315402732
# Coefficients:	 [ 0.00536237]
# R^2 score:	 0.682602223796
# CFLAR,0.682602223796
#
# 286
# Working on G530011O06RIK mean/freq regression...
# Intercept:	 0.0566937231608
# Coefficients:	 [ 0.00222025]
# R^2 score:	 0.539627571821
# G530011O06RIK,0.539627571821
#
# 287
# Working on B3GNT2 mean/freq regression...
# Intercept:	 0.18496490895
# Coefficients:	 [ 0.00128036]
# R^2 score:	 0.0322548564904
# B3GNT2,0.0322548564904
#
# 288
# Working on MTPN mean/freq regression...
# Intercept:	 0.459841788019
# Coefficients:	 [ 0.00250917]
# R^2 score:	 0.243633833351
# MTPN,0.243633833351
#
# 289
# Working on PSMB10 mean/freq regression...
# Intercept:	 0.20774143738
# Coefficients:	 [ 0.00190538]
# R^2 score:	 0.131976513708
# PSMB10,0.131976513708
#
# 290
# Working on PTPRE mean/freq regression...
# Intercept:	 0.197580111129
# Coefficients:	 [ 0.00290432]
# R^2 score:	 0.100882128277
# PTPRE,0.100882128277
#
# 291
# Working on MKIAA0694 mean/freq regression...
# Intercept:	 0.173856964163
# Coefficients:	 [ 0.00286959]
# R^2 score:	 0.272150054538
# MKIAA0694,0.272150054538
#
# 292
# Working on OLR1 mean/freq regression...
# Intercept:	 0.0719395575295
# Coefficients:	 [ 0.00268846]
# R^2 score:	 0.528141064837
# OLR1,0.528141064837
#
# 293
# Working on CCNL1 mean/freq regression...
# Intercept:	 0.27126022412
# Coefficients:	 [ 0.00289311]
# R^2 score:	 0.223744156036
# CCNL1,0.223744156036
#
# 294
# Working on AA467197 mean/freq regression...
# Intercept:	 0.531764924479
# Coefficients:	 [ 0.00043327]
# R^2 score:	 0.341892866581
# AA467197,0.341892866581
#
# 295
# Working on DNAJB6 mean/freq regression...
# Intercept:	 0.417767150415
# Coefficients:	 [ 0.00086727]
# R^2 score:	 0.0207331079272
# DNAJB6,0.0207331079272
#
# 296
# Working on EHD1 mean/freq regression...
# Intercept:	 0.118138547621
# Coefficients:	 [ 0.00604824]
# R^2 score:	 0.435052682805
# EHD1,0.435052682805
#
# 297
# Working on H3F3B mean/freq regression...
# Intercept:	 0.751869126539
# Coefficients:	 [ 0.00093304]
# R^2 score:	 0.157072915074
# H3F3B,0.157072915074
#
# 298
# Working on SLC15A3 mean/freq regression...
# Intercept:	 0.189503281166
# Coefficients:	 [ 0.00255447]
# R^2 score:	 0.176676781126
# SLC15A3,0.176676781126
#
# 299
# Working on NFKBIB mean/freq regression...
# Intercept:	 0.0764940192919
# Coefficients:	 [ 0.00318305]
# R^2 score:	 0.486314479428
# NFKBIB,0.486314479428
#
# 300
# Working on JAK2 mean/freq regression...
# Intercept:	 0.138152220725
# Coefficients:	 [ 0.00376705]
# R^2 score:	 0.277993707084
# JAK2,0.277993707084
#
# 301
# Working on PLEK mean/freq regression...
# Intercept:	 0.0508398036427
# Coefficients:	 [ 0.00237368]
# R^2 score:	 0.498266998046
# PLEK,0.498266998046
#
# 302
# Working on RAP1B mean/freq regression...
# Intercept:	 0.254671871347
# Coefficients:	 [ 0.00214483]
# R^2 score:	 0.231173668303
# RAP1B,0.231173668303
#
# 303
# Working on SLC3A2 mean/freq regression...
# Intercept:	 0.46863503531
# Coefficients:	 [ 0.00169578]
# R^2 score:	 0.0856995690292
# SLC3A2,0.0856995690292
#
# 304
# Working on PGAP2 mean/freq regression...
# Intercept:	 0.052364907412
# Coefficients:	 [ 0.00210304]
# R^2 score:	 0.42491968091
# PGAP2,0.42491968091
#
# 305
# Working on ALCAM mean/freq regression...
# Intercept:	 0.203440149613
# Coefficients:	 [ 0.00639665]
# R^2 score:	 0.234124819548
# ALCAM,0.234124819548
#
# 306
# Working on UBC mean/freq regression...
# Intercept:	 0.500464180409
# Coefficients:	 [ 0.00031007]
# R^2 score:	 0.218645932671
# UBC,0.218645932671
#
# 307
# Working on TFG mean/freq regression...
# Intercept:	 0.0692606503524
# Coefficients:	 [ 0.0033752]
# R^2 score:	 0.406218743404
# TFG,0.406218743404
#
# 308
# Working on PILRA mean/freq regression...
# Intercept:	 0.0819321682412
# Coefficients:	 [ 0.00353686]
# R^2 score:	 0.367593200022
# PILRA,0.367593200022
#
# 309
# Working on PSME1 mean/freq regression...
# Intercept:	 0.454587803762
# Coefficients:	 [ 0.00084112]
# R^2 score:	 0.17126050213
# PSME1,0.17126050213
#
# 310
# Working on DAB2 mean/freq regression...
# Intercept:	 -0.0148994228085
# Coefficients:	 [ 0.00615666]
# R^2 score:	 0.787493012435
# DAB2,0.787493012435
#
# 311
# Working on AK142678 mean/freq regression...
# Intercept:	 0.181621227366
# Coefficients:	 [ 0.00052564]
# R^2 score:	 0.0217300712899
# AK142678,0.0217300712899
#
# 312
# Working on PNRC1 mean/freq regression...
# Intercept:	 0.116020287352
# Coefficients:	 [ 0.00377905]
# R^2 score:	 0.239198224424
# PNRC1,0.239198224424
#
# 313
# Working on SKIL mean/freq regression...
# Intercept:	 0.0242526510435
# Coefficients:	 [ 0.00988757]
# R^2 score:	 0.554680940317
# SKIL,0.554680940317
#
# 314
# Working on SAT1 mean/freq regression...
# Intercept:	 0.76057329096
# Coefficients:	 [ 0.00036476]
# R^2 score:	 0.0291370554795
# SAT1,0.0291370554795
#
# 315
# Working on BCL2A1B mean/freq regression...
# Intercept:	 -0.129844027943
# Coefficients:	 [ 0.00126596]
# R^2 score:	 0.361710687253
# BCL2A1B,0.361710687253
#
# 316
# Working on GNA13 mean/freq regression...
# Intercept:	 0.0856663704921
# Coefficients:	 [ 0.00572934]
# R^2 score:	 0.378077194054
# GNA13,0.378077194054
#
# 317
# Working on NRP2 mean/freq regression...
# Intercept:	 0.170841249488
# Coefficients:	 [ 0.00478607]
# R^2 score:	 0.228543923933
# NRP2,0.228543923933
#
# 318
# Working on NAMPT mean/freq regression...
# Intercept:	 0.418854043849
# Coefficients:	 [ 0.00113279]
# R^2 score:	 0.0636621375031
# NAMPT,0.0636621375031
#
# 319
# Working on ISG15 mean/freq regression...
# Intercept:	 0.0662582714304
# Coefficients:	 [ 0.00426904]
# R^2 score:	 0.619307432065
# ISG15,0.619307432065
#
# 320
# Working on FAM102B mean/freq regression...
# Intercept:	 0.0435101794951
# Coefficients:	 [ 0.00576342]
# R^2 score:	 0.507534567577
# FAM102B,0.507534567577
#
# 321
# Working on BCL2A1C mean/freq regression...
# Intercept:	 0.213962400209
# Coefficients:	 [ 0.00525946]
# R^2 score:	 0.419905503067
# BCL2A1C,0.419905503067
#
# 322
# Working on BIRC6 mean/freq regression...
# Intercept:	 0.228959130205
# Coefficients:	 [ 0.00190736]
# R^2 score:	 0.092045900469
# BIRC6,0.092045900469
#
# 323
# Working on RGS1 mean/freq regression...
# Intercept:	 -0.248110981994
# Coefficients:	 [ 0.00132034]
# R^2 score:	 0.733726420742
# RGS1,0.733726420742

# %%
print(scoreAll)
# Out:
# 0.775844304301

# %%
print(max(summary_stats['Mean']))
# Out:
# 1118.170156

# %%
print(lm.intercept_)
# Out:
# 37967.2236598
