# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn import linear_model
from statsmodels.formula.api import ols

induced_data = pd.read_csv('induced_genes_outliers_removed_all_zero_removed.csv')
induced_data = induced_data.iloc[:,1:]

#grp1 = ['IFITM3','SRGN','IL1RN','IFI27L2A','TNF','IFI205','TARM1','TNFSF9','IRG1','GLIPR2','INHBA','BTG1','PSME2','CLEC4E','2310016C08RIK','SQSTM1','NFKBIA','USP18','EBI3','CD86','MS4A6D','NT5C3','FPR2','H3F3B','SERPINA3G','CAV1','FAS','MS4A6C','LGALS9','GM4902','CD200','IFI204','CISH','PROCR','SLAMF7','AI607873','SGK1','IL15','ACPP','CXCL16','SLFN2','H2-Q7','MT2','H2-T23','THBS1','UBE2L6','AY096003','H1F0','ATF3','TANK','TNFSF15','HSPA5','IL15RA','IRF1','MED21','IRGM1','CCRL2','ZBP1','CASP1','RAB32','SP100','IRF8','BLNK','PSMB9','PCGF5','KTELC1','RILPL2','TMEM39A','TRIM30A','TNIP3','RBM7','SLC2A6','GBP3','BIRC3','TLR2','GTF2B','CFB','SBDS','CAR13','ARF4','SEPW1','BST2','NMI','DUSP1','PYHIN1','CD47','ZFP36','CD274','SAMHD1','SWAP70','IL7R','RELA','AK042010','A130040M12RIK','D14ERTD668E','NFKBIZ','ADAP2','XAF1','PNP','ZUFSP','IFI35','ACSL1','ANXA7','SLC7A2','HERC6','TAPBP','SLFN5','SLFN8','IFIH1','FGL2','LCP2','STAT1','GBP5','TRIM30D','LAP3','STAT5A','GBP6','DDX58','CLIC4','DHX58','STAT2','TNFAIP3','TAP1','ELL2','PIK3R5','PARP9','KPNA3','HIF1A','AFTPH','DTX3L']
#grp2 = ['SDC4','CXCL1','IL1A','CXCL3','IL1B','CCL3','AW112010','CCL17','PRDX1','CCL4','H2-M2']
#with open("global_regressions/summary.csv","w") as logfile:
#    logfile.write("gene,scoreAll\n")


#glist=['CCL5','CCL17','AK217941','AK138792','PRDX1','CXCL10','APOL7C','AW112010','IL1B','CXCL1','CCL3','SDC4','H2-M2','LY6C2','CLU','IL1A','ZDHHC21','CXCL3','CCR7','CD14','CD69','BCL2A1B','IFI27L2A','SLPI','SERPINB9','IFITM3','AA467197','GLIPR2','MX1','TNF','TARM1','BCL2A1D','CLEC4D','IRG1','CD40','BCL2A1A','USP18','SAMSN1','CLEC4E','CAR4','1810029B16RIK','CD86','SQSTM1','SERPINB6B','RNASET2B','MS4A6D','NUPR1','P2RY14','2310016C08RIK','H2-Q7','FOS','GBP2','CDKN1A','NFKBIA','FPR1','EBI3','FPR2','SAMHD1','UBE2L6','IFIT2','MS4A6C','ARF4','STXBP3A','AY096003','EPSTI1','TNIP3','AI607873','SLAMF7','CD200','RAB8B','MT2','SLFN2','HSPA5','BIRC3','IRGM1','MARCKSL1','TMEM39A','ETV3','TREX1','PROCR','BLNK','RELA','RTP4','CCRL2','TRIM30A','BHLHE40','PLAUR','KYNU','TLR2','BST2','SWAP70','ZBP1','SP100','GBP3','PCGF5','KTELC1','IRF8','IGTP','SOD2','CISH','TNFSF15','MNDAL','CFB','PLEK','PNP','ZFP36','NMI','SLC2A6','H1F0','SBDS','XAF1','NFKBIZ','TRAF1','PYHIN1','MTPN','SLC7A2','APOBEC3','CD274','TAPBP','LGALS3BP','KTN1','PPP1CB','ZUFSP','PTTG1','IFIH1','GM4951','BATF','ADAP2','IFI203','IFI35','GADD45B','PELI1','STAT1','LCP2','STAT2','GBP6','KPNA3','SLFN5','GBP5','PFKP','TAP1','TOR3A','INSIG1','DAB2','AFTPH','TXNRD1']

regression_data=pd.read_csv('summary_mean_var_all_cond.csv')
glist=regression_data.iloc[:,0].tolist();

# %%
x
# Out:
# array([  3.04802783e+01,   4.54950095e+02,   8.38031117e+02,
#          7.10301238e+02,   9.72864922e+02,   1.41244583e+02,
#          1.08086040e+03,   8.14579840e+02,   2.01483062e+02,
#          3.21550343e+02,   1.18444405e+01,   4.50396451e+01,
#          1.57874524e+03,   2.02917395e+02,   1.01740475e+02,
#          1.59641919e+03,   2.87951322e-01,   2.90803889e+03,
#          3.32398058e+02,   1.08762771e+03,   4.85120121e+01,
#          1.74788576e+03,   2.64619210e+03,   1.52172552e+03,
#          8.73531625e+00,   4.56399480e+02])

# %%
#print(induced_data.head)

#genelist = induced_data.iloc[:,0].reset_index(drop=True).drop_duplicates().tolist()
#genelist += [genelist.pop(24)] #manually moving index 24 TNF to end so visible on plots

i=0

plt.subplots(1,1,figsize=(5,4.5))
axes = plt.gca()
axes.set_xlim([0,3000])
axes.set_ylim([0,4])

with open("my_summary_mean_freq_all_conds_robust.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % ('gene','N','intercept','slope','min x','max x','R2'))



for test_gene in glist:
    i+=1
    print(i)
    summary_stats = induced_data[induced_data["Gene"]==test_gene]
    #print(summary_stats)
    if (len(summary_stats.loc[summary_stats['Mean'] == 0,['Mean']])>0) :
        print("Missing data for %s" % test_gene)
        with open("errorlog.csv","a") as logfile:
            logfile.write("%s\n" % test_gene)
        continue
    
    print("Working on %s mean/freq regression..." % test_gene)
    

    x=np.ravel(summary_stats['Mean'].values.reshape(-1, 1))
    #print(x)
    y=np.ravel(summary_stats['Frequency'].values.reshape(-1, 1))
    x=x.reshape(-1, 1)
    y=y.reshape(-1, 1)
    
    lm = linear_model.LinearRegression()
    model = lm.fit(x,y)
    
    Fy=lm.predict(x)
    Residuals=y-Fy;   
    I = abs( Residuals) < 1.5 * np.std(Residuals);
    x1=x[I==True]
    y1=y[I==True]
    x1=x1.reshape(-1, 1)
    y1=y1.reshape(-1, 1)
    
    model = lm.fit(x1,y1)
    print("Intercept:\t",lm.intercept_)
    print("Coefficients:\t",lm.coef_)
    scoreAll = lm.score(x1,y1)
    print("R^2 score:\t",scoreAll)

    linecol = 'gray'

    """
    if(test_gene == 'TNF') :
        linecol = 'red'
    elif(test_gene == 'IL1A'):
        linecol = 'blue'
    elif(test_gene == 'IL1B'):
        linecol = 'green'
    elif(test_gene == 'CCL4'):
        linecol = 'orange'
    elif(test_gene == 'CCL17'):
        linecol = 'purple'
    """
    
    #if test_gene in glist:
        
    plt.plot(x1, lm.predict(x1), color=linecol, linewidth=1)

    with open("my_summary_mean_freq_all_conds_robust.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % (test_gene,len(x1),float(lm.intercept_),float(lm.coef_),float(min(x1)), float(max(x1)), scoreAll))
        print("%s,%s\n" % (test_gene,scoreAll))

plt.ylabel("Freq")
plt.xlabel("Mean")
#plt.savefig("global_regressions/mean_var_composite.png")
plt.savefig("my_mean_freq_allconds_robust.png")
plt.close()
# Out:
# 1
# Working on CXCL1 mean/freq regression...
# Intercept:	 [ 0.03611044]
# Coefficients:	 [[ 0.00019401]]
# R^2 score:	 0.967931043116
# CXCL1,0.967931043116
#
# 2
# Working on RSAD2 mean/freq regression...
# Intercept:	 [ 0.09068904]
# Coefficients:	 [[ 0.00066543]]
# R^2 score:	 0.970177018088
# RSAD2,0.970177018088
#
# 3
# Working on OASL1 mean/freq regression...
# Intercept:	 [ 0.04474974]
# Coefficients:	 [[ 0.00153364]]
# R^2 score:	 0.981545726973
# OASL1,0.981545726973
#
# 4
# Working on NT5C3 mean/freq regression...
# Intercept:	 [ 0.06794898]
# Coefficients:	 [[ 0.00139625]]
# R^2 score:	 0.972266642735
# NT5C3,0.972266642735
#
# 5
# Working on CCL4 mean/freq regression...
# Intercept:	 [ 0.06270197]
# Coefficients:	 [[  7.11916434e-05]]
# R^2 score:	 0.972681325753
# CCL4,0.972681325753
#
# 6
# Working on EBI3 mean/freq regression...
# Intercept:	 [ 0.09529567]
# Coefficients:	 [[ 0.00092637]]
# R^2 score:	 0.85121056209
# EBI3,0.85121056209
#
# 7
# Working on IRGM1 mean/freq regression...
# Intercept:	 [ 0.07593068]
# Coefficients:	 [[ 0.00193886]]
# R^2 score:	 0.962285096376
# IRGM1,0.962285096376
#
# 8
# Working on IFIT2 mean/freq regression...
# Intercept:	 [ 0.0402103]
# Coefficients:	 [[ 0.00183466]]
# R^2 score:	 0.987263676056
# IFIT2,0.987263676056
#
# 9
# Working on PYHIN1 mean/freq regression...
# Intercept:	 [ 0.06220989]
# Coefficients:	 [[ 0.00305345]]
# R^2 score:	 0.987180284509
# PYHIN1,0.987180284509
#
# 10
# Working on CAR4 mean/freq regression...
# Intercept:	 [ 0.01645727]
# Coefficients:	 [[ 0.00100714]]
# R^2 score:	 0.967155501053
# CAR4,0.967155501053
#
# 11
# Working on SLFN8 mean/freq regression...
# Intercept:	 [ 0.04465133]
# Coefficients:	 [[ 0.00409578]]
# R^2 score:	 0.952696352637
# SLFN8,0.952696352637
#
# 12
# Working on AW112010 mean/freq regression...
# Intercept:	 [ 0.13843475]
# Coefficients:	 [[ 0.00019931]]
# R^2 score:	 0.954379082363
# AW112010,0.954379082363
#
# 13
# Working on U90926 mean/freq regression...
# Intercept:	 [ 0.01743364]
# Coefficients:	 [[ 0.00014582]]
# R^2 score:	 0.665567176205
# U90926,0.665567176205
#
# 14
# Working on IL15 mean/freq regression...
# Intercept:	 [ 0.04269846]
# Coefficients:	 [[ 0.00178625]]
# R^2 score:	 0.956603479794
# IL15,0.956603479794
#
# 15
# Working on GM4902 mean/freq regression...
# Intercept:	 [ 0.06113387]
# Coefficients:	 [[ 0.0015832]]
# R^2 score:	 0.951574237003
# GM4902,0.951574237003
#
# 16
# Working on GM14446 mean/freq regression...
# Intercept:	 [ 0.02141564]
# Coefficients:	 [[ 0.00054963]]
# R^2 score:	 0.947671658376
# GM14446,0.947671658376
#
# 17
# Working on FAM26F mean/freq regression...
# Intercept:	 [ 0.01740447]
# Coefficients:	 [[ 0.00248766]]
# R^2 score:	 0.926370970524
# FAM26F,0.926370970524
#
# 18
# Working on D14ERTD668E mean/freq regression...
# Intercept:	 [ 0.0403518]
# Coefficients:	 [[ 0.00307441]]
# R^2 score:	 0.824966059666
# D14ERTD668E,0.824966059666
#
# 19
# Working on GM4951 mean/freq regression...
# Intercept:	 [ 0.02475303]
# Coefficients:	 [[ 0.00287639]]
# R^2 score:	 0.971690249171
# GM4951,0.971690249171
#
# 20
# Working on FGL2 mean/freq regression...
# Intercept:	 [ 0.08337225]
# Coefficients:	 [[ 0.0034698]]
# R^2 score:	 0.88490671549
# FGL2,0.88490671549
#
# 21
# Working on APOL7C mean/freq regression...
# Intercept:	 [ 0.03482205]
# Coefficients:	 [[ 0.00019568]]
# R^2 score:	 0.828166949888
# APOL7C,0.828166949888
#
# 22
# Working on TRIM30A mean/freq regression...
# Intercept:	 [ 0.05970993]
# Coefficients:	 [[ 0.00232955]]
# R^2 score:	 0.977097728934
# TRIM30A,0.977097728934
#
# 23
# Working on CCL3 mean/freq regression...
# Intercept:	 [ 0.1510662]
# Coefficients:	 [[ 0.000141]]
# R^2 score:	 0.802531157826
# CCL3,0.802531157826
#
# 24
# Working on CXCL3 mean/freq regression...
# Intercept:	 [ 0.07568166]
# Coefficients:	 [[ 0.00020273]]
# R^2 score:	 0.922238321295
# CXCL3,0.922238321295
#
# 25
# Working on CFB mean/freq regression...
# Intercept:	 [ 0.02548467]
# Coefficients:	 [[ 0.0024045]]
# R^2 score:	 0.892390302593
# CFB,0.892390302593
#
# 26
# Working on TMEM39A mean/freq regression...
# Intercept:	 [ 0.06174451]
# Coefficients:	 [[ 0.00188474]]
# R^2 score:	 0.876130671555
# TMEM39A,0.876130671555
#
# 27
# Working on CCND2 mean/freq regression...
# Intercept:	 [ 0.08475808]
# Coefficients:	 [[ 0.00186895]]
# R^2 score:	 0.917702748311
# CCND2,0.917702748311
#
# 28
# Working on MS4A6C mean/freq regression...
# Intercept:	 [ 0.04585905]
# Coefficients:	 [[ 0.0013213]]
# R^2 score:	 0.9154018465
# MS4A6C,0.9154018465
#
# 29
# Working on IRG1 mean/freq regression...
# Intercept:	 [ 0.0641245]
# Coefficients:	 [[ 0.00087044]]
# R^2 score:	 0.939665268659
# IRG1,0.939665268659
#
# 30
# Working on CCR7 mean/freq regression...
# Intercept:	 [ 0.0231043]
# Coefficients:	 [[ 0.00043991]]
# R^2 score:	 0.947447994306
# CCR7,0.947447994306
#
# 31
# Working on USP18 mean/freq regression...
# Intercept:	 [ 0.05936849]
# Coefficients:	 [[ 0.00119778]]
# R^2 score:	 0.956838615877
# USP18,0.956838615877
#
# 32
# Working on IFIT3 mean/freq regression...
# Intercept:	 [ 0.02115946]
# Coefficients:	 [[ 0.00087278]]
# R^2 score:	 0.992296632583
# IFIT3,0.992296632583
#
# 33
# Working on ACPP mean/freq regression...
# Intercept:	 [ 0.09140473]
# Coefficients:	 [[ 0.0014304]]
# R^2 score:	 0.838557222865
# ACPP,0.838557222865
#
# 34
# Working on ACSL1 mean/freq regression...
# Intercept:	 [ 0.12856902]
# Coefficients:	 [[ 0.00232709]]
# R^2 score:	 0.63989077027
# ACSL1,0.63989077027
#
# 35
# Working on STAT5A mean/freq regression...
# Intercept:	 [ 0.10713725]
# Coefficients:	 [[ 0.00429703]]
# R^2 score:	 0.893111471617
# STAT5A,0.893111471617
#
# 36
# Working on TNFSF9 mean/freq regression...
# Intercept:	 [ 0.05104829]
# Coefficients:	 [[ 0.00067808]]
# R^2 score:	 0.896255295053
# TNFSF9,0.896255295053
#
# 37
# Working on CD40 mean/freq regression...
# Intercept:	 [ 0.07609242]
# Coefficients:	 [[ 0.00077285]]
# R^2 score:	 0.938669818303
# CD40,0.938669818303
#
# 38
# Working on IFI205 mean/freq regression...
# Intercept:	 [ 0.07638413]
# Coefficients:	 [[ 0.0008213]]
# R^2 score:	 0.909863663377
# IFI205,0.909863663377
#
# 39
# Working on MS4A4C mean/freq regression...
# Intercept:	 [ 0.02476276]
# Coefficients:	 [[ 0.00122041]]
# R^2 score:	 0.827937403486
# MS4A4C,0.827937403486
#
# 40
# Working on TARM1 mean/freq regression...
# Intercept:	 [ 0.0705902]
# Coefficients:	 [[ 0.00064246]]
# R^2 score:	 0.810588097455
# TARM1,0.810588097455
#
# 41
# Working on NUDT17 mean/freq regression...
# Intercept:	 [ 0.03349344]
# Coefficients:	 [[ 0.001263]]
# R^2 score:	 0.899252914401
# NUDT17,0.899252914401
#
# 42
# Working on AFTPH mean/freq regression...
# Intercept:	 [ 0.09712059]
# Coefficients:	 [[ 0.00601067]]
# R^2 score:	 0.908959681431
# AFTPH,0.908959681431
#
# 43
# Working on IRF7 mean/freq regression...
# Intercept:	 [ 0.02766265]
# Coefficients:	 [[ 0.00270211]]
# R^2 score:	 0.907839383595
# IRF7,0.907839383595
#
# 44
# Working on TLR2 mean/freq regression...
# Intercept:	 [ 0.07160455]
# Coefficients:	 [[ 0.00237809]]
# R^2 score:	 0.874832358673
# TLR2,0.874832358673
#
# 45
# Working on IL15RA mean/freq regression...
# Intercept:	 [ 0.0515163]
# Coefficients:	 [[ 0.00188876]]
# R^2 score:	 0.927536820765
# IL15RA,0.927536820765
#
# 46
# Working on INHBA mean/freq regression...
# Intercept:	 [ 0.04712882]
# Coefficients:	 [[ 0.00085377]]
# R^2 score:	 0.890840970468
# INHBA,0.890840970468
#
# 47
# Working on IIGP1 mean/freq regression...
# Intercept:	 [ 0.04101373]
# Coefficients:	 [[ 0.00226305]]
# R^2 score:	 0.839468471347
# IIGP1,0.839468471347
#
# 48
# Working on TRIM30D mean/freq regression...
# Intercept:	 [ 0.05186062]
# Coefficients:	 [[ 0.0046685]]
# R^2 score:	 0.954927528064
# TRIM30D,0.954927528064
#
# 49
# Working on TIMP1 mean/freq regression...
# Intercept:	 [ 0.02365366]
# Coefficients:	 [[ 0.000819]]
# R^2 score:	 0.80774652571
# TIMP1,0.80774652571
#
# 50
# Working on CCL7 mean/freq regression...
# Intercept:	 [ 0.01352771]
# Coefficients:	 [[ 0.00015509]]
# R^2 score:	 0.611745511199
# CCL7,0.611745511199
#
# 51
# Working on SRGN mean/freq regression...
# Intercept:	 [ 0.12386226]
# Coefficients:	 [[ 0.00073318]]
# R^2 score:	 0.923829195116
# SRGN,0.923829195116
#
# 52
# Working on IL1A mean/freq regression...
# Intercept:	 [ 0.09075183]
# Coefficients:	 [[ 0.00030712]]
# R^2 score:	 0.872291319931
# IL1A,0.872291319931
#
# 53
# Working on SERPINA3G mean/freq regression...
# Intercept:	 [ 0.02386472]
# Coefficients:	 [[ 0.001245]]
# R^2 score:	 0.905108269615
# SERPINA3G,0.905108269615
#
# 54
# Working on TAP1 mean/freq regression...
# Intercept:	 [ 0.05949084]
# Coefficients:	 [[ 0.00483684]]
# R^2 score:	 0.888586533958
# TAP1,0.888586533958
#
# 55
# Working on SLAMF7 mean/freq regression...
# Intercept:	 [ 0.08847649]
# Coefficients:	 [[ 0.00164206]]
# R^2 score:	 0.906446781089
# SLAMF7,0.906446781089
#
# 56
# Working on IFIT1 mean/freq regression...
# Intercept:	 [ 0.03727575]
# Coefficients:	 [[ 0.00105164]]
# R^2 score:	 0.943645176582
# IFIT1,0.943645176582
#
# 57
# Working on CISH mean/freq regression...
# Intercept:	 [ 0.05765741]
# Coefficients:	 [[ 0.00161228]]
# R^2 score:	 0.909336770132
# CISH,0.909336770132
#
# 58
# Working on FAS mean/freq regression...
# Intercept:	 [ 0.08709204]
# Coefficients:	 [[ 0.00105685]]
# R^2 score:	 0.788680802941
# FAS,0.788680802941
#
# 59
# Working on CXCL10 mean/freq regression...
# Intercept:	 [ 0.07324279]
# Coefficients:	 [[ 0.00017709]]
# R^2 score:	 0.94545545766
# CXCL10,0.94545545766
#
# 60
# Working on SLFN5 mean/freq regression...
# Intercept:	 [ 0.09230309]
# Coefficients:	 [[ 0.00394454]]
# R^2 score:	 0.931898739527
# SLFN5,0.931898739527
#
# 61
# Working on SLC2A6 mean/freq regression...
# Intercept:	 [ 0.17909454]
# Coefficients:	 [[ 0.00183664]]
# R^2 score:	 0.765883691883
# SLC2A6,0.765883691883
#
# 62
# Working on CMPK2 mean/freq regression...
# Intercept:	 [ 0.05215136]
# Coefficients:	 [[ 0.00166386]]
# R^2 score:	 0.925137617119
# CMPK2,0.925137617119
#
# 63
# Working on PCGF5 mean/freq regression...
# Intercept:	 [ 0.08590157]
# Coefficients:	 [[ 0.00145453]]
# R^2 score:	 0.685428786465
# PCGF5,0.685428786465
#
# 64
# Working on CAR13 mean/freq regression...
# Intercept:	 [ 0.06835578]
# Coefficients:	 [[ 0.00223354]]
# R^2 score:	 0.719144248533
# CAR13,0.719144248533
#
# 65
# Working on GBP3 mean/freq regression...
# Intercept:	 [ 0.05947676]
# Coefficients:	 [[ 0.00250046]]
# R^2 score:	 0.895689705383
# GBP3,0.895689705383
#
# 66
# Working on UBE2L6 mean/freq regression...
# Intercept:	 [ 0.0483331]
# Coefficients:	 [[ 0.00188926]]
# R^2 score:	 0.912630901917
# UBE2L6,0.912630901917
#
# 67
# Working on MX2 mean/freq regression...
# Intercept:	 [ 0.01880572]
# Coefficients:	 [[ 0.00281417]]
# R^2 score:	 0.940048573667
# MX2,0.940048573667
#
# 68
# Working on ZDHHC21 mean/freq regression...
# Intercept:	 [ 0.54202613]
# Coefficients:	 [[-0.00498694]]
# R^2 score:	 0.35572725725
# ZDHHC21,0.35572725725
#
# 69
# Working on AK138792 mean/freq regression...
# Intercept:	 [ 0.41502566]
# Coefficients:	 [[-0.00109977]]
# R^2 score:	 0.315433289259
# AK138792,0.315433289259
#
# 70
# Working on CH25H mean/freq regression...
# Intercept:	 [ 0.02724447]
# Coefficients:	 [[ 0.00087868]]
# R^2 score:	 0.790489243494
# CH25H,0.790489243494
#
# 71
# Working on PTGS2 mean/freq regression...
# Intercept:	 [ 0.02691449]
# Coefficients:	 [[ 0.00256012]]
# R^2 score:	 0.903311447516
# PTGS2,0.903311447516
#
# 72
# Working on SAMHD1 mean/freq regression...
# Intercept:	 [ 0.23584017]
# Coefficients:	 [[ 0.00274784]]
# R^2 score:	 0.829749925018
# SAMHD1,0.829749925018
#
# 73
# Working on SDC4 mean/freq regression...
# Intercept:	 [ 0.21857363]
# Coefficients:	 [[ 0.00017935]]
# R^2 score:	 0.451490428062
# SDC4,0.451490428062
#
# 74
# Working on ADAP2 mean/freq regression...
# Intercept:	 [ 0.06294249]
# Coefficients:	 [[ 0.00277797]]
# R^2 score:	 0.737745588377
# ADAP2,0.737745588377
#
# 75
# Working on MS4A6D mean/freq regression...
# Intercept:	 [ 0.1029924]
# Coefficients:	 [[ 0.00114845]]
# R^2 score:	 0.864174641841
# MS4A6D,0.864174641841
#
# 76
# Working on ATF3 mean/freq regression...
# Intercept:	 [ 0.14634655]
# Coefficients:	 [[ 0.00145478]]
# R^2 score:	 0.824911940048
# ATF3,0.824911940048
#
# 77
# Working on TNFSF15 mean/freq regression...
# Intercept:	 [ 0.04966156]
# Coefficients:	 [[ 0.00209071]]
# R^2 score:	 0.955948713496
# TNFSF15,0.955948713496
#
# 78
# Working on RELA mean/freq regression...
# Intercept:	 [ 0.11702268]
# Coefficients:	 [[ 0.00197413]]
# R^2 score:	 0.587279525603
# RELA,0.587279525603
#
# 79
# Working on ZFP36 mean/freq regression...
# Intercept:	 [ 0.14869249]
# Coefficients:	 [[ 0.00247967]]
# R^2 score:	 0.810216753632
# ZFP36,0.810216753632
#
# 80
# Working on SLFN2 mean/freq regression...
# Intercept:	 [ 0.25247863]
# Coefficients:	 [[ 0.00158338]]
# R^2 score:	 0.792074834162
# SLFN2,0.792074834162
#
# 81
# Working on GM12250 mean/freq regression...
# Intercept:	 [ 0.024817]
# Coefficients:	 [[ 0.00525429]]
# R^2 score:	 0.976828270665
# GM12250,0.976828270665
#
# 82
# Working on STAT1 mean/freq regression...
# Intercept:	 [ 0.03168455]
# Coefficients:	 [[ 0.00450847]]
# R^2 score:	 0.957912914136
# STAT1,0.957912914136
#
# 83
# Working on BIRC3 mean/freq regression...
# Intercept:	 [ 0.12578798]
# Coefficients:	 [[ 0.00155084]]
# R^2 score:	 0.59989266221
# BIRC3,0.59989266221
#
# 84
# Working on 1190002H23RIK mean/freq regression...
# Intercept:	 [ 0.03333006]
# Coefficients:	 [[ 0.00095451]]
# R^2 score:	 0.654037059337
# 1190002H23RIK,0.654037059337
#
# 85
# Working on ALDH1A2 mean/freq regression...
# Intercept:	 [ 0.03828302]
# Coefficients:	 [[ 0.00077521]]
# R^2 score:	 0.571900486757
# ALDH1A2,0.571900486757
#
# 86
# Working on OASL2 mean/freq regression...
# Intercept:	 [ 0.04183504]
# Coefficients:	 [[ 0.00306936]]
# R^2 score:	 0.959128478995
# OASL2,0.959128478995
#
# 87
# Working on IL27 mean/freq regression...
# Intercept:	 [ 0.03012533]
# Coefficients:	 [[ 0.00155083]]
# R^2 score:	 0.882810257845
# IL27,0.882810257845
#
# 88
# Working on H1F0 mean/freq regression...
# Intercept:	 [ 0.17320815]
# Coefficients:	 [[ 0.00140962]]
# R^2 score:	 0.797819029449
# H1F0,0.797819029449
#
# 89
# Working on CCL2 mean/freq regression...
# Intercept:	 [ 0.04804407]
# Coefficients:	 [[ 0.00013107]]
# R^2 score:	 0.603495316383
# CCL2,0.603495316383
#
# 90
# Working on DDX58 mean/freq regression...
# Intercept:	 [ 0.04854995]
# Coefficients:	 [[ 0.00462849]]
# R^2 score:	 0.916418036751
# DDX58,0.916418036751
#
# 91
# Working on GBP5 mean/freq regression...
# Intercept:	 [ 0.04638243]
# Coefficients:	 [[ 0.00445643]]
# R^2 score:	 0.953850245961
# GBP5,0.953850245961
#
# 92
# Working on CAV1 mean/freq regression...
# Intercept:	 [ 0.0445597]
# Coefficients:	 [[ 0.00146407]]
# R^2 score:	 0.860727428449
# CAV1,0.860727428449
#
# 93
# Working on NMI mean/freq regression...
# Intercept:	 [ 0.05022195]
# Coefficients:	 [[ 0.00253617]]
# R^2 score:	 0.791327861859
# NMI,0.791327861859
#
# 94
# Working on CCL17 mean/freq regression...
# Intercept:	 [ 0.09833224]
# Coefficients:	 [[  6.47086549e-05]]
# R^2 score:	 0.820139921476
# CCL17,0.820139921476
#
# 95
# Working on SLPI mean/freq regression...
# Intercept:	 [ 0.10908018]
# Coefficients:	 [[  6.18412112e-05]]
# R^2 score:	 0.049184581535
# SLPI,0.049184581535
#
# 96
# Working on H2-T23 mean/freq regression...
# Intercept:	 [ 0.1463429]
# Coefficients:	 [[ 0.00164207]]
# R^2 score:	 0.743041239355
# H2-T23,0.743041239355
#
# 97
# Working on NFKBIZ mean/freq regression...
# Intercept:	 [ 0.08140447]
# Coefficients:	 [[ 0.00304517]]
# R^2 score:	 0.827562366252
# NFKBIZ,0.827562366252
#
# 98
# Working on DHX58 mean/freq regression...
# Intercept:	 [ 0.03500716]
# Coefficients:	 [[ 0.00463029]]
# R^2 score:	 0.864941543769
# DHX58,0.864941543769
#
# 99
# Working on THBS1 mean/freq regression...
# Intercept:	 [ 0.0473683]
# Coefficients:	 [[ 0.0017263]]
# R^2 score:	 0.794075193406
# THBS1,0.794075193406
#
# 100
# Working on HERC6 mean/freq regression...
# Intercept:	 [ 0.02701798]
# Coefficients:	 [[ 0.0042164]]
# R^2 score:	 0.902090727128
# HERC6,0.902090727128
#
# 101
# Working on CD86 mean/freq regression...
# Intercept:	 [ 0.10848027]
# Coefficients:	 [[ 0.00091926]]
# R^2 score:	 0.631266915787
# CD86,0.631266915787
#
# 102
# Working on IGTP mean/freq regression...
# Intercept:	 [ 0.02085642]
# Coefficients:	 [[ 0.00280457]]
# R^2 score:	 0.921316390842
# IGTP,0.921316390842
#
# 103
# Working on FABP3 mean/freq regression...
# Intercept:	 [ 0.02480175]
# Coefficients:	 [[ 0.00113189]]
# R^2 score:	 0.907447223358
# FABP3,0.907447223358
#
# 104
# Working on AK042010 mean/freq regression...
# Intercept:	 [ 0.02071293]
# Coefficients:	 [[ 0.00312362]]
# R^2 score:	 0.882630587436
# AK042010,0.882630587436
#
# 105
# Working on GBP6 mean/freq regression...
# Intercept:	 [ 0.05441183]
# Coefficients:	 [[ 0.00478305]]
# R^2 score:	 0.887833385563
# GBP6,0.887833385563
#
# 106
# Working on IL1RN mean/freq regression...
# Intercept:	 [ 0.06675247]
# Coefficients:	 [[ 0.00084125]]
# R^2 score:	 0.905813435485
# IL1RN,0.905813435485
#
# 107
# Working on SERPINB9B mean/freq regression...
# Intercept:	 [ 0.02470326]
# Coefficients:	 [[ 0.00017109]]
# R^2 score:	 0.396678349213
# SERPINB9B,0.396678349213
#
# 108
# Working on INSIG1 mean/freq regression...
# Intercept:	 [ 0.35051195]
# Coefficients:	 [[ 0.00326783]]
# R^2 score:	 0.30279278528
# INSIG1,0.30279278528
#
# 109
# Working on RTP4 mean/freq regression...
# Intercept:	 [ 0.01355684]
# Coefficients:	 [[ 0.00245578]]
# R^2 score:	 0.956718972182
# RTP4,0.956718972182
#
# 110
# Working on IL1B mean/freq regression...
# Intercept:	 [ 0.09632866]
# Coefficients:	 [[ 0.00024132]]
# R^2 score:	 0.762679890927
# IL1B,0.762679890927
#
# 111
# Working on IFI204 mean/freq regression...
# Intercept:	 [ 0.08726947]
# Coefficients:	 [[ 0.00168033]]
# R^2 score:	 0.88214398087
# IFI204,0.88214398087
#
# 112
# Working on CD69 mean/freq regression...
# Intercept:	 [ 0.10412734]
# Coefficients:	 [[ 0.00047674]]
# R^2 score:	 0.579644306892
# CD69,0.579644306892
#
# 113
# Working on LGALS9 mean/freq regression...
# Intercept:	 [ 0.1034858]
# Coefficients:	 [[ 0.00120844]]
# R^2 score:	 0.828929462125
# LGALS9,0.828929462125
#
# 114
# Working on IFI27L2A mean/freq regression...
# Intercept:	 [ 0.09852908]
# Coefficients:	 [[ 0.00070111]]
# R^2 score:	 0.745921896241
# IFI27L2A,0.745921896241
#
# 115
# Working on IFI47 mean/freq regression...
# Intercept:	 [ 0.04547304]
# Coefficients:	 [[ 0.00165696]]
# R^2 score:	 0.958392490362
# IFI47,0.958392490362
#
# 116
# Working on CLU mean/freq regression...
# Intercept:	 [ 0.02033531]
# Coefficients:	 [[ 0.00017474]]
# R^2 score:	 0.791807356897
# CLU,0.791807356897
#
# 117
# Working on 2310016C08RIK mean/freq regression...
# Intercept:	 [-0.0032827]
# Coefficients:	 [[ 0.00122957]]
# R^2 score:	 0.915039790635
# 2310016C08RIK,0.915039790635
#
# 118
# Working on KPNA3 mean/freq regression...
# Intercept:	 [ 0.12899231]
# Coefficients:	 [[ 0.0048404]]
# R^2 score:	 0.802029874991
# KPNA3,0.802029874991
#
# 119
# Working on GLIPR2 mean/freq regression...
# Intercept:	 [ 0.08086525]
# Coefficients:	 [[ 0.00069049]]
# R^2 score:	 0.697966357083
# GLIPR2,0.697966357083
#
# 120
# Working on XAF1 mean/freq regression...
# Intercept:	 [ 0.04076306]
# Coefficients:	 [[ 0.00346152]]
# R^2 score:	 0.892018348183
# XAF1,0.892018348183
#
# 121
# Working on SLC7A2 mean/freq regression...
# Intercept:	 [ 0.19221026]
# Coefficients:	 [[ 0.00279471]]
# R^2 score:	 0.692330918042
# SLC7A2,0.692330918042
#
# 122
# Working on PROCR mean/freq regression...
# Intercept:	 [ 0.03062903]
# Coefficients:	 [[ 0.00180904]]
# R^2 score:	 0.840687760932
# PROCR,0.840687760932
#
# 123
# Working on PRPF38A mean/freq regression...
# Intercept:	 [ 0.11073005]
# Coefficients:	 [[ 0.00082217]]
# R^2 score:	 0.248912127834
# PRPF38A,0.248912127834
#
# 124
# Working on 1810029B16RIK mean/freq regression...
# Intercept:	 [ 0.20482128]
# Coefficients:	 [[ 0.00067351]]
# R^2 score:	 0.294100048453
# 1810029B16RIK,0.294100048453
#
# 125
# Working on CCRL2 mean/freq regression...
# Intercept:	 [ 0.0839191]
# Coefficients:	 [[ 0.00193225]]
# R^2 score:	 0.771864777725
# CCRL2,0.771864777725
#
# 126
# Working on GBP2 mean/freq regression...
# Intercept:	 [ 0.19631803]
# Coefficients:	 [[ 0.00125232]]
# R^2 score:	 0.796879364454
# GBP2,0.796879364454
#
# 127
# Working on DUSP1 mean/freq regression...
# Intercept:	 [ 0.09866556]
# Coefficients:	 [[ 0.00231971]]
# R^2 score:	 0.718186441543
# DUSP1,0.718186441543
#
# 128
# Working on PTX3 mean/freq regression...
# Intercept:	 [ 0.02327711]
# Coefficients:	 [[ 0.00090671]]
# R^2 score:	 0.922222983671
# PTX3,0.922222983671
#
# 129
# Working on BST2 mean/freq regression...
# Intercept:	 [ 0.07943097]
# Coefficients:	 [[ 0.00219745]]
# R^2 score:	 0.773847692106
# BST2,0.773847692106
#
# 130
# Working on RAB32 mean/freq regression...
# Intercept:	 [ 0.10212659]
# Coefficients:	 [[ 0.00193456]]
# R^2 score:	 0.754621115907
# RAB32,0.754621115907
#
# 131
# Working on CLEC4E mean/freq regression...
# Intercept:	 [ 0.08453635]
# Coefficients:	 [[ 0.00098319]]
# R^2 score:	 0.827781682225
# CLEC4E,0.827781682225
#
# 132
# Working on BLNK mean/freq regression...
# Intercept:	 [ 0.10131153]
# Coefficients:	 [[ 0.0018898]]
# R^2 score:	 0.782119365357
# BLNK,0.782119365357
#
# 133
# Working on SP100 mean/freq regression...
# Intercept:	 [ 0.08223795]
# Coefficients:	 [[ 0.00204897]]
# R^2 score:	 0.808871635193
# SP100,0.808871635193
#
# 134
# Working on STAT2 mean/freq regression...
# Intercept:	 [ 0.04674905]
# Coefficients:	 [[ 0.00467766]]
# R^2 score:	 0.908206321639
# STAT2,0.908206321639
#
# 135
# Working on CD200 mean/freq regression...
# Intercept:	 [ 0.06873607]
# Coefficients:	 [[ 0.00137406]]
# R^2 score:	 0.778783232475
# CD200,0.778783232475
#
# 136
# Working on PARP9 mean/freq regression...
# Intercept:	 [ 0.02343274]
# Coefficients:	 [[ 0.00583676]]
# R^2 score:	 0.932752042866
# PARP9,0.932752042866
#
# 137
# Working on PRDX1 mean/freq regression...
# Intercept:	 [ 0.45235817]
# Coefficients:	 [[ 0.00012754]]
# R^2 score:	 0.591838198596
# PRDX1,0.591838198596
#
# 138
# Working on MMP13 mean/freq regression...
# Intercept:	 [ 0.03144163]
# Coefficients:	 [[ 0.00068378]]
# R^2 score:	 0.496220069033
# MMP13,0.496220069033
#
# 139
# Working on CD274 mean/freq regression...
# Intercept:	 [ 0.07263273]
# Coefficients:	 [[ 0.00320427]]
# R^2 score:	 0.924400308297
# CD274,0.924400308297
#
# 140
# Working on AI607873 mean/freq regression...
# Intercept:	 [ 0.05811969]
# Coefficients:	 [[ 0.00158021]]
# R^2 score:	 0.77498785222
# AI607873,0.77498785222
#
# 141
# Working on PMP22 mean/freq regression...
# Intercept:	 [ 0.09434726]
# Coefficients:	 [[ 0.00097977]]
# R^2 score:	 0.589607081208
# PMP22,0.589607081208
#
# 142
# Working on CD47 mean/freq regression...
# Intercept:	 [ 0.39454895]
# Coefficients:	 [[ 0.00168686]]
# R^2 score:	 0.527740140747
# CD47,0.527740140747
#
# 143
# Working on ZBP1 mean/freq regression...
# Intercept:	 [ 0.02909]
# Coefficients:	 [[ 0.00226527]]
# R^2 score:	 0.89289027084
# ZBP1,0.89289027084
#
# 144
# Working on PHF11 mean/freq regression...
# Intercept:	 [ 0.02653419]
# Coefficients:	 [[ 0.00261498]]
# R^2 score:	 0.952969433725
# PHF11,0.952969433725
#
# 145
# Working on TOR3A mean/freq regression...
# Intercept:	 [ 0.04434581]
# Coefficients:	 [[ 0.00531984]]
# R^2 score:	 0.934140545439
# TOR3A,0.934140545439
#
# 146
# Working on IFI35 mean/freq regression...
# Intercept:	 [-0.00577816]
# Coefficients:	 [[ 0.00398156]]
# R^2 score:	 0.899109078592
# IFI35,0.899109078592
#
# 147
# Working on LCP2 mean/freq regression...
# Intercept:	 [ 0.09593887]
# Coefficients:	 [[ 0.00348526]]
# R^2 score:	 0.720561414673
# LCP2,0.720561414673
#
# 148
# Working on SBDS mean/freq regression...
# Intercept:	 [ 0.10236863]
# Coefficients:	 [[ 0.00264461]]
# R^2 score:	 0.883595077638
# SBDS,0.883595077638
#
# 149
# Working on IFITM3 mean/freq regression...
# Intercept:	 [ 0.04733164]
# Coefficients:	 [[ 0.00066378]]
# R^2 score:	 0.879451373147
# IFITM3,0.879451373147
#
# 150
# Working on DTX3L mean/freq regression...
# Intercept:	 [ 0.08615935]
# Coefficients:	 [[ 0.00768106]]
# R^2 score:	 0.769684538859
# DTX3L,0.769684538859
#
# 151
# Working on IL6 mean/freq regression...
# Intercept:	 [ 0.02305531]
# Coefficients:	 [[ 0.00059101]]
# R^2 score:	 0.899195834195
# IL6,0.899195834195
#
# 152
# Working on FPR1 mean/freq regression...
# Intercept:	 [ 0.00723302]
# Coefficients:	 [[ 0.00138939]]
# R^2 score:	 0.916904663788
# FPR1,0.916904663788
#
# 153
# Working on AY096003 mean/freq regression...
# Intercept:	 [ 0.08658394]
# Coefficients:	 [[ 0.00162021]]
# R^2 score:	 0.798024025544
# AY096003,0.798024025544
#
# 154
# Working on SAA3 mean/freq regression...
# Intercept:	 [ 0.04225403]
# Coefficients:	 [[ 0.00012872]]
# R^2 score:	 0.441007733037
# SAA3,0.441007733037
#
# 155
# Working on FOS mean/freq regression...
# Intercept:	 [ 0.0575692]
# Coefficients:	 [[ 0.00095425]]
# R^2 score:	 0.407775663145
# FOS,0.407775663145
#
# 156
# Working on ZUFSP mean/freq regression...
# Intercept:	 [ 0.04958028]
# Coefficients:	 [[ 0.00308597]]
# R^2 score:	 0.830113227105
# ZUFSP,0.830113227105
#
# 157
# Working on EPSTI1 mean/freq regression...
# Intercept:	 [ 0.07998571]
# Coefficients:	 [[ 0.00123492]]
# R^2 score:	 0.338812014068
# EPSTI1,0.338812014068
#
# 158
# Working on PDZK1IP1 mean/freq regression...
# Intercept:	 [ 0.05109656]
# Coefficients:	 [[ 0.00151439]]
# R^2 score:	 0.664745347048
# PDZK1IP1,0.664745347048
#
# 159
# Working on MCA32 mean/freq regression...
# Intercept:	 [ 0.08782141]
# Coefficients:	 [[ 0.00096026]]
# R^2 score:	 0.579697484317
# MCA32,0.579697484317
#
# 160
# Working on NFKBIA mean/freq regression...
# Intercept:	 [ 0.35620356]
# Coefficients:	 [[ 0.00097717]]
# R^2 score:	 0.811634496204
# NFKBIA,0.811634496204
#
# 161
# Working on H2-T10 mean/freq regression...
# Intercept:	 [ 0.06796903]
# Coefficients:	 [[ 0.00168415]]
# R^2 score:	 0.756178623863
# H2-T10,0.756178623863
#
# 162
# Working on IFNB1 mean/freq regression...
# Intercept:	 [ 0.01769174]
# Coefficients:	 [[ 0.0003414]]
# R^2 score:	 0.31883919379
# IFNB1,0.31883919379
#
# 163
# Working on IFIH1 mean/freq regression...
# Intercept:	 [-0.01490631]
# Coefficients:	 [[ 0.00469755]]
# R^2 score:	 0.947685232086
# IFIH1,0.947685232086
#
# 164
# Working on AK052414 mean/freq regression...
# Intercept:	 [ 0.04772283]
# Coefficients:	 [[ 0.0019178]]
# R^2 score:	 0.719245833536
# AK052414,0.719245833536
#
# 165
# Working on MT2 mean/freq regression...
# Intercept:	 [ 0.06247271]
# Coefficients:	 [[ 0.00171075]]
# R^2 score:	 0.92294410436
# MT2,0.92294410436
#
# 166
# Working on CLIC4 mean/freq regression...
# Intercept:	 [ 0.14310364]
# Coefficients:	 [[ 0.00456481]]
# R^2 score:	 0.716244463892
# CLIC4,0.716244463892
#
# 167
# Working on ARF4 mean/freq regression...
# Intercept:	 [ 0.39107262]
# Coefficients:	 [[ 0.0013813]]
# R^2 score:	 0.342759839906
# ARF4,0.342759839906
#
# 168
# Working on ETV3 mean/freq regression...
# Intercept:	 [ 0.23957804]
# Coefficients:	 [[ 0.00098656]]
# R^2 score:	 0.180869384451
# ETV3,0.180869384451
#
# 169
# Working on SERPINB6B mean/freq regression...
# Intercept:	 [ 0.03051247]
# Coefficients:	 [[ 0.00058158]]
# R^2 score:	 0.610046819611
# SERPINB6B,0.610046819611
#
# 170
# Working on RNASET2B mean/freq regression...
# Intercept:	 [ 0.34999209]
# Coefficients:	 [[ 0.00036304]]
# R^2 score:	 0.059987362194
# RNASET2B,0.059987362194
#
# 171
# Working on KTELC1 mean/freq regression...
# Intercept:	 [ 0.04114117]
# Coefficients:	 [[ 0.00213273]]
# R^2 score:	 0.84657266798
# KTELC1,0.84657266798
#
# 172
# Working on IL7R mean/freq regression...
# Intercept:	 [ 0.10974967]
# Coefficients:	 [[ 0.0026051]]
# R^2 score:	 0.552700956495
# IL7R,0.552700956495
#
# 173
# Working on LAP3 mean/freq regression...
# Intercept:	 [ 0.10093571]
# Coefficients:	 [[ 0.00362282]]
# R^2 score:	 0.712075842483
# LAP3,0.712075842483
#
# 174
# Working on FPR2 mean/freq regression...
# Intercept:	 [ 0.03689883]
# Coefficients:	 [[ 0.00148969]]
# R^2 score:	 0.822413390828
# FPR2,0.822413390828
#
# 175
# Working on TNIP3 mean/freq regression...
# Intercept:	 [ 0.22497339]
# Coefficients:	 [[ 0.00153877]]
# R^2 score:	 0.478280783298
# TNIP3,0.478280783298
#
# 176
# Working on NCOA7 mean/freq regression...
# Intercept:	 [ 0.16662308]
# Coefficients:	 [[ 0.00072342]]
# R^2 score:	 0.112865961842
# NCOA7,0.112865961842
#
# 177
# Working on TNFAIP3 mean/freq regression...
# Intercept:	 [ 0.07909764]
# Coefficients:	 [[ 0.004304]]
# R^2 score:	 0.809251989395
# TNFAIP3,0.809251989395
#
# 178
# Working on ELL2 mean/freq regression...
# Intercept:	 [ 0.06796825]
# Coefficients:	 [[ 0.00468095]]
# R^2 score:	 0.721342557761
# ELL2,0.721342557761
#
# 179
# Working on PTTG1 mean/freq regression...
# Intercept:	 [ 0.11467347]
# Coefficients:	 [[ 0.00200888]]
# R^2 score:	 0.837513191142
# PTTG1,0.837513191142
#
# 180
# Working on MX1 mean/freq regression...
# Intercept:	 [ 0.06144884]
# Coefficients:	 [[ 0.00088785]]
# R^2 score:	 0.90803719021
# MX1,0.90803719021
#
# 181
# Working on RILPL2 mean/freq regression...
# Intercept:	 [ 0.1160046]
# Coefficients:	 [[ 0.00196714]]
# R^2 score:	 0.642374596513
# RILPL2,0.642374596513
#
# 182
# Working on CCL5 mean/freq regression...
# Intercept:	 [ 0.01477429]
# Coefficients:	 [[  8.72024738e-05]]
# R^2 score:	 0.919737325193
# CCL5,0.919737325193
#
# 183
# Working on CAR2 mean/freq regression...
# Intercept:	 [ 0.03372099]
# Coefficients:	 [[ 0.00098555]]
# R^2 score:	 0.7042152905
# CAR2,0.7042152905
#
# 184
# Working on TNF mean/freq regression...
# Intercept:	 [ 0.03644834]
# Coefficients:	 [[ 0.00083404]]
# R^2 score:	 0.829811249176
# TNF,0.829811249176
#
# 185
# Working on SWAP70 mean/freq regression...
# Intercept:	 [ 0.04149981]
# Coefficients:	 [[ 0.00292279]]
# R^2 score:	 0.676070906044
# SWAP70,0.676070906044
#
# 186
# Working on IRF8 mean/freq regression...
# Intercept:	 [ 0.08421508]
# Coefficients:	 [[ 0.00170262]]
# R^2 score:	 0.641261524025
# IRF8,0.641261524025
#
# 187
# Working on TRAF1 mean/freq regression...
# Intercept:	 [ 0.09122432]
# Coefficients:	 [[ 0.00158537]]
# R^2 score:	 0.562130310022
# TRAF1,0.562130310022
#
# 188
# Working on PPP1CB mean/freq regression...
# Intercept:	 [ 0.23837892]
# Coefficients:	 [[ 0.00185168]]
# R^2 score:	 0.170138931862
# PPP1CB,0.170138931862
#
# 189
# Working on SERPINB9 mean/freq regression...
# Intercept:	 [ 0.04958714]
# Coefficients:	 [[ 0.0007042]]
# R^2 score:	 0.588706950308
# SERPINB9,0.588706950308
#
# 190
# Working on RBM7 mean/freq regression...
# Intercept:	 [ 0.12700416]
# Coefficients:	 [[ 0.00173305]]
# R^2 score:	 0.452595133909
# RBM7,0.452595133909
#
# 191
# Working on 9430076C15RIK mean/freq regression...
# Intercept:	 [ 0.09905842]
# Coefficients:	 [[ 0.00297692]]
# R^2 score:	 0.606760977663
# 9430076C15RIK,0.606760977663
#
# 192
# Working on H2-Q7 mean/freq regression...
# Intercept:	 [ 0.07903204]
# Coefficients:	 [[ 0.00155382]]
# R^2 score:	 0.754041696931
# H2-Q7,0.754041696931
#
# 193
# Working on MALT1 mean/freq regression...
# Intercept:	 [ 0.13388352]
# Coefficients:	 [[ 0.0030554]]
# R^2 score:	 0.655450350035
# MALT1,0.655450350035
#
# 194
# Working on AK217941 mean/freq regression...
# Intercept:	 [ 0.09468748]
# Coefficients:	 [[ 0.00062134]]
# R^2 score:	 0.310843284122
# AK217941,0.310843284122
#
# 195
# Working on KTN1 mean/freq regression...
# Intercept:	 [ 0.11444062]
# Coefficients:	 [[ 0.00286851]]
# R^2 score:	 0.540481008366
# KTN1,0.540481008366
#
# 196
# Working on HSPA5 mean/freq regression...
# Intercept:	 [ 0.27302081]
# Coefficients:	 [[ 0.00137435]]
# R^2 score:	 0.646586436073
# HSPA5,0.646586436073
#
# 197
# Working on MYD88 mean/freq regression...
# Intercept:	 [ 0.11699055]
# Coefficients:	 [[ 0.00191703]]
# R^2 score:	 0.469895023476
# MYD88,0.469895023476
#
# 198
# Working on TAPBP mean/freq regression...
# Intercept:	 [ 0.38269488]
# Coefficients:	 [[ 0.00268163]]
# R^2 score:	 0.485910167479
# TAPBP,0.485910167479
#
# 199
# Working on MKIAA1673 mean/freq regression...
# Intercept:	 [ 0.07353715]
# Coefficients:	 [[ 0.00424219]]
# R^2 score:	 0.675535591331
# MKIAA1673,0.675535591331
#
# 200
# Working on IFRD1 mean/freq regression...
# Intercept:	 [ 0.06027196]
# Coefficients:	 [[ 0.00214707]]
# R^2 score:	 0.620589187098
# IFRD1,0.620589187098
#
# 201
# Working on CASP1 mean/freq regression...
# Intercept:	 [ 0.06969842]
# Coefficients:	 [[ 0.0019094]]
# R^2 score:	 0.586549957053
# CASP1,0.586549957053
#
# 202
# Working on IFI203 mean/freq regression...
# Intercept:	 [ 0.06629038]
# Coefficients:	 [[ 0.0039714]]
# R^2 score:	 0.803131751335
# IFI203,0.803131751335
#
# 203
# Working on IRF1 mean/freq regression...
# Intercept:	 [ 0.04724459]
# Coefficients:	 [[ 0.00212411]]
# R^2 score:	 0.789195391549
# IRF1,0.789195391549
#
# 204
# Working on TNFRSF1B mean/freq regression...
# Intercept:	 [ 0.18251856]
# Coefficients:	 [[ 0.00296741]]
# R^2 score:	 0.70922945342
# TNFRSF1B,0.70922945342
# 205
# Working on A130040M12RIK mean/freq regression...
# Intercept:	 [ 0.07908495]
# Coefficients:	 [[ 0.00322358]]
# R^2 score:	 0.818797250495
# A130040M12RIK,0.818797250495
#
# 206
# Working on PNP mean/freq regression...
# Intercept:	 [ 0.128649]
# Coefficients:	 [[ 0.00329657]]
# R^2 score:	 0.79347467356
# PNP,0.79347467356
#
# 207
# Working on SP140 mean/freq regression...
# Intercept:	 [ 0.14205375]
# Coefficients:	 [[ 0.00291766]]
# R^2 score:	 0.853698254766
# SP140,0.853698254766
#
# 208
# Working on BHLHE40 mean/freq regression...
# Intercept:	 [ 0.13563563]
# Coefficients:	 [[ 0.00178787]]
# R^2 score:	 0.600952331848
# BHLHE40,0.600952331848
#
# 209
# Working on CXCL16 mean/freq regression...
# Intercept:	 [ 0.22708908]
# Coefficients:	 [[ 0.00136164]]
# R^2 score:	 0.638156702846
# CXCL16,0.638156702846
#
# 210
# Working on MAP2K1 mean/freq regression...
# Intercept:	 [ 0.08773593]
# Coefficients:	 [[ 0.00336167]]
# R^2 score:	 0.535202124394
# MAP2K1,0.535202124394
#
# 211
# Working on RASGEF1B mean/freq regression...
# Intercept:	 [ 0.07259903]
# Coefficients:	 [[ 0.00260436]]
# R^2 score:	 0.577106007804
# RASGEF1B,0.577106007804
#
# 212
# Working on CDKN1A mean/freq regression...
# Intercept:	 [ 0.43879073]
# Coefficients:	 [[ 0.00102022]]
# R^2 score:	 0.340674857762
# CDKN1A,0.340674857762
#
# 213
# Working on SGK1 mean/freq regression...
# Intercept:	 [-0.00707763]
# Coefficients:	 [[ 0.00194034]]
# R^2 score:	 0.868456961563
# SGK1,0.868456961563
#
# 214
# Working on OAS1A mean/freq regression...
# Intercept:	 [ 0.07536914]
# Coefficients:	 [[ 0.00214112]]
# R^2 score:	 0.785212817757
# OAS1A,0.785212817757
#
# 215
# Working on SQSTM1 mean/freq regression...
# Intercept:	 [ 0.19668064]
# Coefficients:	 [[ 0.00100071]]
# R^2 score:	 0.668776264923
# SQSTM1,0.668776264923
#
# 216
# Working on RNF19B mean/freq regression...
# Intercept:	 [ 0.17309424]
# Coefficients:	 [[ 0.00235108]]
# R^2 score:	 0.44286991692
# RNF19B,0.44286991692
#
# 217
# Working on SLC7A11 mean/freq regression...
# Intercept:	 [ 0.65189732]
# Coefficients:	 [[ 0.00110879]]
# R^2 score:	 0.138352035016
# SLC7A11,0.138352035016
#
# 218
# Working on CD83 mean/freq regression...
# Intercept:	 [ 0.05310259]
# Coefficients:	 [[ 0.00080948]]
# R^2 score:	 0.687294006058
# CD83,0.687294006058
#
# 219
# Working on SAMSN1 mean/freq regression...
# Intercept:	 [ 0.17908976]
# Coefficients:	 [[ 0.0007887]]
# R^2 score:	 0.54281692887
# SAMSN1,0.54281692887
#
# 220
# Working on MED21 mean/freq regression...
# Intercept:	 [ 0.11428024]
# Coefficients:	 [[ 0.00059839]]
# R^2 score:	 0.0714297206431
# MED21,0.0714297206431
#
# 221
# Working on HK2 mean/freq regression...
# Intercept:	 [ 0.10401132]
# Coefficients:	 [[ 0.00298957]]
# R^2 score:	 0.595294222616
# HK2,0.595294222616
#
# 222
# Working on PARP14 mean/freq regression...
# Intercept:	 [ 0.03436035]
# Coefficients:	 [[ 0.00469948]]
# R^2 score:	 0.908576659641
# PARP14,0.908576659641
#
# 223
# Working on GM6377 mean/freq regression...
# Intercept:	 [ 0.05141955]
# Coefficients:	 [[ 0.00317507]]
# R^2 score:	 0.673300577495
# GM6377,0.673300577495
#
# 224
# Working on CCL22 mean/freq regression...
# Intercept:	 [ 0.05086412]
# Coefficients:	 [[  8.88295254e-05]]
# R^2 score:	 0.735327503375
# CCL22,0.735327503375
#
# 225
# Working on BTG1 mean/freq regression...
# Intercept:	 [ 0.60004224]
# Coefficients:	 [[ 0.00082646]]
# R^2 score:	 0.481544198292
# BTG1,0.481544198292
#
# 226
# Working on PDPN mean/freq regression...
# Intercept:	 [ 0.06799703]
# Coefficients:	 [[ 0.0010379]]
# R^2 score:	 0.526605120117
# PDPN,0.526605120117
#
# 227
# Working on SOD2 mean/freq regression...
# Intercept:	 [ 0.44977685]
# Coefficients:	 [[ 0.00222021]]
# R^2 score:	 0.426634121333
# SOD2,0.426634121333
#
# 228
# Working on MNDAL mean/freq regression...
# Intercept:	 [ 0.04426359]
# Coefficients:	 [[ 0.002493]]
# R^2 score:	 0.828168707407
# MNDAL,0.828168707407
#
# 229
# Working on CXCL2 mean/freq regression...
# Intercept:	 [ 0.1403824]
# Coefficients:	 [[ 0.00041225]]
# R^2 score:	 0.659732535991
# CXCL2,0.659732535991
#
# 230
# Working on PELI1 mean/freq regression...
# Intercept:	 [ 0.09515323]
# Coefficients:	 [[ 0.00606654]]
# R^2 score:	 0.769440678248
# PELI1,0.769440678248
#
# 231
# Working on NCK1 mean/freq regression...
# Intercept:	 [ 0.09356204]
# Coefficients:	 [[ 0.00200109]]
# R^2 score:	 0.463092867287
# NCK1,0.463092867287
#
# 232
# Working on GADD45B mean/freq regression...
# Intercept:	 [ 0.08228794]
# Coefficients:	 [[ 0.00406912]]
# R^2 score:	 0.884666370594
# GADD45B,0.884666370594
#
# 233
# Working on PSME2 mean/freq regression...
# Intercept:	 [ 0.27369056]
# Coefficients:	 [[ 0.00087483]]
# R^2 score:	 0.553665449675
# PSME2,0.553665449675
#
# 234
# Working on CD14 mean/freq regression...
# Intercept:	 [ 0.32031333]
# Coefficients:	 [[ 0.00032543]]
# R^2 score:	 0.434961009933
# CD14,0.434961009933
#
# 235
# Working on LGALS3BP mean/freq regression...
# Intercept:	 [ 0.1022916]
# Coefficients:	 [[ 0.00266902]]
# R^2 score:	 0.751553810687
# LGALS3BP,0.751553810687
#
# 236
# Working on CLEC4D mean/freq regression...
# Intercept:	 [ 0.28224423]
# Coefficients:	 [[ 0.00043729]]
# R^2 score:	 0.0997833978281
# CLEC4D,0.0997833978281
#
# 237
# Working on SNX10 mean/freq regression...
# Intercept:	 [ 0.35158964]
# Coefficients:	 [[ 0.00143761]]
# R^2 score:	 0.220872434585
# SNX10,0.220872434585
#
# 238
# Working on BTG2 mean/freq regression...
# Intercept:	 [ 0.0607726]
# Coefficients:	 [[ 0.00212156]]
# R^2 score:	 0.473257269304
# BTG2,0.473257269304
#
# 239
# Working on NFKB1 mean/freq regression...
# Intercept:	 [ 0.14607634]
# Coefficients:	 [[ 0.00252953]]
# R^2 score:	 0.630515573871
# NFKB1,0.630515573871
#
# 240
# Working on PSMB9 mean/freq regression...
# Intercept:	 [ 0.07508591]
# Coefficients:	 [[ 0.00224617]]
# R^2 score:	 0.657286465022
# PSMB9,0.657286465022
#
# 241
# Working on RNASET2A mean/freq regression...
# Intercept:	 [ 0.05525041]
# Coefficients:	 [[ 0.0023872]]
# R^2 score:	 0.782618530664
# RNASET2A,0.782618530664
#
# 242
# Working on P2RY14 mean/freq regression...
# Intercept:	 [ 0.16332738]
# Coefficients:	 [[ 0.00074378]]
# R^2 score:	 0.223494847561
# P2RY14,0.223494847561
#
# 243
# Working on RNF114 mean/freq regression...
# Intercept:	 [ 0.06716626]
# Coefficients:	 [[ 0.0016859]]
# R^2 score:	 0.646398447457
# RNF114,0.646398447457
#
# 244
# Working on TMEM219 mean/freq regression...
# Intercept:	 [ 0.1172472]
# Coefficients:	 [[ 0.00163486]]
# R^2 score:	 0.356969066985
# TMEM219,0.356969066985
#
# 245
# Working on LY6C2 mean/freq regression...
# Intercept:	 [ 0.03132987]
# Coefficients:	 [[ 0.00065066]]
# R^2 score:	 0.657994627127
# LY6C2,0.657994627127
#
# 246
# Working on IL12B mean/freq regression...
# Intercept:	 [ 0.03470394]
# Coefficients:	 [[ 0.00024048]]
# R^2 score:	 0.902572752162
# IL12B,0.902572752162
#
# 247
# Working on F10 mean/freq regression...
# Intercept:	 [ 0.0740238]
# Coefficients:	 [[ 0.00128987]]
# R^2 score:	 0.493338390109
# F10,0.493338390109
#
# 248
# Working on CASP7 mean/freq regression...
# Intercept:	 [ 0.10651816]
# Coefficients:	 [[ 0.00089167]]
# R^2 score:	 0.0831528619132
# CASP7,0.0831528619132
#
# 249
# Working on MDM2 mean/freq regression...
# Intercept:	 [ 0.0431411]
# Coefficients:	 [[ 0.0022051]]
# R^2 score:	 0.64894785568
# MDM2,0.64894785568
#
# 250
# Working on KLF6 mean/freq regression...
# Intercept:	 [ 0.42424331]
# Coefficients:	 [[ 0.00250028]]
# R^2 score:	 0.22153138402
# KLF6,0.22153138402
#
# 251
# Working on NUPR1 mean/freq regression...
# Intercept:	 [ 0.04758232]
# Coefficients:	 [[ 0.00073767]]
# R^2 score:	 0.649965714365
# NUPR1,0.649965714365
#
# 252
# Working on CASP11 mean/freq regression...
# Intercept:	 [ 0.06461216]
# Coefficients:	 [[ 0.00177192]]
# R^2 score:	 0.885856676626
# CASP11,0.885856676626
#
# 253
# Working on 2810474O19RIK mean/freq regression...
# Intercept:	 [ 0.22697729]
# Coefficients:	 [[ 0.00396855]]
# R^2 score:	 0.51739714269
# 2810474O19RIK,0.51739714269
#
# 254
# Working on HCK mean/freq regression...
# Intercept:	 [ 0.05422791]
# Coefficients:	 [[ 0.00339187]]
# R^2 score:	 0.631920667317
# HCK,0.631920667317
#
# 255
# Working on RAB8B mean/freq regression...
# Intercept:	 [ 0.30304278]
# Coefficients:	 [[ 0.00257363]]
# R^2 score:	 0.418601847584
# RAB8B,0.418601847584
#
# 256
# Working on BCL2A1D mean/freq regression...
# Intercept:	 [ 0.62433812]
# Coefficients:	 [[ 0.00075628]]
# R^2 score:	 0.448461266905
# BCL2A1D,0.448461266905
#
# 257
# Working on STXBP3A mean/freq regression...
# Intercept:	 [ 0.09567191]
# Coefficients:	 [[ 0.00308396]]
# R^2 score:	 0.607837720961
# STXBP3A,0.607837720961
#
# 258
# Working on PFKP mean/freq regression...
# Intercept:	 [ 0.16050578]
# Coefficients:	 [[ 0.00265799]]
# R^2 score:	 0.521630327096
# PFKP,0.521630327096
#
# 259
# Working on TANK mean/freq regression...
# Intercept:	 [ 0.20840407]
# Coefficients:	 [[ 0.0015285]]
# R^2 score:	 0.494385382966
# TANK,0.494385382966
#
# 260
# Working on TGIF1 mean/freq regression...
# Intercept:	 [ 0.10488397]
# Coefficients:	 [[ 0.00160861]]
# R^2 score:	 0.443206990275
# TGIF1,0.443206990275
#
# 261
# Working on PPP1R15A mean/freq regression...
# Intercept:	 [ 0.08621816]
# Coefficients:	 [[ 0.0016721]]
# R^2 score:	 0.55791926549
# PPP1R15A,0.55791926549
#
# 262
# Working on SEPW1 mean/freq regression...
# Intercept:	 [ 0.24199805]
# Coefficients:	 [[ 0.00214727]]
# R^2 score:	 0.484768441724
# SEPW1,0.484768441724
#
# 263
# Working on PLAUR mean/freq regression...
# Intercept:	 [ 0.09598637]
# Coefficients:	 [[ 0.00144115]]
# R^2 score:	 0.645049973757
# PLAUR,0.645049973757
#
# 264
# Working on H2-M2 mean/freq regression...
# Intercept:	 [ 0.05563061]
# Coefficients:	 [[ 0.00036644]]
# R^2 score:	 0.697116558839
# H2-M2,0.697116558839
#
# 265
# Working on BATF mean/freq regression...
# Intercept:	 [ 0.02598155]
# Coefficients:	 [[ 0.00201718]]
# R^2 score:	 0.766407324967
# BATF,0.766407324967
#
# 266
# Working on NUP62-IL4I1 mean/freq regression...
# Intercept:	 [-0.00670185]
# Coefficients:	 [[ 0.00175396]]
# R^2 score:	 0.902076770105
# NUP62-IL4I1,0.902076770105
#
# 267
# Working on TNFAIP2 mean/freq regression...
# Intercept:	 [ 0.36839215]
# Coefficients:	 [[ 0.00190194]]
# R^2 score:	 0.549904858759
# TNFAIP2,0.549904858759
#
# 268
# Working on FNDC3A mean/freq regression...
# Intercept:	 [ 0.20039528]
# Coefficients:	 [[ 0.00168099]]
# R^2 score:	 0.133040843692
# FNDC3A,0.133040843692
#
# 269
# Working on TREX1 mean/freq regression...
# Intercept:	 [ 0.01718576]
# Coefficients:	 [[ 0.00194407]]
# R^2 score:	 0.912316015046
# TREX1,0.912316015046
#
# 270
# Working on RAB9 mean/freq regression...
# Intercept:	 [ 0.20482376]
# Coefficients:	 [[ 0.00035384]]
# R^2 score:	 0.0166857581174
# RAB9,0.0166857581174
#
# 271
# Working on BCL2A1A mean/freq regression...
# Intercept:	 [ 0.38949586]
# Coefficients:	 [[ 0.00113723]]
# R^2 score:	 0.478785200112
# BCL2A1A,0.478785200112
#
# 272
# Working on PDE4B mean/freq regression...
# Intercept:	 [ 0.10864542]
# Coefficients:	 [[ 0.00399773]]
# R^2 score:	 0.543684185535
# PDE4B,0.543684185535
#
# 273
# Working on PIK3R5 mean/freq regression...
# Intercept:	 [ 0.31230765]
# Coefficients:	 [[ 0.00245452]]
# R^2 score:	 0.247002955527
# PIK3R5,0.247002955527
#
# 274
# Working on RND3 mean/freq regression...
# Intercept:	 [ 0.08458198]
# Coefficients:	 [[ 0.00404387]]
# R^2 score:	 0.631782381304
# RND3,0.631782381304
#
# 275
# Working on CD44 mean/freq regression...
# Intercept:	 [ 0.28992454]
# Coefficients:	 [[ 0.00238838]]
# R^2 score:	 0.499550913925
# CD44,0.499550913925
#
# 276
# Working on AK172683 mean/freq regression...
# Intercept:	 [ 0.0369757]
# Coefficients:	 [[ 0.0083071]]
# R^2 score:	 0.868010396276
# AK172683,0.868010396276
#
# 277
# Working on ARL5C mean/freq regression...
# Intercept:	 [ 0.25620231]
# Coefficients:	 [[ 0.00121392]]
# R^2 score:	 0.226891053289
# ARL5C,0.226891053289
#
# 278
# Working on IER3 mean/freq regression...
# Intercept:	 [ 0.01606504]
# Coefficients:	 [[ 0.00254169]]
# R^2 score:	 0.72628093233
# IER3,0.72628093233
#
# 279
# Working on GTF2B mean/freq regression...
# Intercept:	 [ 0.09747531]
# Coefficients:	 [[ 0.00199272]]
# R^2 score:	 0.448978891494
# GTF2B,0.448978891494
#
# 280
# Working on ANXA7 mean/freq regression...
# Intercept:	 [ 0.12455594]
# Coefficients:	 [[ 0.00296723]]
# R^2 score:	 0.419134827152
# ANXA7,0.419134827152
#
# 281
# Working on TXNRD1 mean/freq regression...
# Intercept:	 [ 0.24976801]
# Coefficients:	 [[ 0.00445981]]
# R^2 score:	 0.466726416871
# TXNRD1,0.466726416871
#
# 282
# Working on HIF1A mean/freq regression...
# Intercept:	 [ 0.15244499]
# Coefficients:	 [[ 0.00478964]]
# R^2 score:	 0.327869210616
# HIF1A,0.327869210616
#
# 283
# Working on MARCKSL1 mean/freq regression...
# Intercept:	 [ 0.09272673]
# Coefficients:	 [[ 0.00207421]]
# R^2 score:	 0.78687834607
# MARCKSL1,0.78687834607
#
# 284
# Working on PLK2 mean/freq regression...
# Intercept:	 [-0.02613774]
# Coefficients:	 [[ 0.00410837]]
# R^2 score:	 0.835090893707
# PLK2,0.835090893707
#
# 285
# Working on CFLAR mean/freq regression...
# Intercept:	 [ 0.09073009]
# Coefficients:	 [[ 0.00459789]]
# R^2 score:	 0.710368721891
# CFLAR,0.710368721891
#
# 286
# Working on G530011O06RIK mean/freq regression...
# Intercept:	 [ 0.07018193]
# Coefficients:	 [[ 0.00178497]]
# R^2 score:	 0.557913988462
# G530011O06RIK,0.557913988462
#
# 287
# Working on B3GNT2 mean/freq regression...
# Intercept:	 [ 0.16935757]
# Coefficients:	 [[ 0.00086268]]
# R^2 score:	 0.0475403839805
# B3GNT2,0.0475403839805
#
# 288
# Working on MTPN mean/freq regression...
# Intercept:	 [ 0.37498073]
# Coefficients:	 [[ 0.0024339]]
# R^2 score:	 0.533689855482
# MTPN,0.533689855482
#
# 289
# Working on PSMB10 mean/freq regression...
# Intercept:	 [ 0.21894541]
# Coefficients:	 [[ 0.00143437]]
# R^2 score:	 0.149582130512
# PSMB10,0.149582130512
#
# 290
# Working on PTPRE mean/freq regression...
# Intercept:	 [ 0.1786613]
# Coefficients:	 [[ 0.00213289]]
# R^2 score:	 0.129547903497
# PTPRE,0.129547903497
#
# 291
# Working on MKIAA0694 mean/freq regression...
# Intercept:	 [ 0.07091183]
# Coefficients:	 [[ 0.00400605]]
# R^2 score:	 0.745321053412
# MKIAA0694,0.745321053412
#
# 292
# Working on OLR1 mean/freq regression...
# Intercept:	 [ 0.05964343]
# Coefficients:	 [[ 0.00303455]]
# R^2 score:	 0.752773282273
# OLR1,0.752773282273
#
# 293
# Working on CCNL1 mean/freq regression...
# Intercept:	 [ 0.20884688]
# Coefficients:	 [[ 0.00334222]]
# R^2 score:	 0.473621807693
# CCNL1,0.473621807693
#
# 294
# Working on AA467197 mean/freq regression...
# Intercept:	 [ 0.44270183]
# Coefficients:	 [[ 0.00051299]]
# R^2 score:	 0.501713306633
# AA467197,0.501713306633
#
# 295
# Working on DNAJB6 mean/freq regression...
# Intercept:	 [ 0.34167348]
# Coefficients:	 [[ 0.00105931]]
# R^2 score:	 0.0636590120267
# DNAJB6,0.0636590120267
#
# 296
# Working on EHD1 mean/freq regression...
# Intercept:	 [ 0.11543491]
# Coefficients:	 [[ 0.00566105]]
# R^2 score:	 0.589474976473
# EHD1,0.589474976473
#
# 297
# Working on H3F3B mean/freq regression...
# Intercept:	 [ 0.55942493]
# Coefficients:	 [[ 0.00103873]]
# R^2 score:	 0.368790661052
# H3F3B,0.368790661052
#
# 298
# Working on SLC15A3 mean/freq regression...
# Intercept:	 [ 0.12101122]
# Coefficients:	 [[ 0.00240786]]
# R^2 score:	 0.419068283872
# SLC15A3,0.419068283872
#
# 299
# Working on NFKBIB mean/freq regression...
# Intercept:	 [ 0.07989441]
# Coefficients:	 [[ 0.00305238]]
# R^2 score:	 0.708723838165
# NFKBIB,0.708723838165
#
# 300
# Working on JAK2 mean/freq regression...
# Intercept:	 [ 0.10886007]
# Coefficients:	 [[ 0.00339446]]
# R^2 score:	 0.418960868738
# JAK2,0.418960868738
#
# 301
# Working on PLEK mean/freq regression...
# Intercept:	 [ 0.13219516]
# Coefficients:	 [[ 0.00189456]]
# R^2 score:	 0.583925998119
# PLEK,0.583925998119
#
# 302
# Working on RAP1B mean/freq regression...
# Intercept:	 [ 0.3341091]
# Coefficients:	 [[ 0.00170689]]
# R^2 score:	 0.215354269649
# RAP1B,0.215354269649
#
# 303
# Working on SLC3A2 mean/freq regression...
# Intercept:	 [ 0.11343226]
# Coefficients:	 [[ 0.0031358]]
# R^2 score:	 0.473216462085
# SLC3A2,0.473216462085
#
# 304
# Working on PGAP2 mean/freq regression...
# Intercept:	 [ 0.04512742]
# Coefficients:	 [[ 0.00191954]]
# R^2 score:	 0.610949846861
# PGAP2,0.610949846861
#
# 305
# Working on ALCAM mean/freq regression...
# Intercept:	 [ 0.1919783]
# Coefficients:	 [[ 0.00599667]]
# R^2 score:	 0.300285753163
# ALCAM,0.300285753163
#
# 306
# Working on UBC mean/freq regression...
# Intercept:	 [ 0.46244547]
# Coefficients:	 [[ 0.00026459]]
# R^2 score:	 0.336740364986
# UBC,0.336740364986
#
# 307
# Working on TFG mean/freq regression...
# Intercept:	 [ 0.06053297]
# Coefficients:	 [[ 0.00310039]]
# R^2 score:	 0.585509032947
# TFG,0.585509032947
#
# 308
# Working on PILRA mean/freq regression...
# Intercept:	 [-0.02687999]
# Coefficients:	 [[ 0.00453149]]
# R^2 score:	 0.661273978644
# PILRA,0.661273978644
#
# 309
# Working on PSME1 mean/freq regression...
# Intercept:	 [ 0.46911719]
# Coefficients:	 [[ 0.00079724]]
# R^2 score:	 0.295735356321
# PSME1,0.295735356321
#
# 310
# Working on DAB2 mean/freq regression...
# Intercept:	 [ 0.03204747]
# Coefficients:	 [[ 0.00557633]]
# R^2 score:	 0.843209532778
# DAB2,0.843209532778
#
# 311
# Working on AK142678 mean/freq regression...
# Intercept:	 [ 0.12964333]
# Coefficients:	 [[ 0.00136165]]
# R^2 score:	 0.17175157486
# AK142678,0.17175157486
#
# 312
# Working on PNRC1 mean/freq regression...
# Intercept:	 [ 0.09880779]
# Coefficients:	 [[ 0.00359466]]
# R^2 score:	 0.318809560278
# PNRC1,0.318809560278
#
# 313
# Working on SKIL mean/freq regression...
# Intercept:	 [-0.02667929]
# Coefficients:	 [[ 0.0102629]]
# R^2 score:	 0.727664607114
# SKIL,0.727664607114
#
# 314
# Working on SAT1 mean/freq regression...
# Intercept:	 [ 0.73828676]
# Coefficients:	 [[ 0.00031908]]
# R^2 score:	 0.0487734625886
# SAT1,0.0487734625886
#
# 315
# Working on BCL2A1B mean/freq regression...
# Intercept:	 [-0.01779186]
# Coefficients:	 [[ 0.0010212]]
# R^2 score:	 0.434919426821
# BCL2A1B,0.434919426821
#
# 316
# Working on GNA13 mean/freq regression...
# Intercept:	 [ 0.02451014]
# Coefficients:	 [[ 0.00618146]]
# R^2 score:	 0.493681390372
# GNA13,0.493681390372
#
# 317
# Working on NRP2 mean/freq regression...
# Intercept:	 [ 0.1078583]
# Coefficients:	 [[ 0.00530604]]
# R^2 score:	 0.451334582995
# NRP2,0.451334582995
#
# 318
# Working on NAMPT mean/freq regression...
# Intercept:	 [ 0.23923655]
# Coefficients:	 [[ 0.00156448]]
# R^2 score:	 0.275393079855
# NAMPT,0.275393079855
#
# 319
# Working on ISG15 mean/freq regression...
# Intercept:	 [ 0.02392771]
# Coefficients:	 [[ 0.00462549]]
# R^2 score:	 0.809562071554
# ISG15,0.809562071554
#
# 320
# Working on FAM102B mean/freq regression...
# Intercept:	 [ 0.048006]
# Coefficients:	 [[ 0.00559728]]
# R^2 score:	 0.774872186647
# FAM102B,0.774872186647
#
# 321
# Working on BCL2A1C mean/freq regression...
# Intercept:	 [-0.05870844]
# Coefficients:	 [[ 0.0068368]]
# R^2 score:	 0.880419242986
# BCL2A1C,0.880419242986
#
# 322
# Working on BIRC6 mean/freq regression...
# Intercept:	 [ 0.21670292]
# Coefficients:	 [[ 0.00166851]]
# R^2 score:	 0.102245754016
# BIRC6,0.102245754016
#
# 323
# Working on RGS1 mean/freq regression...
# Intercept:	 [-0.21112769]
# Coefficients:	 [[ 0.00125348]]
# R^2 score:	 0.824638702555
# RGS1,0.824638702555

# %%
x1
# Out:
# array([[  415.42631491],
#        [ 1083.28813642],
#        [  432.64161359],
#        [  588.52541452],
#        [  786.0472841 ],
#        [  675.28670075],
#        [  426.63907959],
#        [  438.06328826],
#        [  593.26476283],
#        [  915.02621588],
#        [  729.10019489],
#        [  529.31792485],
#        [  509.53069838],
#        [  333.68231193],
#        [  388.03384699],
#        [  281.59506739],
#        [  457.62964107],
#        [ 1289.35629098],
#        [  836.9740624 ],
#        [  791.7523987 ],
#        [  707.76427944],
#        [  762.05792869]])

# %%
lm.predict(x1)
# Out:
# array([[ 1311.58845456],
#        [  907.97599171],
#        [ 1301.18464215],
#        [ 1206.97856122],
#        [ 1087.60912629],
#        [ 1154.54565476],
#        [ 1304.81218524],
#        [ 1297.90813286],
#        [ 1204.11440582],
#        [ 1009.66260706],
#        [ 1122.02426156],
#        [ 1242.75973624],
#        [ 1254.71785535],
#        [ 1360.98923972],
#        [ 1328.14268941],
#        [ 1392.46739939],
#        [ 1286.0834955 ],
#        [  783.44173523],
#        [ 1056.83227732],
#        [ 1084.16132425],
#        [ 1134.91830806],
#        [ 1102.10674018]])

# %%
print(lm.intercept_)
# Out:
# 37967.2236598
