# %%
import pandas as pd
import statistics as st
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from statsmodels.formula.api import ols
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

induced_data = pd.read_csv('induced_genes_outliers_removed_all_zero_removed.csv')
induced_data = induced_data.iloc[:,1:]

#grp1 = ['IFITM3','SRGN','IL1RN','IFI27L2A','TNF','IFI205','TARM1','TNFSF9','IRG1','GLIPR2','INHBA','BTG1','PSME2','CLEC4E','2310016C08RIK','SQSTM1','NFKBIA','USP18','EBI3','CD86','MS4A6D','NT5C3','FPR2','H3F3B','SERPINA3G','CAV1','FAS','MS4A6C','LGALS9','GM4902','CD200','IFI204','CISH','PROCR','SLAMF7','AI607873','SGK1','IL15','ACPP','CXCL16','SLFN2','H2-Q7','MT2','H2-T23','THBS1','UBE2L6','AY096003','H1F0','ATF3','TANK','TNFSF15','HSPA5','IL15RA','IRF1','MED21','IRGM1','CCRL2','ZBP1','CASP1','RAB32','SP100','IRF8','BLNK','PSMB9','PCGF5','KTELC1','RILPL2','TMEM39A','TRIM30A','TNIP3','RBM7','SLC2A6','GBP3','BIRC3','TLR2','GTF2B','CFB','SBDS','CAR13','ARF4','SEPW1','BST2','NMI','DUSP1','PYHIN1','CD47','ZFP36','CD274','SAMHD1','SWAP70','IL7R','RELA','AK042010','A130040M12RIK','D14ERTD668E','NFKBIZ','ADAP2','XAF1','PNP','ZUFSP','IFI35','ACSL1','ANXA7','SLC7A2','HERC6','TAPBP','SLFN5','SLFN8','IFIH1','FGL2','LCP2','STAT1','GBP5','TRIM30D','LAP3','STAT5A','GBP6','DDX58','CLIC4','DHX58','STAT2','TNFAIP3','TAP1','ELL2','PIK3R5','PARP9','KPNA3','HIF1A','AFTPH','DTX3L']
#grp2 = ['SDC4','CXCL1','IL1A','CXCL3','IL1B','CCL3','AW112010','CCL17','PRDX1','CCL4','H2-M2']
#with open("global_regressions/summary.csv","w") as logfile:
#    logfile.write("gene,scoreAll\n")


#glist=['CCL5','CCL17','AK217941','AK138792','PRDX1','CXCL10','APOL7C','AW112010','IL1B','CXCL1','CCL3','SDC4','H2-M2','LY6C2','CLU','IL1A','ZDHHC21','CXCL3','CCR7','CD14','CD69','BCL2A1B','IFI27L2A','SLPI','SERPINB9','IFITM3','AA467197','GLIPR2','MX1','TNF','TARM1','BCL2A1D','CLEC4D','IRG1','CD40','BCL2A1A','USP18','SAMSN1','CLEC4E','CAR4','1810029B16RIK','CD86','SQSTM1','SERPINB6B','RNASET2B','MS4A6D','NUPR1','P2RY14','2310016C08RIK','H2-Q7','FOS','GBP2','CDKN1A','NFKBIA','FPR1','EBI3','FPR2','SAMHD1','UBE2L6','IFIT2','MS4A6C','ARF4','STXBP3A','AY096003','EPSTI1','TNIP3','AI607873','SLAMF7','CD200','RAB8B','MT2','SLFN2','HSPA5','BIRC3','IRGM1','MARCKSL1','TMEM39A','ETV3','TREX1','PROCR','BLNK','RELA','RTP4','CCRL2','TRIM30A','BHLHE40','PLAUR','KYNU','TLR2','BST2','SWAP70','ZBP1','SP100','GBP3','PCGF5','KTELC1','IRF8','IGTP','SOD2','CISH','TNFSF15','MNDAL','CFB','PLEK','PNP','ZFP36','NMI','SLC2A6','H1F0','SBDS','XAF1','NFKBIZ','TRAF1','PYHIN1','MTPN','SLC7A2','APOBEC3','CD274','TAPBP','LGALS3BP','KTN1','PPP1CB','ZUFSP','PTTG1','IFIH1','GM4951','BATF','ADAP2','IFI203','IFI35','GADD45B','PELI1','STAT1','LCP2','STAT2','GBP6','KPNA3','SLFN5','GBP5','PFKP','TAP1','TOR3A','INSIG1','DAB2','AFTPH','TXNRD1']

regression_data=pd.read_csv('summary_mean_var_all_cond.csv')
glist=regression_data.iloc[:,0].tolist();


def fit_func(x, a, b):
    return b-a*np.log(x)

# %%
summary_stats = induced_data[induced_data["Gene"]=='CXCL1']

x=np.ravel(summary_stats['Mean'].values.reshape(-1, 1))
print(x)
y=np.ravel(summary_stats['Burst Size'].values.reshape(-1, 1))
#print(y)
params = curve_fit(fit_func, x, y)
[a, b] = params[0]
    
Fy=b-a*np.log(x)
Residuals=y-Fy;   
I = abs( Residuals) < 1.5 * np.std(Residuals);

x1=x[I==True]
y1=y[I==True]
# Out:
# [  3.04802783e+01   4.54950095e+02   8.38031117e+02   7.10301238e+02
#    9.72864922e+02   1.41244583e+02   1.08086040e+03   8.14579840e+02
#    2.01483062e+02   3.21550343e+02   1.18444405e+01   4.50396451e+01
#    1.57874524e+03   2.02917395e+02   1.01740475e+02   1.59641919e+03
#    2.87951322e-01   2.90803889e+03   3.32398058e+02   1.08762771e+03
#    4.85120121e+01   1.74788576e+03   2.64619210e+03   1.52172552e+03
#    8.73531625e+00   4.56399480e+02]

# %%
#print(induced_data.head)

genelist = induced_data.iloc[:,0].reset_index(drop=True).drop_duplicates().tolist()

i=0

plt.subplots(1,1,figsize=(5,4.5))
axes = plt.gca()
axes.set_xlim([0,3000])
axes.set_ylim([0,10000])

with open("my_summary_mean_burst_all_conds_log_robust.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % ('gene','N','intercept','slope','min x','max x','R2'))

for test_gene in glist:
    i+=1
    print(i)
    summary_stats = induced_data[induced_data["Gene"]==test_gene]
    #print(summary_stats)
    if (len(summary_stats.loc[summary_stats['Mean'] == 0,['Mean']])>0) :
        print("Missing data for %s" % test_gene)
        with open("errorlog.csv","a") as logfile:
            logfile.write("%s\n" % test_gene)
        continue
    
    print("Working on %s mean/burst regression..." % test_gene)
    
    x=np.ravel(summary_stats['Mean'].values.reshape(-1, 1))
    #print(x)
    y=np.ravel(summary_stats['Burst Size'].values.reshape(-1, 1))
    #print(y)
    params = curve_fit(fit_func, x, y)
    [a, b] = params[0]
    
    Fy=b-a*np.log(x)
    Residuals=y-Fy;   
    I = abs( Residuals) < 1.5 * np.std(Residuals);
    x1=x[I==True]
    y1=y[I==True]
    
    params = curve_fit(fit_func, x1, y1)
    [a, b] = params[0]
    
    scoreAll=r2_score(y1,b-a*np.log(x1))
    print("R^2 score:\t",scoreAll)

    linecol = 'gray'
    
    #if test_gene in glist:
    plt.plot(sorted(x1),b-a*np.log(sorted(x1)), color=linecol, linewidth=1)

    with open("my_summary_mean_burst_all_conds_log_robust.csv","a") as logfile:
        logfile.write("%s,%s,%s,%s,%s,%s,%s,\n" % (test_gene,len(x1),b,a,min(x1), max(x1), scoreAll))
        print("%s,%s\n" % (test_gene,scoreAll))

plt.ylabel("Burst")
plt.xlabel("Mean")
#plt.savefig("global_regressions/mean_var_composite.png")
plt.savefig("my_mean_burst_all_conds_log_robust.png")
plt.close()
# Out:
# 1
# Working on CXCL1 mean/burst regression...
# R^2 score:	 0.837954109718
# CXCL1,0.837954109718
#
# 2
# Working on RSAD2 mean/burst regression...
# R^2 score:	 0.85489084762
# RSAD2,0.85489084762
#
# 3
# Working on OASL1 mean/burst regression...
# R^2 score:	 0.863845275008
# OASL1,0.863845275008
#
# 4
# Working on NT5C3 mean/burst regression...
# R^2 score:	 0.499857946361
# NT5C3,0.499857946361
#
# 5
# Working on CCL4 mean/burst regression...
# R^2 score:	 0.839929552282
# CCL4,0.839929552282
#
# 6
# Working on EBI3 mean/burst regression...
# R^2 score:	 0.692088539657
# EBI3,0.692088539657
#
# 7
# Working on IRGM1 mean/burst regression...
# R^2 score:	 0.807270361778
# IRGM1,0.807270361778
#
# 8
# Working on IFIT2 mean/burst regression...
# R^2 score:	 0.887873055281
# IFIT2,0.887873055281
#
# 9
# Working on PYHIN1 mean/burst regression...
# R^2 score:	 0.602748846921
# PYHIN1,0.602748846921
#
# 10
# Working on CAR4 mean/burst regression...
# R^2 score:	 0.733963213251
# CAR4,0.733963213251
#
# 11
# Working on SLFN8 mean/burst regression...
# R^2 score:	 0.80444721032
# SLFN8,0.80444721032
#
# 12
# Working on AW112010 mean/burst regression...
# R^2 score:	 0.795311263223
# AW112010,0.795311263223
#
# 13
# Working on U90926 mean/burst regression...
# R^2 score:	 0.554951298483
# U90926,0.554951298483
#
# 14
# Working on IL15 mean/burst regression...
# R^2 score:	 0.570899180429
# IL15,0.570899180429
#
# 15
# Working on GM4902 mean/burst regression...
# R^2 score:	 0.660892899752
# GM4902,0.660892899752
#
# 16
# Working on GM14446 mean/burst regression...
# R^2 score:	 0.810261522202
# GM14446,0.810261522202
#
# 17
# Working on FAM26F mean/burst regression...
# R^2 score:	 0.802505589318
# FAM26F,0.802505589318
#
# 18
# Working on D14ERTD668E mean/burst regression...
# R^2 score:	 0.745122363655
# D14ERTD668E,0.745122363655
#
# 19
# Working on GM4951 mean/burst regression...
# R^2 score:	 0.712178836097
# GM4951,0.712178836097
#
# 20
# Working on FGL2 mean/burst regression...
# R^2 score:	 0.708765192276
# FGL2,0.708765192276
#
# 21
# Working on APOL7C mean/burst regression...
# R^2 score:	 0.732476625037
# APOL7C,0.732476625037
#
# 22
# Working on TRIM30A mean/burst regression...
# R^2 score:	 0.584167443908
# TRIM30A,0.584167443908
#
# 23
# Working on CCL3 mean/burst regression...
# R^2 score:	 0.680246366969
# CCL3,0.680246366969
#
# 24
# Working on CXCL3 mean/burst regression...
# R^2 score:	 0.812959079019
# CXCL3,0.812959079019
#
# 25
# Working on CFB mean/burst regression...
# R^2 score:	 0.609931288793
# CFB,0.609931288793
#
# 26
# Working on TMEM39A mean/burst regression...
# R^2 score:	 0.859969357209
# TMEM39A,0.859969357209
#
# 27
# Working on CCND2 mean/burst regression...
# R^2 score:	 0.699891169114
# CCND2,0.699891169114
#
# 28
# Working on MS4A6C mean/burst regression...
# R^2 score:	 0.785773149257
# MS4A6C,0.785773149257
#
# 29
# Working on IRG1 mean/burst regression...
# R^2 score:	 0.813696712491
# IRG1,0.813696712491
#
# 30
# Working on CCR7 mean/burst regression...
# R^2 score:	 0.438150207593
# CCR7,0.438150207593
#
# 31
# Working on USP18 mean/burst regression...
# R^2 score:	 0.663947177693
# USP18,0.663947177693
#
# 32
# Working on IFIT3 mean/burst regression...
# R^2 score:	 0.847965005702
# IFIT3,0.847965005702
#
# 33
# Working on ACPP mean/burst regression...
# R^2 score:	 0.79962166263
# ACPP,0.79962166263
#
# 34
# Working on ACSL1 mean/burst regression...
# R^2 score:	 0.896751237516
# ACSL1,0.896751237516
#
# 35
# Working on STAT5A mean/burst regression...
# R^2 score:	 0.709082717407
# STAT5A,0.709082717407
#
# 36
# Working on TNFSF9 mean/burst regression...
# R^2 score:	 0.762764020987
# TNFSF9,0.762764020987
#
# 37
# Working on CD40 mean/burst regression...
# R^2 score:	 0.799723572389
# CD40,0.799723572389
#
# 38
# Working on IFI205 mean/burst regression...
# R^2 score:	 0.668010062895
# IFI205,0.668010062895
#
# 39
# Working on MS4A4C mean/burst regression...
# R^2 score:	 0.771718161472
# MS4A4C,0.771718161472
#
# 40
# Working on TARM1 mean/burst regression...
# R^2 score:	 0.819380418336
# TARM1,0.819380418336
#
# 41
# Working on NUDT17 mean/burst regression...
# R^2 score:	 0.730024948378
# NUDT17,0.730024948378
#
# 42
# Working on AFTPH mean/burst regression...
# R^2 score:	 0.454984188528
# AFTPH,0.454984188528
#
# 43
# Working on IRF7 mean/burst regression...
# R^2 score:	 0.640955705277
# IRF7,0.640955705277
#
# 44
# Working on TLR2 mean/burst regression...
# R^2 score:	 0.621309246059
# TLR2,0.621309246059
#
# 45
# Working on IL15RA mean/burst regression...
# R^2 score:	 0.783518991233
# IL15RA,0.783518991233
#
# 46
# Working on INHBA mean/burst regression...
# R^2 score:	 0.644760376941
# INHBA,0.644760376941
#
# 47
# Working on IIGP1 mean/burst regression...
# R^2 score:	 0.743539702061
# IIGP1,0.743539702061
#
# 48
# Working on TRIM30D mean/burst regression...
# R^2 score:	 0.481374129126
# TRIM30D,0.481374129126
#
# 49
# Working on TIMP1 mean/burst regression...
# R^2 score:	 0.788340791927
# TIMP1,0.788340791927
#
# 50
# Working on CCL7 mean/burst regression...
# R^2 score:	 0.785926845026
# CCL7,0.785926845026
#
# 51
# Working on SRGN mean/burst regression...
# R^2 score:	 0.255637752865
# SRGN,0.255637752865
#
# 52
# Working on IL1A mean/burst regression...
# R^2 score:	 0.750332640418
# IL1A,0.750332640418
#
# 53
# Working on SERPINA3G mean/burst regression...
# R^2 score:	 0.571169808806
# SERPINA3G,0.571169808806
#
# 54
# Working on TAP1 mean/burst regression...
# R^2 score:	 0.536563893048
# TAP1,0.536563893048
#
# 55
# Working on SLAMF7 mean/burst regression...
# R^2 score:	 0.166400636591
# SLAMF7,0.166400636591
#
# 56
# Working on IFIT1 mean/burst regression...
# R^2 score:	 0.738048446118
# IFIT1,0.738048446118
#
# 57
# Working on CISH mean/burst regression...
# R^2 score:	 0.474845599069
# CISH,0.474845599069
#
# 58
# Working on FAS mean/burst regression...
# R^2 score:	 0.830942923862
# FAS,0.830942923862
#
# 59
# Working on CXCL10 mean/burst regression...
# R^2 score:	 0.651422575961
# CXCL10,0.651422575961
#
# 60
# Working on SLFN5 mean/burst regression...
# R^2 score:	 0.569234228187
# SLFN5,0.569234228187
#
# 61
# Working on SLC2A6 mean/burst regression...
# R^2 score:	 0.679169920396
# SLC2A6,0.679169920396
#
# 62
# Working on CMPK2 mean/burst regression...
# R^2 score:	 0.78268597799
# CMPK2,0.78268597799
#
# 63
# Working on PCGF5 mean/burst regression...
# R^2 score:	 0.742725295765
# PCGF5,0.742725295765
#
# 64
# Working on CAR13 mean/burst regression...
# R^2 score:	 0.48716762628
# CAR13,0.48716762628
#
# 65
# Working on GBP3 mean/burst regression...
# R^2 score:	 0.56412623269
# GBP3,0.56412623269
#
# 66
# Working on UBE2L6 mean/burst regression...
# R^2 score:	 0.39128580151
# UBE2L6,0.39128580151
#
# 67
# Working on MX2 mean/burst regression...
# R^2 score:	 0.785041616201
# MX2,0.785041616201
#
# 68
# Working on ZDHHC21 mean/burst regression...
# R^2 score:	 0.807185477811
# ZDHHC21,0.807185477811
#
# 69
# Working on AK138792 mean/burst regression...
# R^2 score:	 0.822765543629
# AK138792,0.822765543629
#
# 70
# Working on CH25H mean/burst regression...
# R^2 score:	 0.693976669045
# CH25H,0.693976669045
#
# 71
# Working on PTGS2 mean/burst regression...
# R^2 score:	 0.580648264932
# PTGS2,0.580648264932
#
# 72
# Working on SAMHD1 mean/burst regression...
# R^2 score:	 0.493308739996
# SAMHD1,0.493308739996
#
# 73
# Working on SDC4 mean/burst regression...
# R^2 score:	 0.775919421469
# SDC4,0.775919421469
#
# 74
# Working on ADAP2 mean/burst regression...
# R^2 score:	 0.533023972772
# ADAP2,0.533023972772
#
# 75
# Working on MS4A6D mean/burst regression...
# R^2 score:	 0.306629223872
# MS4A6D,0.306629223872
#
# 76
# Working on ATF3 mean/burst regression...
# R^2 score:	 0.722523170276
# ATF3,0.722523170276
#
# 77
# Working on TNFSF15 mean/burst regression...
# R^2 score:	 0.804192045071
# TNFSF15,0.804192045071
#
# 78
# Working on RELA mean/burst regression...
# R^2 score:	 0.705519634302
# RELA,0.705519634302
#
# 79
# Working on ZFP36 mean/burst regression...
# R^2 score:	 0.652412809084
# ZFP36,0.652412809084
#
# 80
# Working on SLFN2 mean/burst regression...
# R^2 score:	 0.284979054194
# SLFN2,0.284979054194
#
# 81
# Working on GM12250 mean/burst regression...
# R^2 score:	 0.697319390232
# GM12250,0.697319390232
#
# 82
# Working on STAT1 mean/burst regression...
# R^2 score:	 0.242576355741
# STAT1,0.242576355741
#
# 83
# Working on BIRC3 mean/burst regression...
# R^2 score:	 0.650660371651
# BIRC3,0.650660371651
#
# 84
# Working on 1190002H23RIK mean/burst regression...
# R^2 score:	 0.278440110701
# 1190002H23RIK,0.278440110701
#
# 85
# Working on ALDH1A2 mean/burst regression...
# R^2 score:	 0.508052166811
# ALDH1A2,0.508052166811
#
# 86
# Working on OASL2 mean/burst regression...
# R^2 score:	 0.40402328229
# OASL2,0.40402328229
#
# 87
# Working on IL27 mean/burst regression...
# R^2 score:	 0.575602635374
# IL27,0.575602635374
#
# 88
# Working on H1F0 mean/burst regression...
# R^2 score:	 0.626511942656
# H1F0,0.626511942656
#
# 89
# Working on CCL2 mean/burst regression...
# R^2 score:	 0.684850327906
# CCL2,0.684850327906
#
# 90
# Working on DDX58 mean/burst regression...
# R^2 score:	 0.749757031034
# DDX58,0.749757031034
#
# 91
# Working on GBP5 mean/burst regression...
# R^2 score:	 0.433247397786
# GBP5,0.433247397786
#
# 92
# Working on CAV1 mean/burst regression...
# R^2 score:	 0.617745872396
# CAV1,0.617745872396
#
# 93
# Working on NMI mean/burst regression...
# R^2 score:	 0.519942429306
# NMI,0.519942429306
#
# 94
# Working on CCL17 mean/burst regression...
# R^2 score:	 0.33521543168
# CCL17,0.33521543168
#
# 95
# Working on SLPI mean/burst regression...
# R^2 score:	 0.725218293854
# SLPI,0.725218293854
#
# 96
# Working on H2-T23 mean/burst regression...
# R^2 score:	 0.269664371295
# H2-T23,0.269664371295
#
# 97
# Working on NFKBIZ mean/burst regression...
# R^2 score:	 0.514075912292
# NFKBIZ,0.514075912292
#
# 98
# Working on DHX58 mean/burst regression...
# R^2 score:	 0.418778013323
# DHX58,0.418778013323
#
# 99
# Working on THBS1 mean/burst regression...
# R^2 score:	 0.524433110962
# THBS1,0.524433110962
#
# 100
# Working on HERC6 mean/burst regression...
# R^2 score:	 0.400387792703
# HERC6,0.400387792703
#
# 101
# Working on CD86 mean/burst regression...
# R^2 score:	 0.503828312564
# CD86,0.503828312564
#
# 102
# Working on IGTP mean/burst regression...
# R^2 score:	 0.708447068494
# IGTP,0.708447068494
#
# 103
# Working on FABP3 mean/burst regression...
# R^2 score:	 0.704198268163
# FABP3,0.704198268163
#
# 104
# Working on AK042010 mean/burst regression...
# R^2 score:	 0.154250351554
# AK042010,0.154250351554
#
# 105
# Working on GBP6 mean/burst regression...
# R^2 score:	 0.533208041124
# GBP6,0.533208041124
#
# 106
# Working on IL1RN mean/burst regression...
# R^2 score:	 0.479958961858
# IL1RN,0.479958961858
#
# 107
# Working on SERPINB9B mean/burst regression...
# R^2 score:	 0.591772216026
# SERPINB9B,0.591772216026
#
# 108
# Working on INSIG1 mean/burst regression...
# R^2 score:	 0.737418612484
# INSIG1,0.737418612484
#
# 109
# Working on RTP4 mean/burst regression...
# R^2 score:	 0.403851934492
# RTP4,0.403851934492
#
# 110
# Working on IL1B mean/burst regression...
# R^2 score:	 0.50625708367
# IL1B,0.50625708367
#
# 111
# Working on IFI204 mean/burst regression...
# R^2 score:	 0.284021499811
# IFI204,0.284021499811
#
# 112
# Working on CD69 mean/burst regression...
# R^2 score:	 0.684395885212
# CD69,0.684395885212
#
# 113
# Working on LGALS9 mean/burst regression...
# R^2 score:	 0.499703768161
# LGALS9,0.499703768161
#
# 114
# Working on IFI27L2A mean/burst regression...
# R^2 score:	 0.55715725546
# IFI27L2A,0.55715725546
#
# 115
# Working on IFI47 mean/burst regression...
# R^2 score:	 0.678027658509
# IFI47,0.678027658509
#
# 116
# Working on CLU mean/burst regression...
# R^2 score:	 0.758993683556
# CLU,0.758993683556
#
# 117
# Working on 2310016C08RIK mean/burst regression...
# R^2 score:	 0.332524644593
# 2310016C08RIK,0.332524644593
#
# 118
# Working on KPNA3 mean/burst regression...
# R^2 score:	 0.527773333627
# KPNA3,0.527773333627
#
# 119
# Working on GLIPR2 mean/burst regression...
# R^2 score:	 0.54926192278
# GLIPR2,0.54926192278
#
# 120
# Working on XAF1 mean/burst regression...
# R^2 score:	 0.525702577366
# XAF1,0.525702577366
#
# 121
# Working on SLC7A2 mean/burst regression...
# R^2 score:	 0.649666338965
# SLC7A2,0.649666338965
#
# 122
# Working on PROCR mean/burst regression...
# R^2 score:	 0.393990346372
# PROCR,0.393990346372
#
# 123
# Working on PRPF38A mean/burst regression...
# R^2 score:	 0.609566343821
# PRPF38A,0.609566343821
#
# 124
# Working on 1810029B16RIK mean/burst regression...
# R^2 score:	 0.677196870123
# 1810029B16RIK,0.677196870123
#
# 125
# Working on CCRL2 mean/burst regression...
# R^2 score:	 0.29472697666
# CCRL2,0.29472697666
#
# 126
# Working on GBP2 mean/burst regression...
# R^2 score:	 0.76112210028
# GBP2,0.76112210028
#
# 127
# Working on DUSP1 mean/burst regression...
# R^2 score:	 0.441349554368
# DUSP1,0.441349554368
#
# 128
# Working on PTX3 mean/burst regression...
# R^2 score:	 0.687958017877
# PTX3,0.687958017877
#
# 129
# Working on BST2 mean/burst regression...
# R^2 score:	 0.63666155856
# BST2,0.63666155856
#
# 130
# Working on RAB32 mean/burst regression...
# R^2 score:	 0.358281913194
# RAB32,0.358281913194
#
# 131
# Working on CLEC4E mean/burst regression...
# R^2 score:	 0.659312657816
# CLEC4E,0.659312657816
#
# 132
# Working on BLNK mean/burst regression...
# R^2 score:	 0.412111099298
# BLNK,0.412111099298
#
# 133
# Working on SP100 mean/burst regression...
# R^2 score:	 0.257801687273
# SP100,0.257801687273
#
# 134
# Working on STAT2 mean/burst regression...
# R^2 score:	 0.445241376205
# STAT2,0.445241376205
#
# 135
# Working on CD200 mean/burst regression...
# R^2 score:	 0.534079275929
# CD200,0.534079275929
#
# 136
# Working on PARP9 mean/burst regression...
# R^2 score:	 0.400870835632
# PARP9,0.400870835632
#
# 137
# Working on PRDX1 mean/burst regression...
# R^2 score:	 0.574991348565
# PRDX1,0.574991348565
#
# 138
# Working on MMP13 mean/burst regression...
# R^2 score:	 0.628339023792
# MMP13,0.628339023792
#
# 139
# Working on CD274 mean/burst regression...
# R^2 score:	 0.164204441035
# CD274,0.164204441035
#
# 140
# Working on AI607873 mean/burst regression...
# R^2 score:	 0.213989165612
# AI607873,0.213989165612
#
# 141
# Working on PMP22 mean/burst regression...
# R^2 score:	 0.363294052967
# PMP22,0.363294052967
#
# 142
# Working on CD47 mean/burst regression...
# R^2 score:	 0.519401658128
# CD47,0.519401658128
#
# 143
# Working on ZBP1 mean/burst regression...
# R^2 score:	 0.302588188228
# ZBP1,0.302588188228
#
# 144
# Working on PHF11 mean/burst regression...
# R^2 score:	 0.626499406508
# PHF11,0.626499406508
#
# 145
# Working on TOR3A mean/burst regression...
# R^2 score:	 0.482497087651
# TOR3A,0.482497087651
#
# 146
# Working on IFI35 mean/burst regression...
# R^2 score:	 0.079885436328
# IFI35,0.079885436328
#
# 147
# Working on LCP2 mean/burst regression...
# R^2 score:	 0.306630574701
# LCP2,0.306630574701
#
# 148
# Working on SBDS mean/burst regression...
# R^2 score:	 0.459448782596
# SBDS,0.459448782596
#
# 149
# Working on IFITM3 mean/burst regression...
# R^2 score:	 0.316848047709
# IFITM3,0.316848047709
#
# 150
# Working on DTX3L mean/burst regression...
# R^2 score:	 0.221056140666
# DTX3L,0.221056140666
#
# 151
# Working on IL6 mean/burst regression...
# R^2 score:	 0.58186765831
# IL6,0.58186765831
#
# 152
# Working on FPR1 mean/burst regression...
# R^2 score:	 0.471205125301
# FPR1,0.471205125301
#
# 153
# Working on AY096003 mean/burst regression...
# R^2 score:	 0.355412049436
# AY096003,0.355412049436
#
# 154
# Working on SAA3 mean/burst regression...
# R^2 score:	 0.665486746273
# SAA3,0.665486746273
#
# 155
# Working on FOS mean/burst regression...
# R^2 score:	 0.622366397281
# FOS,0.622366397281
#
# 156
# Working on ZUFSP mean/burst regression...
# R^2 score:	 0.220560233838
# ZUFSP,0.220560233838
#
# 157
# Working on EPSTI1 mean/burst regression...
# R^2 score:	 0.694389483569
# EPSTI1,0.694389483569
#
# 158
# Working on PDZK1IP1 mean/burst regression...
# R^2 score:	 0.437101501933
# PDZK1IP1,0.437101501933
#
# 159
# Working on MCA32 mean/burst regression...
# R^2 score:	 0.617650348304
# MCA32,0.617650348304
#
# 160
# Working on NFKBIA mean/burst regression...
# R^2 score:	 0.578777899045
# NFKBIA,0.578777899045
#
# 161
# Working on H2-T10 mean/burst regression...
# R^2 score:	 0.495237981946
# H2-T10,0.495237981946
#
# 162
# Working on IFNB1 mean/burst regression...
# R^2 score:	 0.454648106276
# IFNB1,0.454648106276
#
# 163
# Working on IFIH1 mean/burst regression...
# R^2 score:	 0.433672031119
# IFIH1,0.433672031119
#
# 164
# Working on AK052414 mean/burst regression...
# R^2 score:	 0.487758538657
# AK052414,0.487758538657
#
# 165
# Working on MT2 mean/burst regression...
# R^2 score:	 0.526829234896
# MT2,0.526829234896
#
# 166
# Working on CLIC4 mean/burst regression...
# R^2 score:	 0.332366160881
# CLIC4,0.332366160881
#
# 167
# Working on ARF4 mean/burst regression...
# R^2 score:	 0.422665413689
# ARF4,0.422665413689
#
# 168
# Working on ETV3 mean/burst regression...
# R^2 score:	 0.574352812682
# ETV3,0.574352812682
#
# 169
# Working on SERPINB6B mean/burst regression...
# R^2 score:	 0.697527853008
# SERPINB6B,0.697527853008
#
# 170
# Working on RNASET2B mean/burst regression...
# R^2 score:	 0.586373034727
# RNASET2B,0.586373034727
#
# 171
# Working on KTELC1 mean/burst regression...
# R^2 score:	 0.531894731975
# KTELC1,0.531894731975
#
# 172
# Working on IL7R mean/burst regression...
# R^2 score:	 0.190537601693
# IL7R,0.190537601693
#
# 173
# Working on LAP3 mean/burst regression...
# R^2 score:	 0.380417011919
# LAP3,0.380417011919
#
# 174
# Working on FPR2 mean/burst regression...
# R^2 score:	 0.4515005817
# FPR2,0.4515005817
#
# 175
# Working on TNIP3 mean/burst regression...
# R^2 score:	 0.642190671296
# TNIP3,0.642190671296
#
# 176
# Working on NCOA7 mean/burst regression...
# R^2 score:	 0.517177115344
# NCOA7,0.517177115344
#
# 177
# Working on TNFAIP3 mean/burst regression...
# R^2 score:	 0.0834287507803
# TNFAIP3,0.0834287507803
#
# 178
# Working on ELL2 mean/burst regression...
# R^2 score:	 0.367326916661
# ELL2,0.367326916661
#
# 179
# Working on PTTG1 mean/burst regression...
# R^2 score:	 0.190369828255
# PTTG1,0.190369828255
#
# 180
# Working on MX1 mean/burst regression...
# R^2 score:	 0.473607037086
# MX1,0.473607037086
#
# 181
# Working on RILPL2 mean/burst regression...
# R^2 score:	 0.310023150044
# RILPL2,0.310023150044
#
# 182
# Working on CCL5 mean/burst regression...
# R^2 score:	 0.0288834899424
# CCL5,0.0288834899424
#
# 183
# Working on CAR2 mean/burst regression...
# R^2 score:	 0.388026909971
# CAR2,0.388026909971
#
# 184
# Working on TNF mean/burst regression...
# R^2 score:	 0.697000848465
# TNF,0.697000848465
#
# 185
# Working on SWAP70 mean/burst regression...
# R^2 score:	 0.213621537088
# SWAP70,0.213621537088
#
# 186
# Working on IRF8 mean/burst regression...
# R^2 score:	 0.622038453642
# IRF8,0.622038453642
#
# 187
# Working on TRAF1 mean/burst regression...
# R^2 score:	 0.449021742882
# TRAF1,0.449021742882
#
# 188
# Working on PPP1CB mean/burst regression...
# R^2 score:	 0.546117874171
# PPP1CB,0.546117874171
#
# 189
# Working on SERPINB9 mean/burst regression...
# R^2 score:	 0.514766637663
# SERPINB9,0.514766637663
#
# 190
# Working on RBM7 mean/burst regression...
# R^2 score:	 0.373555100135
# RBM7,0.373555100135
#
# 191
# Working on 9430076C15RIK mean/burst regression...
# R^2 score:	 0.211520169784
# 9430076C15RIK,0.211520169784
#
# 192
# Working on H2-Q7 mean/burst regression...
# R^2 score:	 0.625447185335
# H2-Q7,0.625447185335
#
# 193
# Working on MALT1 mean/burst regression...
# R^2 score:	 0.329907164597
# MALT1,0.329907164597
#
# 194
# Working on AK217941 mean/burst regression...
# R^2 score:	 0.616034520087
# AK217941,0.616034520087
#
# 195
# Working on KTN1 mean/burst regression...
# R^2 score:	 0.391248800706
# KTN1,0.391248800706
#
# 196
# Working on HSPA5 mean/burst regression...
# R^2 score:	 0.316707360184
# HSPA5,0.316707360184
#
# 197
# Working on MYD88 mean/burst regression...
# R^2 score:	 0.443074126913
# MYD88,0.443074126913
#
# 198
# Working on TAPBP mean/burst regression...
# R^2 score:	 0.479902173378
# TAPBP,0.479902173378
#
# 199
# Working on MKIAA1673 mean/burst regression...
# R^2 score:	 0.228640651206
# MKIAA1673,0.228640651206
#
# 200
# Working on IFRD1 mean/burst regression...
# R^2 score:	 0.0859527666727
# IFRD1,0.0859527666727
#
# 201
# Working on CASP1 mean/burst regression...
# R^2 score:	 0.400256596088
# CASP1,0.400256596088
#
# 202
# Working on IFI203 mean/burst regression...
# R^2 score:	 0.300767699126
# IFI203,0.300767699126
#
# 203
# Working on IRF1 mean/burst regression...
# R^2 score:	 0.377821505004
# IRF1,0.377821505004
#
# 204
# Working on TNFRSF1B mean/burst regression...
# R^2 score:	 0.414542113274
# TNFRSF1B,0.414542113274
#
# 205
# Working on A130040M12RIK mean/burst regression...
# R^2 score:	 0.136809458511
# A130040M12RIK,0.136809458511
#
# 206
# Working on PNP mean/burst regression...
# R^2 score:	 0.302606710218
# PNP,0.302606710218
#
# 207
# Working on SP140 mean/burst regression...
# R^2 score:	 0.40881962353
# SP140,0.40881962353
#
# 208
# Working on BHLHE40 mean/burst regression...
# R^2 score:	 0.198863145048
# BHLHE40,0.198863145048
#
# 209
# Working on CXCL16 mean/burst regression...
# R^2 score:	 0.484403956925
# CXCL16,0.484403956925
#
# 210
# Working on MAP2K1 mean/burst regression...
# R^2 score:	 0.44945167441
# MAP2K1,0.44945167441
#
# 211
# Working on RASGEF1B mean/burst regression...
# R^2 score:	 0.374301680179
# RASGEF1B,0.374301680179
#
# 212
# Working on CDKN1A mean/burst regression...
# R^2 score:	 0.483097536947
# CDKN1A,0.483097536947
#
# 213
# Working on SGK1 mean/burst regression...
# R^2 score:	 0.0241783706877
# SGK1,0.0241783706877
#
# 214
# Working on OAS1A mean/burst regression...
# R^2 score:	 0.42557428672
# OAS1A,0.42557428672
#
# 215
# Working on SQSTM1 mean/burst regression...
# R^2 score:	 0.183943820398
# SQSTM1,0.183943820398
# 216
# Working on RNF19B mean/burst regression...
# R^2 score:	 0.491586966366
# RNF19B,0.491586966366
#
# 217
# Working on SLC7A11 mean/burst regression...
# R^2 score:	 0.609168908433
# SLC7A11,0.609168908433
#
# 218
# Working on CD83 mean/burst regression...
# R^2 score:	 0.549206041189
# CD83,0.549206041189
#
# 219
# Working on SAMSN1 mean/burst regression...
# R^2 score:	 0.434693881361
# SAMSN1,0.434693881361
#
# 220
# Working on MED21 mean/burst regression...
# R^2 score:	 0.510242482842
# MED21,0.510242482842
#
# 221
# Working on HK2 mean/burst regression...
# R^2 score:	 0.363647186669
# HK2,0.363647186669
#
# 222
# Working on PARP14 mean/burst regression...
# R^2 score:	 0.435660112659
# PARP14,0.435660112659
#
# 223
# Working on GM6377 mean/burst regression...
# R^2 score:	 0.330610302938
# GM6377,0.330610302938
#
# 224
# Working on CCL22 mean/burst regression...
# R^2 score:	 0.593808492758
# CCL22,0.593808492758
#
# 225
# Working on BTG1 mean/burst regression...
# R^2 score:	 0.0051451642001
# BTG1,0.0051451642001
#
# 226
# Working on PDPN mean/burst regression...
# R^2 score:	 0.169211503601
# PDPN,0.169211503601
#
# 227
# Working on SOD2 mean/burst regression...
# R^2 score:	 0.478689707599
# SOD2,0.478689707599
#
# 228
# Working on MNDAL mean/burst regression...
# R^2 score:	 0.221475808156
# MNDAL,0.221475808156
#
# 229
# Working on CXCL2 mean/burst regression...
# R^2 score:	 0.20416022371
# CXCL2,0.20416022371
#
# 230
# Working on PELI1 mean/burst regression...
# R^2 score:	 0.441889990414
# PELI1,0.441889990414
#
# 231
# Working on NCK1 mean/burst regression...
# R^2 score:	 0.338107151948
# NCK1,0.338107151948
#
# 232
# Working on GADD45B mean/burst regression...
# R^2 score:	 0.391851433028
# GADD45B,0.391851433028
#
# 233
# Working on PSME2 mean/burst regression...
# R^2 score:	 0.338879004884
# PSME2,0.338879004884
#
# 234
# Working on CD14 mean/burst regression...
# R^2 score:	 0.460390058332
# CD14,0.460390058332
#
# 235
# Working on LGALS3BP mean/burst regression...
# R^2 score:	 0.112270467207
# LGALS3BP,0.112270467207
#
# 236
# Working on CLEC4D mean/burst regression...
# R^2 score:	 0.418077806289
# CLEC4D,0.418077806289
#
# 237
# Working on SNX10 mean/burst regression...
# R^2 score:	 0.481416309918
# SNX10,0.481416309918
#
# 238
# Working on BTG2 mean/burst regression...
# R^2 score:	 0.335113614496
# BTG2,0.335113614496
#
# 239
# Working on NFKB1 mean/burst regression...
# R^2 score:	 0.223700115464
# NFKB1,0.223700115464
#
# 240
# Working on PSMB9 mean/burst regression...
# R^2 score:	 0.366889992033
# PSMB9,0.366889992033
#
# 241
# Working on RNASET2A mean/burst regression...
# R^2 score:	 0.118166233336
# RNASET2A,0.118166233336
#
# 242
# Working on P2RY14 mean/burst regression...
# R^2 score:	 0.451236027917
# P2RY14,0.451236027917
#
# 243
# Working on RNF114 mean/burst regression...
# R^2 score:	 0.376290605944
# RNF114,0.376290605944
#
# 244
# Working on TMEM219 mean/burst regression...
# R^2 score:	 0.185948822024
# TMEM219,0.185948822024
#
# 245
# Working on LY6C2 mean/burst regression...
# R^2 score:	 0.590316524348
# LY6C2,0.590316524348
#
# 246
# Working on IL12B mean/burst regression...
# R^2 score:	 0.645589005332
# IL12B,0.645589005332
#
# 247
# Working on F10 mean/burst regression...
# R^2 score:	 0.172496351044
# F10,0.172496351044
#
# 248
# Working on CASP7 mean/burst regression...
# R^2 score:	 0.327507289515
# CASP7,0.327507289515
#
# 249
# Working on MDM2 mean/burst regression...
# R^2 score:	 0.188470674414
# MDM2,0.188470674414
#
# 250
# Working on KLF6 mean/burst regression...
# R^2 score:	 0.203838729506
# KLF6,0.203838729506
#
# 251
# Working on NUPR1 mean/burst regression...
# R^2 score:	 0.371827002006
# NUPR1,0.371827002006
#
# 252
# Working on CASP11 mean/burst regression...
# R^2 score:	 0.422659517531
# CASP11,0.422659517531
#
# 253
# Working on 2810474O19RIK mean/burst regression...
# R^2 score:	 0.322247362459
# 2810474O19RIK,0.322247362459
#
# 254
# Working on HCK mean/burst regression...
# R^2 score:	 0.150554191593
# HCK,0.150554191593
#
# 255
# Working on RAB8B mean/burst regression...
# R^2 score:	 0.248677263841
# RAB8B,0.248677263841
#
# 256
# Working on BCL2A1D mean/burst regression...
# R^2 score:	 0.000814940587291
# BCL2A1D,0.000814940587291
#
# 257
# Working on STXBP3A mean/burst regression...
# R^2 score:	 0.384133698058
# STXBP3A,0.384133698058
#
# 258
# Working on PFKP mean/burst regression...
# R^2 score:	 0.223547984823
# PFKP,0.223547984823
#
# 259
# Working on TANK mean/burst regression...
# R^2 score:	 0.380052140575
# TANK,0.380052140575
#
# 260
# Working on TGIF1 mean/burst regression...
# R^2 score:	 0.276967075666
# TGIF1,0.276967075666
#
# 261
# Working on PPP1R15A mean/burst regression...
# R^2 score:	 0.256987037236
# PPP1R15A,0.256987037236
#
# 262
# Working on SEPW1 mean/burst regression...
# R^2 score:	 0.0163543153171
# SEPW1,0.0163543153171
#
# 263
# Working on PLAUR mean/burst regression...
# R^2 score:	 0.0658201821261
# PLAUR,0.0658201821261
#
# 264
# Working on H2-M2 mean/burst regression...
# R^2 score:	 0.000749587204889
# H2-M2,0.000749587204889
#
# 265
# Working on BATF mean/burst regression...
# R^2 score:	 0.367944521617
# BATF,0.367944521617
#
# 266
# Working on NUP62-IL4I1 mean/burst regression...
# R^2 score:	 0.289110147111
# NUP62-IL4I1,0.289110147111
#
# 267
# Working on TNFAIP2 mean/burst regression...
# R^2 score:	 0.288583565884
# TNFAIP2,0.288583565884
#
# 268
# Working on FNDC3A mean/burst regression...
# R^2 score:	 0.372696281954
# FNDC3A,0.372696281954
#
# 269
# Working on TREX1 mean/burst regression...
# R^2 score:	 0.219032983502
# TREX1,0.219032983502
#
# 270
# Working on RAB9 mean/burst regression...
# R^2 score:	 0.485705115656
# RAB9,0.485705115656
#
# 271
# Working on BCL2A1A mean/burst regression...
# R^2 score:	 0.077715011773
# BCL2A1A,0.077715011773
#
# 272
# Working on PDE4B mean/burst regression...
# R^2 score:	 0.27462961362
# PDE4B,0.27462961362
#
# 273
# Working on PIK3R5 mean/burst regression...
# R^2 score:	 0.498995995384
# PIK3R5,0.498995995384
#
# 274
# Working on RND3 mean/burst regression...
# R^2 score:	 0.495621273828
# RND3,0.495621273828
#
# 275
# Working on CD44 mean/burst regression...
# R^2 score:	 0.051068897892
# CD44,0.051068897892
#
# 276
# Working on AK172683 mean/burst regression...
# R^2 score:	 0.246139799794
# AK172683,0.246139799794
#
# 277
# Working on ARL5C mean/burst regression...
# R^2 score:	 0.427129984914
# ARL5C,0.427129984914
#
# 278
# Working on IER3 mean/burst regression...
# R^2 score:	 0.270455130642
# IER3,0.270455130642
#
# 279
# Working on GTF2B mean/burst regression...
# R^2 score:	 0.0849501886125
# GTF2B,0.0849501886125
#
# 280
# Working on ANXA7 mean/burst regression...
# R^2 score:	 0.235869096286
# ANXA7,0.235869096286
#
# 281
# Working on TXNRD1 mean/burst regression...
# R^2 score:	 0.0898338217725
# TXNRD1,0.0898338217725
#
# 282
# Working on HIF1A mean/burst regression...
# R^2 score:	 0.00172601060494
# HIF1A,0.00172601060494
#
# 283
# Working on MARCKSL1 mean/burst regression...
# R^2 score:	 0.51198445719
# MARCKSL1,0.51198445719
#
# 284
# Working on PLK2 mean/burst regression...
# R^2 score:	 0.102331511141
# PLK2,0.102331511141
#
# 285
# Working on CFLAR mean/burst regression...
# R^2 score:	 0.20498515884
# CFLAR,0.20498515884
#
# 286
# Working on G530011O06RIK mean/burst regression...
# R^2 score:	 0.419641200937
# G530011O06RIK,0.419641200937
#
# 287
# Working on B3GNT2 mean/burst regression...
# R^2 score:	 0.408493330476
# B3GNT2,0.408493330476
#
# 288
# Working on MTPN mean/burst regression...
# R^2 score:	 0.231160711325
# MTPN,0.231160711325
#
# 289
# Working on PSMB10 mean/burst regression...
# R^2 score:	 0.114318638621
# PSMB10,0.114318638621
#
# 290
# Working on PTPRE mean/burst regression...
# R^2 score:	 0.155609749355
# PTPRE,0.155609749355
#
# 291
# Working on MKIAA0694 mean/burst regression...
# R^2 score:	 0.322986128791
# MKIAA0694,0.322986128791
#
# 292
# Working on OLR1 mean/burst regression...
# R^2 score:	 0.449025489154
# OLR1,0.449025489154
#
# 293
# Working on CCNL1 mean/burst regression...
# R^2 score:	 0.0576208562774
# CCNL1,0.0576208562774
#
# 294
# Working on AA467197 mean/burst regression...
# R^2 score:	 0.320885239953
# AA467197,0.320885239953
#
# 295
# Working on DNAJB6 mean/burst regression...
# R^2 score:	 0.297583123983
# DNAJB6,0.297583123983
#
# 296
# Working on EHD1 mean/burst regression...
# R^2 score:	 0.120301585595
# EHD1,0.120301585595
#
# 297
# Working on H3F3B mean/burst regression...
# R^2 score:	 0.21568568632
# H3F3B,0.21568568632
#
# 298
# Working on SLC15A3 mean/burst regression...
# R^2 score:	 0.209121074937
# SLC15A3,0.209121074937
#
# 299
# Working on NFKBIB mean/burst regression...
# R^2 score:	 0.0740261607045
# NFKBIB,0.0740261607045
#
# 300
# Working on JAK2 mean/burst regression...
# R^2 score:	 0.303290559796
# JAK2,0.303290559796
#
# 301
# Working on PLEK mean/burst regression...
# R^2 score:	 0.142486009509
# PLEK,0.142486009509
#
# 302
# Working on RAP1B mean/burst regression...
# R^2 score:	 0.122738510227
# RAP1B,0.122738510227
#
# 303
# Working on SLC3A2 mean/burst regression...
# R^2 score:	 0.0518786339843
# SLC3A2,0.0518786339843
#
# 304
# Working on PGAP2 mean/burst regression...
# R^2 score:	 0.217561889715
# PGAP2,0.217561889715
#
# 305
# Working on ALCAM mean/burst regression...
# R^2 score:	 0.0357284782351
# ALCAM,0.0357284782351
#
# 306
# Working on UBC mean/burst regression...
# R^2 score:	 0.189575387881
# UBC,0.189575387881
#
# 307
# Working on TFG mean/burst regression...
# R^2 score:	 0.044861579612
# TFG,0.044861579612
#
# 308
# Working on PILRA mean/burst regression...
# R^2 score:	 0.0676753967138
# PILRA,0.0676753967138
#
# 309
# Working on PSME1 mean/burst regression...
# R^2 score:	 0.35784123042
# PSME1,0.35784123042
#
# 310
# Working on DAB2 mean/burst regression...
# R^2 score:	 0.232049221451
# DAB2,0.232049221451
#
# 311
# Working on AK142678 mean/burst regression...
# R^2 score:	 0.125396062062
# AK142678,0.125396062062
#
# 312
# Working on PNRC1 mean/burst regression...
# R^2 score:	 0.195134063878
# PNRC1,0.195134063878
#
# 313
# Working on SKIL mean/burst regression...
# R^2 score:	 0.0944758723432
# SKIL,0.0944758723432
#
# 314
# Working on SAT1 mean/burst regression...
# R^2 score:	 0.138076001024
# SAT1,0.138076001024
#
# 315
# Working on BCL2A1B mean/burst regression...
# R^2 score:	 0.0434277275742
# BCL2A1B,0.0434277275742
#
# 316
# Working on GNA13 mean/burst regression...
# R^2 score:	 0.0621715948447
# GNA13,0.0621715948447
#
# 317
# Working on NRP2 mean/burst regression...
# R^2 score:	 0.0346556122361
# NRP2,0.0346556122361
#
# 318
# Working on NAMPT mean/burst regression...
# R^2 score:	 0.183110779084
# NAMPT,0.183110779084
#
# 319
# Working on ISG15 mean/burst regression...
# R^2 score:	 0.192079254727
# ISG15,0.192079254727
#
# 320
# Working on FAM102B mean/burst regression...
# R^2 score:	 0.0236389772565
# FAM102B,0.0236389772565
#
# 321
# Working on BCL2A1C mean/burst regression...
# R^2 score:	 0.0153236190341
# BCL2A1C,0.0153236190341
#
# 322
# Working on BIRC6 mean/burst regression...
# R^2 score:	 0.124927033382
# BIRC6,0.124927033382
#
# 323
# Working on RGS1 mean/burst regression...
# R^2 score:	 0.158740250926
# RGS1,0.158740250926
